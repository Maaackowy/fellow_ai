# %% [markdown]
# Maciej Filipowicz - Sentiment Classification - 10.03.2019

# %% [markdown]
# This section shows the LSTM and ULMFIT application on US Airline tweeter data for sentiment classification purpose.
# <br> The notebook is built on the following activities: </br>
# * Prepare data for deep learning (not much description here as partly it was convered in Notebook_part1.
# * Run following LSTMs:
#     * LSTM - 1-hot encoded X matrix
#     * LSTM - embedding layer learned during training
#     * LSTM - embedding layer pretrained from Twitter400 dataset
#     * LSTM - embedding layer pretrained from GoogleNews 300 dataset
#     * CNN-LSTM - chosen x representation based on vanilla-LSTM scores from previous points
# * Run the following UMLFIT:
#     * First model run on the same twitter text as other DL and ML models to see if accuracy improved.
#     * Second model with twitter text light cleansing
#     * Third model selecting only highly confident sentiment tweets

# %% [markdown]
# # Libraries and data preparation

# %% [markdown]
# ## Libraries

# %%
# General libraries
from google.colab import drive
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from functools import partial
import io

# Data and text manipulation
from sklearn.model_selection import train_test_split
from gensim.models.word2vec import Word2Vec
from gensim.models import KeyedVectors
import warnings
warnings.filterwarnings('ignore')
import string
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
from nltk.corpus import wordnet
from nltk.corpus import stopwords 
stopwords_english = stopwords.words('english')
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()   
from nltk.tokenize import TweetTokenizer
import re as regex

# keras - Deep Learning
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from keras.preprocessing.text import Tokenizer as Keras_Tokenizer
from keras.preprocessing.sequence import pad_sequences
import keras.utils
from keras.layers import Dense, Activation, Bidirectional, Embedding, Input, Dropout 
from keras.layers import CuDNNLSTM, LSTM, CuDNNGRU, GRU
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.optimizers import RMSprop
import tensorflow as tf
from keras.optimizers import RMSprop , Adam
from keras.metrics import categorical_accuracy
from keras import backend as K
from keras.callbacks import LearningRateScheduler
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D

# fastai - Deep Learning
import fastai
from fastai import *
from fastai.text import *
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Using TensorFlow backend.

# %% [markdown]
# ## Mount the Google Drive

# %%
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
df_tweet=pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/Tweets.csv")

# %%
df_tweet.shape
# Out:
# (14640, 15)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Cleansing twitter text

# %% [markdown]
# Cleansing of text is done in the same way as cleansing for Machine Learning algorithms.

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
 def clean_tweets(tweet):
    
    # remove the owner
    tweet = re.sub(r'@[A-Za-z0-9]+','', tweet)
    
    # remove stock market tickers like $GE
    
    tweet = re.sub(r'\$\w*', '', tweet)
 
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
 
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    
    # remove non-alphabetical strings 
    tweet = re.sub(r'[^a-zA-Z]', ' ', tweet) # to consider, some strings like '...' might mean irritation
 
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, #lower() function for tweets
                               strip_handles=True, 
                               reduce_len=True)
    
    tweet_tokens = tokenizer.tokenize(tweet)
 
    tweets_clean = []    
    for word in tweet_tokens:
        if (word not in stopwords_english and # remove stopwords
            word not in string.punctuation): # remove punctuation
            #stem_word = stemmer.stem(word) # stemming word
            lem_word = lemmatizer.lemmatize(word,get_wordnet_pos(word))
            tweets_clean.append(lem_word)
 
    return tweets_clean

# %%
df_tweet['cleaned_text_tokenized']=df_tweet['text'].apply(lambda x: clean_tweets(x))
df_tweet['cleaned_text_joined']=df_tweet['cleaned_text_tokenized'].apply(lambda x: ' '.join(map(str, x)))
cleaned_text_joined_all = ' '.join(df_tweet['cleaned_text_joined'])

# %%
df_tweet_selected=df_tweet[['airline_sentiment','cleaned_text_tokenized','cleaned_text_joined']]

# %%
df_tweet_selected.head(10)
# Out:
#   airline_sentiment                             cleaned_text_tokenized  \
# 0           neutral                                              [say]
# 1          positive         [plus, add, commercial, experience, tacky]
# 2           neutral     [today, must, mean, need, take, another, trip]
# 3          negative  [really, aggressive, blast, obnoxious, enterta...
# 4          negative                          [really, big, bad, thing]
# 5          negative  [seriously, would, pay, flight, seat, play, re...
# 6          positive  [yes, nearly, every, time, fly, vx, ear, worm,...
# 7           neutral  [really, miss, prime, opportunity, men, withou...
# 8          positive                                             [well]
# 9          positive                 [amaze, arrive, hour, early, good]
#
#                                  cleaned_text_joined
# 0                                                say
# 1               plus add commercial experience tacky
# 2             today must mean need take another trip
# 3  really aggressive blast obnoxious entertainmen...
# 4                               really big bad thing
# 5  seriously would pay flight seat play really ba...
# 6      yes nearly every time fly vx ear worm go away
# 7  really miss prime opportunity men without hat ...
# 8                                               well
# 9                       amaze arrive hour early good

# %% [markdown]
# ### Split the data into train and test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df_tweet_selected[['cleaned_text_tokenized','cleaned_text_joined']], df_tweet['airline_sentiment'], test_size=0.2, random_state=88)

# %%
X_train.merge(Y_train.to_frame(), left_index=True, right_index=True).head(5)
# Out:
#                                   cleaned_text_tokenized  \
# 4058   [amaze, fly, mile, unitedairlines, amp, allian...
# 382           [need, receipt, flight, change, send, one]
# 1668                [finally, make, rep, solve, problem]
# 3766   [southwest, u, mechanical, problem, least, giv...
# 12677  [airport, extra, night, hotel, heard, anything...
#
#                                      cleaned_text_joined airline_sentiment
# 4058   amaze fly mile unitedairlines amp alliance las...          positive
# 382                  need receipt flight change send one           neutral
# 1668                      finally make rep solve problem          positive
# 3766   southwest u mechanical problem least give u ro...           neutral
# 12677  airport extra night hotel heard anything embar...          negative

# %%
print(X_train.shape, Y_train.shape)
# Out:
# (11712, 2) (11712,)

# %%
X_test.merge(Y_test.to_frame(), left_index=True, right_index=True).head(5)
# Out:
#                                   cleaned_text_tokenized  \
# 1022                    [soon, do, article, thanks, tom]
# 11109                                              [lol]
# 682    [luckily, make, flight, time, disappointed, la...
# 9981                     [cancel, flight, every, flight]
# 13686  [word, failure, mean, act, instance, fail, pro...
#
#                                      cleaned_text_joined airline_sentiment
# 1022                          soon do article thanks tom          positive
# 11109                                                lol          positive
# 682    luckily make flight time disappointed lack com...          negative
# 9981                          cancel flight every flight          negative
# 13686  word failure mean act instance fail prove unsu...          negative

# %%
print(X_test.shape, Y_test.shape)
# Out:
# (2928, 2) (2928,)

# %% [markdown]
# ### Convert Y (twitter sentiment) to numeric - for Deep Learning

# %% [markdown]
# I will convert integer encoded Y variable to 1 hot-encoding using Keras to_categorical function.

# %%
Y_train = Y_train.astype('category')
dict_train = dict(enumerate(Y_train.cat.categories))
Y_train = Y_train.cat.codes

Y_test = Y_test.astype('category')
dict_test = dict(enumerate(Y_test.cat.categories))
Y_test = Y_test.cat.codes

# %%
print(f'Dictionary for train: {dict_train}')
print(f'Dictionary for test: {dict_test}')
# Out:
# Dictionary for train: {0: 'negative', 1: 'neutral', 2: 'positive'}
# Dictionary for test: {0: 'negative', 1: 'neutral', 2: 'positive'}

# %%
labels_train = keras.utils.to_categorical(np.asarray(Y_train), num_classes=3)
labels_test = keras.utils.to_categorical(np.asarray(Y_test), num_classes=3)

print('Shape of label tensor - train:', labels_train.shape)
print('Shape of label tensor - test', labels_test.shape)
# Out:
# Shape of label tensor - train: (11712, 3)
# Shape of label tensor - test (2928, 3)

# %% [markdown]
# ### Convert X (twitter text) to numeric - for Deep Learning

# %% [markdown]
# As opposite to Machine Learning algorithms I will not create 1 hot encoded (Bag of Words) vectors to represent text.
# Creating 1-hot encoded X sparse matrix would consume a lot of RAM (on Google Colab I have only 12GB), I would need to use Batch Training to get around this.
# Instead I would use Embeddings layer form Keras Sequential API.  This layer expects integer encoding and learn Embeddings during training or use pre-trained Embeddings learned from other models (Twitter 400 and GoogleNews300).
# To simulate 1-hot encoding I will use the following method from link below, which creates the 1-hot representation of the fly using keras Lambda functionality layer:
# https://fdalvi.github.io/blog/2018-04-07-keras-sequential-onehot/

# %%
# Convert X to integer encoding.
texts_train = X_train['cleaned_text_joined']
texts_test = X_test['cleaned_text_joined']

# Create the integer sequences.
tokenizer = Keras_Tokenizer()
tokenizer.fit_on_texts(texts_train)
sequences_train = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 8208 unique tokens.

# %% [markdown]
# The sequences consist of integers indicating the position of particular word in the vocabulary.

# %%
# Check the longest sequences in both training and test
def longest(list1):
    longest_list = max(len(elem) for elem in list1)
    return longest_list

print(f'Longest training sequence {longest(sequences_train)}')
print(f'Longest testing sequence {longest(sequences_test)}')
# Out:
# Longest training sequence 22
# Longest testing sequence 20

# %% [markdown]
# The longest tweet equal to 22 words, this will be my padding limit.

# %%
# Pad the sequences to specified lenght (max from dataset)
x_train_seq_pad = pad_sequences(sequences_train, maxlen=22)
x_test_seq_pad = pad_sequences(sequences_test, maxlen=22)

# %%
# Load the external embeddings - Twitter400
twitter_pretrained_w2v = KeyedVectors.load_word2vec_format('/content/gdrive/My Drive/Colab Notebooks/word2vec_twitter_model.bin', binary=True, unicode_errors='ignore')
twitter_pretrained_w2v.wv.syn0.shape
# Out:
# (3039345, 400)

# %%
# Load the external embeddings - GoogleNews300
google_pretrained_w2v = KeyedVectors.load_word2vec_format('/content/gdrive/My Drive/Colab Notebooks/GoogleNews-vectors-negative300.bin', binary=True, unicode_errors='ignore')
google_pretrained_w2v.wv.syn0.shape
# Out:
# (3000000, 300)

# %%
# Convert the pretrained weights to numpy matrices:
embedding_matrix_google_pr = np.zeros((len(word_index)+1, 300))
for word, i in word_index.items():
    #print(i,word)
    if word in google_pretrained_w2v.vocab:
        embedding_matrix_google_pr[i] = google_pretrained_w2v.word_vec(word)
print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix_google_pr, axis=1) == 0)) # Check how many words we miss to find the embeddings.

embedding_matrix_twitter_pr = np.zeros((len(word_index)+1, 400))
for word, i in word_index.items():
    #print(i,word)
    if word in twitter_pretrained_w2v.vocab:
        embedding_matrix_twitter_pr[i] = twitter_pretrained_w2v.word_vec(word)
print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix_twitter_pr, axis=1) == 0))
# Out:
# Null word embeddings: 1923
# Null word embeddings: 1173

# %% [markdown]
# Some of the words do not exist in pretrained vocabulary. These are probably the hastags. The will have null vector as representation (or unknown <UNK> token index, depending on algorithm).

# %%
# Create Emedding layer definition for pretrained weights 
embedding_layer_twitter_pr = Embedding(len(word_index)+1,
                            400,
                            weights=[embedding_matrix_twitter_pr],
                            input_length=22,
                            trainable=False)

embedding_layer_google_pr = Embedding(len(word_index)+1,
                            300,
                            weights=[embedding_matrix_google_pr],
                            input_length=22,
                            trainable=False)

# %% [markdown]
# ### Split train into Train into Train and Validation

# %% [markdown]
# In opposite to ML algorithms I will not use cross-validation strategy for validation purposes.
# Instead I separate validation sample from my train sample and compare the models while training to random validation sample.
#
# In the end of modelling I predict my results on separate test set, the same as I did for ML.

# %%
# X - integer encoded sequence padded matrix - initial training set
x_train_seq_pad.shape
# Out:
# (11712, 22)

# %%
# Y - 1-hot encoded response matrix - initial training set
labels_train.shape
# Out:
# (11712, 3)

# %%
# Split initial training matrices to receive final training and validation set for Deep Learning

trainX_DL, valX_DL, trainY_DL, valY_DL = train_test_split(x_train_seq_pad, labels_train, test_size=0.20,random_state=88)

# %%
# Check the share in sentiment type in training and validation (whether it is more less the same)
print(trainY_DL[:,0].sum()/trainY_DL.sum(), valY_DL[:,0].sum()/valY_DL.sum())
print(trainY_DL[:,1].sum()/trainY_DL.sum(), valY_DL[:,1].sum()/valY_DL.sum())
print(trainY_DL[:,2].sum()/trainY_DL.sum(), valY_DL[:,2].sum()/valY_DL.sum())
# Out:
# 0.6258939 0.631242
# 0.2120824 0.20486556
# 0.1620237 0.16389245

# %% [markdown]
# Ok, my data is ready for LSTM modelling.

# %% [markdown]
# # Modelling - Deep Learning - LSTM

# %% [markdown]
# I hope that applying LSTM models will bring additional accuracy gain in comparison to my best ML model (**78.2%**). The well known adavantage of LSTM are as follows:
# * Deep network with multi-layer structure  - I don't think this feature will benefit for this dataset. The tweet dataset is rather small, so applying complex deep network architectures will likely lead to quick overfit and rather poor generalization.
# * Long memory feature - I think that LSTM's ability to keep in memory long seqences and allow words from the beginning of sequence to have impact on predicition (like in seq to seq modelling) will not be crucial here, as the tweet texts are rather short.
# * Word as standalone vector - However using LSTM, I will apply each word separately to network so I do not average the meaning of the tweet like I did in ML algorithms. This should have positive impact on accuracy I believe.
# * Forget gates - Additionally I hope to benefit from the relevant gate structure inside LSTM cells so that crucial words will impact prediction and non-informative words will be forgotten via forget gates.
#
# Regarding the API I applied. I decided for Keras as it is simple and intuitive for my level for now. I use Sequential API which likely be replaced by Functional API, however I like sequential way of adding layers.
#
# Regarding the LSTM structure I applied.  I use CuDNNLSTM which is Cuda optimised library for LSTM. I can't then use the recurrent dropout functionality as given (known issue in keras community). After short experiments I also do not use the bidirectional layer (computational cost increased, but accuracy did not improve significantly). I would rather not expect that bidirectional forward learning would improve sentiment classification significantly (like it does for text translation use cases). I also do not use attention mechanisms. It is not easily available for this API and I would need to build it (e.g. here: https://github.com/philipperemy/keras-attention-mechanism). I have decided to skip it although we might expect that position of words might impact sentiment classification to some extent. Like words in the end of tweet text might potentially express some emotions more than other words and such position should be emphasized through model.

# %% [markdown]
# ## Model 1 - LSTM based on 1-hot encoded vectors created on the fly

# %%
# Clean memory when possible
import gc
gc.collect()
# !cat /proc/meminfo
# Out:
# MemTotal:       13335276 kB
# MemFree:          186352 kB
# MemAvailable:    1850308 kB
# Buffers:           38400 kB
# Cached:          1696144 kB
# SwapCached:            0 kB
# Active:         11672664 kB
# Inactive:        1191836 kB
# Active(anon):   11004012 kB
# Inactive(anon):      348 kB
# Active(file):     668652 kB
# Inactive(file):  1191488 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               436 kB
# Writeback:             0 kB
# AnonPages:      11130012 kB
# Mapped:           277900 kB
# Shmem:               908 kB
# Slab:             124628 kB
# SReclaimable:      90844 kB
# SUnreclaim:        33784 kB
# KernelStack:        4768 kB
# PageTables:        28784 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667636 kB
# Committed_AS:   13206804 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# DirectMap4k:      774132 kB
# DirectMap2M:    11808768 kB
# DirectMap1G:     3145728 kB

# %% [markdown]
# I have 2 GB RAM available now.

# %%
# Create index to word dictionary
idx_word=tokenizer.index_word

# Display first tweet using indexes
[idx_word[index] for index in sequences_train[0] if index!=0]
# Out:
# ['amaze',
#  'fly',
#  'mile',
#  'unitedairlines',
#  'amp',
#  'alliance',
#  'last',
#  'year',
#  'still',
#  'get',
#  'jilt',
#  'status',
#  'moneyelsewhere']

# %%
# Create function which allows to use 1-hot encoded vectors through Lambda on the fly

from keras.layers import Lambda
from keras import backend as K

def OneHot(input_dim=None, input_length=None):
    if input_dim is None or input_length is None:
        raise TypeError("input_dim or input_length is not set")

    def _one_hot(x, num_classes):
        return K.one_hot(K.cast(x, 'uint8'),
                          num_classes=num_classes)

    return Lambda(_one_hot,
                  arguments={'num_classes': input_dim},
                  input_shape=(input_length,))

# %%
# First attempt on LSTM based on 1-hot encoded vectors
model_basic_1hot_try = Sequential()
model_basic_1hot_try.add(OneHot(input_dim=8209,
                                input_length=22))
model_basic_1hot_try.add(Dropout(0.3))
model_basic_1hot_try.add(CuDNNLSTM(100, return_sequences=False))
model_basic_1hot_try.add(Dropout(0.2))
model_basic_1hot_try.add(Dense(3, activation='softmax'))
optimizer = RMSprop(lr=0.1)
model_basic_1hot_try.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])

print(model_basic_1hot_try.summary())

# I will save the model with highest accuracy 0 checkpoint
# I will monitor val_loss for patience parameter

checkpoint = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5', monitor="val_categorical_accuracy", save_best_only=True, mode='max', verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", mode='min', verbose=1, patience=50)
change_lr = LearningRateScheduler(scheduler)
callbacks_list = [checkpoint, early_stopping, change_lr]

model_basic_1hot_trained=model_basic_1hot_try.fit(trainX_DL, 
                                                  trainY_DL, 
                                                  batch_size=32, 
                                                  callbacks=callbacks_list,                      
                                                  epochs=300, 
                                                  validation_data=(valX_DL, valY_DL), 
                                                  verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_10 (Lambda)           (None, 22, 8209)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 22, 8209)          0
# _________________________________________________________________
# cu_dnnlstm_10 (CuDNNLSTM)    (None, 100)               3324400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 3,324,703
# Trainable params: 3,324,703
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 9369 samples, validate on 2343 samples
# Epoch 1/300
#  - 9s - loss: 1.0741 - categorical_accuracy: 0.6118 - val_loss: 1.0475 - val_categorical_accuracy: 0.6312
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.63124, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 2/300
#  - 7s - loss: 1.0150 - categorical_accuracy: 0.6259 - val_loss: 0.9711 - val_categorical_accuracy: 0.6312
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.63124
# Epoch 3/300
#  - 8s - loss: 0.9437 - categorical_accuracy: 0.6259 - val_loss: 0.9155 - val_categorical_accuracy: 0.6312
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.63124
# Epoch 4/300
#  - 7s - loss: 0.9189 - categorical_accuracy: 0.6259 - val_loss: 0.9059 - val_categorical_accuracy: 0.6312
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.63124
# Epoch 5/300
#  - 7s - loss: 0.9095 - categorical_accuracy: 0.6259 - val_loss: 0.8982 - val_categorical_accuracy: 0.6312
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.63124
# Epoch 6/300
#  - 7s - loss: 0.9020 - categorical_accuracy: 0.6259 - val_loss: 0.8904 - val_categorical_accuracy: 0.6312
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.63124
# Epoch 7/300
#  - 7s - loss: 0.8930 - categorical_accuracy: 0.6259 - val_loss: 0.8823 - val_categorical_accuracy: 0.6312
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.63124
# Epoch 8/300
#  - 7s - loss: 0.8837 - categorical_accuracy: 0.6259 - val_loss: 0.8738 - val_categorical_accuracy: 0.6312
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.63124
# Epoch 9/300
#  - 7s - loss: 0.8732 - categorical_accuracy: 0.6259 - val_loss: 0.8652 - val_categorical_accuracy: 0.6312
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.63124
# Epoch 10/300
#  - 7s - loss: 0.8659 - categorical_accuracy: 0.6259 - val_loss: 0.8577 - val_categorical_accuracy: 0.6312
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.63124
# Epoch 11/300
#  - 7s - loss: 0.8575 - categorical_accuracy: 0.6259 - val_loss: 0.8506 - val_categorical_accuracy: 0.6312
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.63124
# Epoch 12/300
#  - 7s - loss: 0.8553 - categorical_accuracy: 0.6259 - val_loss: 0.8466 - val_categorical_accuracy: 0.6312
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.63124
# Epoch 13/300
#  - 7s - loss: 0.8490 - categorical_accuracy: 0.6259 - val_loss: 0.8425 - val_categorical_accuracy: 0.6312
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.63124
# Epoch 14/300
#  - 7s - loss: 0.8440 - categorical_accuracy: 0.6260 - val_loss: 0.8400 - val_categorical_accuracy: 0.6312
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.63124
# Epoch 15/300
#  - 7s - loss: 0.8417 - categorical_accuracy: 0.6260 - val_loss: 0.8369 - val_categorical_accuracy: 0.6312
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.63124
# Epoch 16/300
#  - 7s - loss: 0.8419 - categorical_accuracy: 0.6264 - val_loss: 0.8340 - val_categorical_accuracy: 0.6312
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.63124
# Epoch 17/300
#  - 7s - loss: 0.8382 - categorical_accuracy: 0.6257 - val_loss: 0.8324 - val_categorical_accuracy: 0.6312
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.63124
# Epoch 18/300
#  - 7s - loss: 0.8349 - categorical_accuracy: 0.6269 - val_loss: 0.8298 - val_categorical_accuracy: 0.6312
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.63124
# Epoch 19/300
#  - 7s - loss: 0.8312 - categorical_accuracy: 0.6276 - val_loss: 0.8272 - val_categorical_accuracy: 0.6312
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.63124
# Epoch 20/300
#  - 7s - loss: 0.8315 - categorical_accuracy: 0.6270 - val_loss: 0.8250 - val_categorical_accuracy: 0.6312
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.63124
# Epoch 21/300
#  - 7s - loss: 0.8274 - categorical_accuracy: 0.6269 - val_loss: 0.8232 - val_categorical_accuracy: 0.6312
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.63124
# Epoch 22/300
#  - 7s - loss: 0.8247 - categorical_accuracy: 0.6266 - val_loss: 0.8207 - val_categorical_accuracy: 0.6312
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.63124
# Epoch 23/300
#  - 7s - loss: 0.8221 - categorical_accuracy: 0.6277 - val_loss: 0.8188 - val_categorical_accuracy: 0.6312
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.63124
# Epoch 24/300
#  - 7s - loss: 0.8202 - categorical_accuracy: 0.6274 - val_loss: 0.8165 - val_categorical_accuracy: 0.6312
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.63124
# Epoch 25/300
#  - 7s - loss: 0.8168 - categorical_accuracy: 0.6290 - val_loss: 0.8147 - val_categorical_accuracy: 0.6312
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.63124
# Epoch 26/300
#  - 7s - loss: 0.8157 - categorical_accuracy: 0.6305 - val_loss: 0.8126 - val_categorical_accuracy: 0.6312
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.63124
# Epoch 27/300
#  - 7s - loss: 0.8145 - categorical_accuracy: 0.6302 - val_loss: 0.8106 - val_categorical_accuracy: 0.6312
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.63124
# Epoch 28/300
#  - 7s - loss: 0.8135 - categorical_accuracy: 0.6307 - val_loss: 0.8090 - val_categorical_accuracy: 0.6334
#
# Epoch 00028: val_categorical_accuracy improved from 0.63124 to 0.63338, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 29/300
#  - 7s - loss: 0.8124 - categorical_accuracy: 0.6316 - val_loss: 0.8067 - val_categorical_accuracy: 0.6334
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.63338
# Epoch 30/300
#  - 7s - loss: 0.8079 - categorical_accuracy: 0.6316 - val_loss: 0.8049 - val_categorical_accuracy: 0.6381
#
# Epoch 00030: val_categorical_accuracy improved from 0.63338 to 0.63807, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 31/300
#  - 7s - loss: 0.8078 - categorical_accuracy: 0.6302 - val_loss: 0.8028 - val_categorical_accuracy: 0.6381
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.63807
# Epoch 32/300
#  - 7s - loss: 0.8036 - categorical_accuracy: 0.6328 - val_loss: 0.8011 - val_categorical_accuracy: 0.6398
#
# Epoch 00032: val_categorical_accuracy improved from 0.63807 to 0.63978, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 33/300
#  - 7s - loss: 0.8019 - categorical_accuracy: 0.6324 - val_loss: 0.7997 - val_categorical_accuracy: 0.6415
#
# Epoch 00033: val_categorical_accuracy improved from 0.63978 to 0.64149, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 34/300
#  - 7s - loss: 0.8007 - categorical_accuracy: 0.6350 - val_loss: 0.7975 - val_categorical_accuracy: 0.6411
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.64149
# Epoch 35/300
#  - 7s - loss: 0.7987 - categorical_accuracy: 0.6348 - val_loss: 0.7963 - val_categorical_accuracy: 0.6436
#
# Epoch 00035: val_categorical_accuracy improved from 0.64149 to 0.64362, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 36/300
#  - 7s - loss: 0.7978 - categorical_accuracy: 0.6378 - val_loss: 0.7940 - val_categorical_accuracy: 0.6415
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.64362
# Epoch 37/300
#  - 7s - loss: 0.7961 - categorical_accuracy: 0.6355 - val_loss: 0.7924 - val_categorical_accuracy: 0.6432
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.64362
# Epoch 38/300
#  - 7s - loss: 0.7909 - categorical_accuracy: 0.6390 - val_loss: 0.7908 - val_categorical_accuracy: 0.6440
#
# Epoch 00038: val_categorical_accuracy improved from 0.64362 to 0.64405, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 39/300
#  - 7s - loss: 0.7935 - categorical_accuracy: 0.6373 - val_loss: 0.7894 - val_categorical_accuracy: 0.6440
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.64405
# Epoch 40/300
#  - 7s - loss: 0.7885 - categorical_accuracy: 0.6365 - val_loss: 0.7878 - val_categorical_accuracy: 0.6436
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.64405
# Epoch 41/300
#  - 7s - loss: 0.7918 - categorical_accuracy: 0.6412 - val_loss: 0.7863 - val_categorical_accuracy: 0.6475
#
# Epoch 00041: val_categorical_accuracy improved from 0.64405 to 0.64746, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 42/300
#  - 7s - loss: 0.7855 - categorical_accuracy: 0.6433 - val_loss: 0.7848 - val_categorical_accuracy: 0.6470
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.64746
# Epoch 43/300
#  - 7s - loss: 0.7866 - categorical_accuracy: 0.6435 - val_loss: 0.7833 - val_categorical_accuracy: 0.6470
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.64746
# Epoch 44/300
#  - 7s - loss: 0.7860 - categorical_accuracy: 0.6415 - val_loss: 0.7816 - val_categorical_accuracy: 0.6466
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.64746
# Epoch 45/300
#  - 7s - loss: 0.7823 - categorical_accuracy: 0.6438 - val_loss: 0.7806 - val_categorical_accuracy: 0.6479
#
# Epoch 00045: val_categorical_accuracy improved from 0.64746 to 0.64789, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 46/300
#  - 7s - loss: 0.7813 - categorical_accuracy: 0.6460 - val_loss: 0.7790 - val_categorical_accuracy: 0.6479
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.64789
# Epoch 47/300
#  - 7s - loss: 0.7815 - categorical_accuracy: 0.6479 - val_loss: 0.7781 - val_categorical_accuracy: 0.6522
#
# Epoch 00047: val_categorical_accuracy improved from 0.64789 to 0.65216, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 48/300
#  - 7s - loss: 0.7815 - categorical_accuracy: 0.6451 - val_loss: 0.7764 - val_categorical_accuracy: 0.6500
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.65216
# Epoch 49/300
#  - 7s - loss: 0.7800 - categorical_accuracy: 0.6473 - val_loss: 0.7754 - val_categorical_accuracy: 0.6534
#
# Epoch 00049: val_categorical_accuracy improved from 0.65216 to 0.65344, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 50/300
#  - 7s - loss: 0.7756 - categorical_accuracy: 0.6486 - val_loss: 0.7739 - val_categorical_accuracy: 0.6492
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.65344
# Epoch 51/300
#  - 7s - loss: 0.7772 - categorical_accuracy: 0.6489 - val_loss: 0.7728 - val_categorical_accuracy: 0.6569
#
# Epoch 00051: val_categorical_accuracy improved from 0.65344 to 0.65685, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 52/300
#  - 7s - loss: 0.7789 - categorical_accuracy: 0.6516 - val_loss: 0.7714 - val_categorical_accuracy: 0.6556
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.65685
# Epoch 53/300
#  - 7s - loss: 0.7748 - categorical_accuracy: 0.6513 - val_loss: 0.7698 - val_categorical_accuracy: 0.6534
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.65685
# Epoch 54/300
#  - 7s - loss: 0.7745 - categorical_accuracy: 0.6524 - val_loss: 0.7688 - val_categorical_accuracy: 0.6539
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.65685
# Epoch 55/300
#  - 7s - loss: 0.7761 - categorical_accuracy: 0.6533 - val_loss: 0.7676 - val_categorical_accuracy: 0.6560
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.65685
# Epoch 56/300
#  - 7s - loss: 0.7752 - categorical_accuracy: 0.6576 - val_loss: 0.7670 - val_categorical_accuracy: 0.6543
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.65685
# Epoch 57/300
#  - 7s - loss: 0.7732 - categorical_accuracy: 0.6544 - val_loss: 0.7653 - val_categorical_accuracy: 0.6560
#
# Epoch 00057: val_categorical_accuracy did not improve from 0.65685
# Epoch 58/300
#  - 7s - loss: 0.7728 - categorical_accuracy: 0.6523 - val_loss: 0.7642 - val_categorical_accuracy: 0.6547
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.65685
# Epoch 59/300
#  - 7s - loss: 0.7717 - categorical_accuracy: 0.6571 - val_loss: 0.7635 - val_categorical_accuracy: 0.6556
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.65685
# Epoch 60/300
#  - 7s - loss: 0.7689 - categorical_accuracy: 0.6577 - val_loss: 0.7623 - val_categorical_accuracy: 0.6564
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.65685
# Epoch 61/300
#  - 7s - loss: 0.7690 - categorical_accuracy: 0.6591 - val_loss: 0.7615 - val_categorical_accuracy: 0.6560
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.65685
# Epoch 62/300
#  - 7s - loss: 0.7682 - categorical_accuracy: 0.6619 - val_loss: 0.7601 - val_categorical_accuracy: 0.6586
#
# Epoch 00062: val_categorical_accuracy improved from 0.65685 to 0.65856, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 63/300
#  - 7s - loss: 0.7688 - categorical_accuracy: 0.6581 - val_loss: 0.7596 - val_categorical_accuracy: 0.6590
#
# Epoch 00063: val_categorical_accuracy improved from 0.65856 to 0.65898, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 64/300
#  - 7s - loss: 0.7660 - categorical_accuracy: 0.6634 - val_loss: 0.7581 - val_categorical_accuracy: 0.6586
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.65898
# Epoch 65/300
#  - 7s - loss: 0.7646 - categorical_accuracy: 0.6650 - val_loss: 0.7569 - val_categorical_accuracy: 0.6603
#
# Epoch 00065: val_categorical_accuracy improved from 0.65898 to 0.66026, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 66/300
#  - 7s - loss: 0.7646 - categorical_accuracy: 0.6643 - val_loss: 0.7558 - val_categorical_accuracy: 0.6628
#
# Epoch 00066: val_categorical_accuracy improved from 0.66026 to 0.66283, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 67/300
#  - 7s - loss: 0.7650 - categorical_accuracy: 0.6695 - val_loss: 0.7549 - val_categorical_accuracy: 0.6624
#
# Epoch 00067: val_categorical_accuracy did not improve from 0.66283
# Epoch 68/300
#  - 7s - loss: 0.7638 - categorical_accuracy: 0.6683 - val_loss: 0.7539 - val_categorical_accuracy: 0.6633
#
# Epoch 00068: val_categorical_accuracy improved from 0.66283 to 0.66325, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 69/300
#  - 7s - loss: 0.7616 - categorical_accuracy: 0.6724 - val_loss: 0.7530 - val_categorical_accuracy: 0.6675
#
# Epoch 00069: val_categorical_accuracy improved from 0.66325 to 0.66752, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 70/300
#  - 7s - loss: 0.7612 - categorical_accuracy: 0.6728 - val_loss: 0.7520 - val_categorical_accuracy: 0.6650
#
# Epoch 00070: val_categorical_accuracy did not improve from 0.66752
# Epoch 71/300
#  - 7s - loss: 0.7621 - categorical_accuracy: 0.6718 - val_loss: 0.7513 - val_categorical_accuracy: 0.6705
#
# Epoch 00071: val_categorical_accuracy improved from 0.66752 to 0.67051, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 72/300
#  - 7s - loss: 0.7629 - categorical_accuracy: 0.6723 - val_loss: 0.7497 - val_categorical_accuracy: 0.6662
#
# Epoch 00072: val_categorical_accuracy did not improve from 0.67051
# Epoch 73/300
#  - 7s - loss: 0.7623 - categorical_accuracy: 0.6701 - val_loss: 0.7489 - val_categorical_accuracy: 0.6718
#
# Epoch 00073: val_categorical_accuracy improved from 0.67051 to 0.67179, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 74/300
#  - 7s - loss: 0.7570 - categorical_accuracy: 0.6753 - val_loss: 0.7480 - val_categorical_accuracy: 0.6739
#
# Epoch 00074: val_categorical_accuracy improved from 0.67179 to 0.67392, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 75/300
#  - 7s - loss: 0.7589 - categorical_accuracy: 0.6725 - val_loss: 0.7472 - val_categorical_accuracy: 0.6709
#
# Epoch 00075: val_categorical_accuracy did not improve from 0.67392
# Epoch 76/300
#  - 8s - loss: 0.7595 - categorical_accuracy: 0.6794 - val_loss: 0.7461 - val_categorical_accuracy: 0.6731
#
# Epoch 00076: val_categorical_accuracy did not improve from 0.67392
# Epoch 77/300
#  - 7s - loss: 0.7581 - categorical_accuracy: 0.6811 - val_loss: 0.7463 - val_categorical_accuracy: 0.6697
#
# Epoch 00077: val_categorical_accuracy did not improve from 0.67392
# Epoch 78/300
#  - 7s - loss: 0.7556 - categorical_accuracy: 0.6797 - val_loss: 0.7439 - val_categorical_accuracy: 0.6731
#
# Epoch 00078: val_categorical_accuracy did not improve from 0.67392
# Epoch 79/300
#  - 7s - loss: 0.7501 - categorical_accuracy: 0.6834 - val_loss: 0.7431 - val_categorical_accuracy: 0.6846
#
# Epoch 00079: val_categorical_accuracy improved from 0.67392 to 0.68459, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 80/300
#  - 7s - loss: 0.7552 - categorical_accuracy: 0.6831 - val_loss: 0.7422 - val_categorical_accuracy: 0.6833
#
# Epoch 00080: val_categorical_accuracy did not improve from 0.68459
# Epoch 81/300
#  - 7s - loss: 0.7528 - categorical_accuracy: 0.6843 - val_loss: 0.7413 - val_categorical_accuracy: 0.6837
#
# Epoch 00081: val_categorical_accuracy did not improve from 0.68459
# Epoch 82/300
#  - 7s - loss: 0.7536 - categorical_accuracy: 0.6808 - val_loss: 0.7404 - val_categorical_accuracy: 0.6842
#
# Epoch 00082: val_categorical_accuracy did not improve from 0.68459
# Epoch 83/300
#  - 7s - loss: 0.7561 - categorical_accuracy: 0.6797 - val_loss: 0.7394 - val_categorical_accuracy: 0.6820
#
# Epoch 00083: val_categorical_accuracy did not improve from 0.68459
# Epoch 84/300
#  - 7s - loss: 0.7524 - categorical_accuracy: 0.6800 - val_loss: 0.7392 - val_categorical_accuracy: 0.6948
#
# Epoch 00084: val_categorical_accuracy improved from 0.68459 to 0.69484, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 85/300
#  - 7s - loss: 0.7479 - categorical_accuracy: 0.6842 - val_loss: 0.7375 - val_categorical_accuracy: 0.6837
#
# Epoch 00085: val_categorical_accuracy did not improve from 0.69484
# Epoch 86/300
#  - 7s - loss: 0.7472 - categorical_accuracy: 0.6837 - val_loss: 0.7363 - val_categorical_accuracy: 0.6948
#
# Epoch 00086: val_categorical_accuracy did not improve from 0.69484
# Epoch 87/300
#  - 7s - loss: 0.7512 - categorical_accuracy: 0.6842 - val_loss: 0.7354 - val_categorical_accuracy: 0.6953
#
# Epoch 00087: val_categorical_accuracy improved from 0.69484 to 0.69526, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 88/300
#  - 7s - loss: 0.7482 - categorical_accuracy: 0.6875 - val_loss: 0.7344 - val_categorical_accuracy: 0.6842
#
# Epoch 00088: val_categorical_accuracy did not improve from 0.69526
# Epoch 89/300
#  - 7s - loss: 0.7482 - categorical_accuracy: 0.6871 - val_loss: 0.7336 - val_categorical_accuracy: 0.6948
#
# Epoch 00089: val_categorical_accuracy did not improve from 0.69526
# Epoch 90/300
#  - 7s - loss: 0.7459 - categorical_accuracy: 0.6850 - val_loss: 0.7323 - val_categorical_accuracy: 0.6944
#
# Epoch 00090: val_categorical_accuracy did not improve from 0.69526
# Epoch 91/300
#  - 7s - loss: 0.7392 - categorical_accuracy: 0.6876 - val_loss: 0.7310 - val_categorical_accuracy: 0.6931
#
# Epoch 00091: val_categorical_accuracy did not improve from 0.69526
# Epoch 92/300
#  - 7s - loss: 0.7400 - categorical_accuracy: 0.6860 - val_loss: 0.7298 - val_categorical_accuracy: 0.6936
#
# Epoch 00092: val_categorical_accuracy did not improve from 0.69526
# Epoch 93/300
#  - 7s - loss: 0.7444 - categorical_accuracy: 0.6865 - val_loss: 0.7289 - val_categorical_accuracy: 0.6936
#
# Epoch 00093: val_categorical_accuracy did not improve from 0.69526
# Epoch 94/300
#  - 7s - loss: 0.7400 - categorical_accuracy: 0.6901 - val_loss: 0.7279 - val_categorical_accuracy: 0.6948
#
# Epoch 00094: val_categorical_accuracy did not improve from 0.69526
# Epoch 95/300
#  - 7s - loss: 0.7400 - categorical_accuracy: 0.6882 - val_loss: 0.7266 - val_categorical_accuracy: 0.6961
#
# Epoch 00095: val_categorical_accuracy improved from 0.69526 to 0.69612, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 96/300
#  - 7s - loss: 0.7420 - categorical_accuracy: 0.6910 - val_loss: 0.7258 - val_categorical_accuracy: 0.6948
#
# Epoch 00096: val_categorical_accuracy did not improve from 0.69612
# Epoch 97/300
#  - 7s - loss: 0.7398 - categorical_accuracy: 0.6887 - val_loss: 0.7247 - val_categorical_accuracy: 0.6978
#
# Epoch 00097: val_categorical_accuracy improved from 0.69612 to 0.69782, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 98/300
#  - 7s - loss: 0.7386 - categorical_accuracy: 0.6887 - val_loss: 0.7237 - val_categorical_accuracy: 0.6995
#
# Epoch 00098: val_categorical_accuracy improved from 0.69782 to 0.69953, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 99/300
#  - 7s - loss: 0.7408 - categorical_accuracy: 0.6887 - val_loss: 0.7225 - val_categorical_accuracy: 0.6961
#
# Epoch 00099: val_categorical_accuracy did not improve from 0.69953
# Epoch 100/300
#  - 7s - loss: 0.7353 - categorical_accuracy: 0.6901 - val_loss: 0.7213 - val_categorical_accuracy: 0.7025
#
# Epoch 00100: val_categorical_accuracy improved from 0.69953 to 0.70252, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 101/300
#  - 7s - loss: 0.7342 - categorical_accuracy: 0.6880 - val_loss: 0.7202 - val_categorical_accuracy: 0.7008
#
# Epoch 00101: val_categorical_accuracy did not improve from 0.70252
# Epoch 102/300
#  - 7s - loss: 0.7335 - categorical_accuracy: 0.6935 - val_loss: 0.7196 - val_categorical_accuracy: 0.6987
#
# Epoch 00102: val_categorical_accuracy did not improve from 0.70252
# Epoch 103/300
#  - 7s - loss: 0.7349 - categorical_accuracy: 0.6876 - val_loss: 0.7181 - val_categorical_accuracy: 0.7017
#
# Epoch 00103: val_categorical_accuracy did not improve from 0.70252
# Epoch 104/300
#  - 7s - loss: 0.7350 - categorical_accuracy: 0.6916 - val_loss: 0.7170 - val_categorical_accuracy: 0.7008
#
# Epoch 00104: val_categorical_accuracy did not improve from 0.70252
# Epoch 105/300
#  - 7s - loss: 0.7356 - categorical_accuracy: 0.6894 - val_loss: 0.7162 - val_categorical_accuracy: 0.7021
#
# Epoch 00105: val_categorical_accuracy did not improve from 0.70252
# Epoch 106/300
#  - 7s - loss: 0.7282 - categorical_accuracy: 0.6898 - val_loss: 0.7146 - val_categorical_accuracy: 0.7034
#
# Epoch 00106: val_categorical_accuracy improved from 0.70252 to 0.70337, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 107/300
#  - 7s - loss: 0.7325 - categorical_accuracy: 0.6893 - val_loss: 0.7138 - val_categorical_accuracy: 0.7012
#
# Epoch 00107: val_categorical_accuracy did not improve from 0.70337
# Epoch 108/300
#  - 7s - loss: 0.7347 - categorical_accuracy: 0.6850 - val_loss: 0.7137 - val_categorical_accuracy: 0.7000
#
# Epoch 00108: val_categorical_accuracy did not improve from 0.70337
# Epoch 109/300
#  - 7s - loss: 0.7338 - categorical_accuracy: 0.6921 - val_loss: 0.7119 - val_categorical_accuracy: 0.7034
#
# Epoch 00109: val_categorical_accuracy did not improve from 0.70337
# Epoch 110/300
#  - 7s - loss: 0.7305 - categorical_accuracy: 0.6889 - val_loss: 0.7125 - val_categorical_accuracy: 0.7000
#
# Epoch 00110: val_categorical_accuracy did not improve from 0.70337
# Epoch 111/300
#  - 7s - loss: 0.7258 - categorical_accuracy: 0.6939 - val_loss: 0.7099 - val_categorical_accuracy: 0.7034
#
# Epoch 00111: val_categorical_accuracy did not improve from 0.70337
# Epoch 112/300
#  - 7s - loss: 0.7292 - categorical_accuracy: 0.6877 - val_loss: 0.7094 - val_categorical_accuracy: 0.7072
#
# Epoch 00112: val_categorical_accuracy improved from 0.70337 to 0.70721, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 113/300
#  - 7s - loss: 0.7286 - categorical_accuracy: 0.6925 - val_loss: 0.7087 - val_categorical_accuracy: 0.7047
#
# Epoch 00113: val_categorical_accuracy did not improve from 0.70721
# Epoch 114/300
#  - 7s - loss: 0.7296 - categorical_accuracy: 0.6917 - val_loss: 0.7079 - val_categorical_accuracy: 0.7059
#
# Epoch 00114: val_categorical_accuracy did not improve from 0.70721
# Epoch 115/300
#  - 7s - loss: 0.7218 - categorical_accuracy: 0.6946 - val_loss: 0.7069 - val_categorical_accuracy: 0.7068
#
# Epoch 00115: val_categorical_accuracy did not improve from 0.70721
# Epoch 116/300
#  - 7s - loss: 0.7226 - categorical_accuracy: 0.6945 - val_loss: 0.7073 - val_categorical_accuracy: 0.7021
#
# Epoch 00116: val_categorical_accuracy did not improve from 0.70721
# Epoch 117/300
#  - 7s - loss: 0.7218 - categorical_accuracy: 0.6925 - val_loss: 0.7059 - val_categorical_accuracy: 0.7038
#
# Epoch 00117: val_categorical_accuracy did not improve from 0.70721
# Epoch 118/300
#  - 7s - loss: 0.7240 - categorical_accuracy: 0.6916 - val_loss: 0.7050 - val_categorical_accuracy: 0.7038
#
# Epoch 00118: val_categorical_accuracy did not improve from 0.70721
# Epoch 119/300
#  - 7s - loss: 0.7254 - categorical_accuracy: 0.6885 - val_loss: 0.7044 - val_categorical_accuracy: 0.7064
#
# Epoch 00119: val_categorical_accuracy did not improve from 0.70721
# Epoch 120/300
#  - 7s - loss: 0.7244 - categorical_accuracy: 0.6966 - val_loss: 0.7048 - val_categorical_accuracy: 0.7012
#
# Epoch 00120: val_categorical_accuracy did not improve from 0.70721
# Epoch 121/300
#  - 7s - loss: 0.7212 - categorical_accuracy: 0.6974 - val_loss: 0.7031 - val_categorical_accuracy: 0.7038
#
# Epoch 00121: val_categorical_accuracy did not improve from 0.70721
# Epoch 122/300
#  - 7s - loss: 0.7240 - categorical_accuracy: 0.6937 - val_loss: 0.7024 - val_categorical_accuracy: 0.7038
#
# Epoch 00122: val_categorical_accuracy did not improve from 0.70721
# Epoch 123/300
#  - 7s - loss: 0.7225 - categorical_accuracy: 0.6966 - val_loss: 0.7027 - val_categorical_accuracy: 0.7025
#
# Epoch 00123: val_categorical_accuracy did not improve from 0.70721
# Epoch 124/300
#  - 7s - loss: 0.7211 - categorical_accuracy: 0.6911 - val_loss: 0.7014 - val_categorical_accuracy: 0.7064
#
# Epoch 00124: val_categorical_accuracy did not improve from 0.70721
# Epoch 125/300
#  - 7s - loss: 0.7214 - categorical_accuracy: 0.6922 - val_loss: 0.7020 - val_categorical_accuracy: 0.7008
#
# Epoch 00125: val_categorical_accuracy did not improve from 0.70721
# Epoch 126/300
#  - 7s - loss: 0.7284 - categorical_accuracy: 0.6916 - val_loss: 0.7008 - val_categorical_accuracy: 0.7059
#
# Epoch 00126: val_categorical_accuracy did not improve from 0.70721
# Epoch 127/300
#  - 7s - loss: 0.7236 - categorical_accuracy: 0.6936 - val_loss: 0.7006 - val_categorical_accuracy: 0.7047
#
# Epoch 00127: val_categorical_accuracy did not improve from 0.70721
# Epoch 128/300
#  - 7s - loss: 0.7231 - categorical_accuracy: 0.6932 - val_loss: 0.7011 - val_categorical_accuracy: 0.7064
#
# Epoch 00128: val_categorical_accuracy did not improve from 0.70721
# Epoch 129/300
#  - 7s - loss: 0.7141 - categorical_accuracy: 0.7028 - val_loss: 0.6996 - val_categorical_accuracy: 0.7042
#
# Epoch 00129: val_categorical_accuracy did not improve from 0.70721
# Epoch 130/300
#  - 7s - loss: 0.7146 - categorical_accuracy: 0.6993 - val_loss: 0.6986 - val_categorical_accuracy: 0.7051
#
# Epoch 00130: val_categorical_accuracy did not improve from 0.70721
# Epoch 131/300
#  - 7s - loss: 0.7164 - categorical_accuracy: 0.6979 - val_loss: 0.6982 - val_categorical_accuracy: 0.7064
#
# Epoch 00131: val_categorical_accuracy did not improve from 0.70721
# Epoch 132/300
#  - 7s - loss: 0.7178 - categorical_accuracy: 0.6980 - val_loss: 0.6981 - val_categorical_accuracy: 0.7038
#
# Epoch 00132: val_categorical_accuracy did not improve from 0.70721
# Epoch 133/300
#  - 7s - loss: 0.7172 - categorical_accuracy: 0.6956 - val_loss: 0.6972 - val_categorical_accuracy: 0.7042
#
# Epoch 00133: val_categorical_accuracy did not improve from 0.70721
# Epoch 134/300
#  - 7s - loss: 0.7144 - categorical_accuracy: 0.6942 - val_loss: 0.6976 - val_categorical_accuracy: 0.7068
#
# Epoch 00134: val_categorical_accuracy did not improve from 0.70721
# Epoch 135/300
#  - 7s - loss: 0.7201 - categorical_accuracy: 0.6920 - val_loss: 0.6974 - val_categorical_accuracy: 0.7059
#
# Epoch 00135: val_categorical_accuracy did not improve from 0.70721
# Epoch 136/300
#  - 7s - loss: 0.7137 - categorical_accuracy: 0.6961 - val_loss: 0.6956 - val_categorical_accuracy: 0.7047
#
# Epoch 00136: val_categorical_accuracy did not improve from 0.70721
# Epoch 137/300
#  - 7s - loss: 0.7193 - categorical_accuracy: 0.6970 - val_loss: 0.6953 - val_categorical_accuracy: 0.7055
#
# Epoch 00137: val_categorical_accuracy did not improve from 0.70721
# Epoch 138/300
#  - 7s - loss: 0.7203 - categorical_accuracy: 0.6898 - val_loss: 0.6951 - val_categorical_accuracy: 0.7051
#
# Epoch 00138: val_categorical_accuracy did not improve from 0.70721
# Epoch 139/300
#  - 7s - loss: 0.7176 - categorical_accuracy: 0.6955 - val_loss: 0.6948 - val_categorical_accuracy: 0.7029
#
# Epoch 00139: val_categorical_accuracy did not improve from 0.70721
# Epoch 140/300
#  - 7s - loss: 0.7147 - categorical_accuracy: 0.6955 - val_loss: 0.6942 - val_categorical_accuracy: 0.7064
#
# Epoch 00140: val_categorical_accuracy did not improve from 0.70721
# Epoch 141/300
#  - 7s - loss: 0.7126 - categorical_accuracy: 0.6991 - val_loss: 0.6944 - val_categorical_accuracy: 0.7051
#
# Epoch 00141: val_categorical_accuracy did not improve from 0.70721
# Epoch 142/300
#  - 7s - loss: 0.7194 - categorical_accuracy: 0.6956 - val_loss: 0.6940 - val_categorical_accuracy: 0.7089
#
# Epoch 00142: val_categorical_accuracy improved from 0.70721 to 0.70892, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 143/300
#  - 7s - loss: 0.7161 - categorical_accuracy: 0.6910 - val_loss: 0.6936 - val_categorical_accuracy: 0.7064
#
# Epoch 00143: val_categorical_accuracy did not improve from 0.70892
# Epoch 144/300
#  - 7s - loss: 0.7150 - categorical_accuracy: 0.6962 - val_loss: 0.6938 - val_categorical_accuracy: 0.7059
#
# Epoch 00144: val_categorical_accuracy did not improve from 0.70892
# Epoch 145/300
#  - 7s - loss: 0.7211 - categorical_accuracy: 0.6911 - val_loss: 0.6953 - val_categorical_accuracy: 0.7068
#
# Epoch 00145: val_categorical_accuracy did not improve from 0.70892
# Epoch 146/300
#  - 7s - loss: 0.7093 - categorical_accuracy: 0.6987 - val_loss: 0.6959 - val_categorical_accuracy: 0.7068
#
# Epoch 00146: val_categorical_accuracy did not improve from 0.70892
# Epoch 147/300
#  - 7s - loss: 0.7146 - categorical_accuracy: 0.6956 - val_loss: 0.6943 - val_categorical_accuracy: 0.7064
#
# Epoch 00147: val_categorical_accuracy did not improve from 0.70892
# Epoch 148/300
#  - 7s - loss: 0.7109 - categorical_accuracy: 0.6938 - val_loss: 0.6940 - val_categorical_accuracy: 0.7093
#
# Epoch 00148: val_categorical_accuracy improved from 0.70892 to 0.70935, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 149/300
#  - 7s - loss: 0.7174 - categorical_accuracy: 0.6931 - val_loss: 0.6933 - val_categorical_accuracy: 0.7059
#
# Epoch 00149: val_categorical_accuracy did not improve from 0.70935
# Epoch 150/300
#  - 7s - loss: 0.7162 - categorical_accuracy: 0.6976 - val_loss: 0.6927 - val_categorical_accuracy: 0.7059
#
# Epoch 00150: val_categorical_accuracy did not improve from 0.70935
# Epoch 151/300
#  - 7s - loss: 0.7119 - categorical_accuracy: 0.6966 - val_loss: 0.6928 - val_categorical_accuracy: 0.7093
#
# Epoch 00151: val_categorical_accuracy did not improve from 0.70935
# Epoch 152/300
#  - 7s - loss: 0.7114 - categorical_accuracy: 0.6976 - val_loss: 0.6922 - val_categorical_accuracy: 0.7038
#
# Epoch 00152: val_categorical_accuracy did not improve from 0.70935
# Epoch 153/300
#  - 7s - loss: 0.7104 - categorical_accuracy: 0.7030 - val_loss: 0.6916 - val_categorical_accuracy: 0.7059
#
# Epoch 00153: val_categorical_accuracy did not improve from 0.70935
# Epoch 154/300
#  - 7s - loss: 0.7061 - categorical_accuracy: 0.7011 - val_loss: 0.6913 - val_categorical_accuracy: 0.7089
#
# Epoch 00154: val_categorical_accuracy did not improve from 0.70935
# Epoch 155/300
#  - 7s - loss: 0.7117 - categorical_accuracy: 0.6938 - val_loss: 0.6908 - val_categorical_accuracy: 0.7068
#
# Epoch 00155: val_categorical_accuracy did not improve from 0.70935
# Epoch 156/300
#  - 7s - loss: 0.7103 - categorical_accuracy: 0.6946 - val_loss: 0.6912 - val_categorical_accuracy: 0.7072
#
# Epoch 00156: val_categorical_accuracy did not improve from 0.70935
# Epoch 157/300
#  - 7s - loss: 0.7084 - categorical_accuracy: 0.6948 - val_loss: 0.6918 - val_categorical_accuracy: 0.7059
#
# Epoch 00157: val_categorical_accuracy did not improve from 0.70935
# Epoch 158/300
#  - 7s - loss: 0.7101 - categorical_accuracy: 0.6948 - val_loss: 0.6936 - val_categorical_accuracy: 0.7076
#
# Epoch 00158: val_categorical_accuracy did not improve from 0.70935
# Epoch 159/300
#  - 7s - loss: 0.7084 - categorical_accuracy: 0.7008 - val_loss: 0.6910 - val_categorical_accuracy: 0.7076
#
# Epoch 00159: val_categorical_accuracy did not improve from 0.70935
# Epoch 160/300
#  - 7s - loss: 0.7178 - categorical_accuracy: 0.6937 - val_loss: 0.6901 - val_categorical_accuracy: 0.7076
#
# Epoch 00160: val_categorical_accuracy did not improve from 0.70935
# Epoch 161/300
#  - 7s - loss: 0.7160 - categorical_accuracy: 0.6968 - val_loss: 0.6904 - val_categorical_accuracy: 0.7029
#
# Epoch 00161: val_categorical_accuracy did not improve from 0.70935
# Epoch 162/300
#  - 7s - loss: 0.7099 - categorical_accuracy: 0.7001 - val_loss: 0.6897 - val_categorical_accuracy: 0.7081
#
# Epoch 00162: val_categorical_accuracy did not improve from 0.70935
# Epoch 163/300
#  - 7s - loss: 0.7110 - categorical_accuracy: 0.6972 - val_loss: 0.6897 - val_categorical_accuracy: 0.7102
#
# Epoch 00163: val_categorical_accuracy improved from 0.70935 to 0.71020, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 164/300
#  - 7s - loss: 0.7114 - categorical_accuracy: 0.6915 - val_loss: 0.6893 - val_categorical_accuracy: 0.7098
#
# Epoch 00164: val_categorical_accuracy did not improve from 0.71020
# Epoch 165/300
#  - 7s - loss: 0.7136 - categorical_accuracy: 0.6971 - val_loss: 0.6903 - val_categorical_accuracy: 0.7068
#
# Epoch 00165: val_categorical_accuracy did not improve from 0.71020
# Epoch 166/300
#  - 7s - loss: 0.7102 - categorical_accuracy: 0.6953 - val_loss: 0.6893 - val_categorical_accuracy: 0.7093
#
# Epoch 00166: val_categorical_accuracy did not improve from 0.71020
# Epoch 167/300
#  - 8s - loss: 0.7116 - categorical_accuracy: 0.7022 - val_loss: 0.6895 - val_categorical_accuracy: 0.7093
#
# Epoch 00167: val_categorical_accuracy did not improve from 0.71020
# Epoch 168/300
#  - 7s - loss: 0.7088 - categorical_accuracy: 0.6988 - val_loss: 0.6894 - val_categorical_accuracy: 0.7064
#
# Epoch 00168: val_categorical_accuracy did not improve from 0.71020
# Epoch 169/300
#  - 7s - loss: 0.7105 - categorical_accuracy: 0.7011 - val_loss: 0.6897 - val_categorical_accuracy: 0.7068
#
# Epoch 00169: val_categorical_accuracy did not improve from 0.71020
# Epoch 170/300
#  - 7s - loss: 0.7053 - categorical_accuracy: 0.6957 - val_loss: 0.6892 - val_categorical_accuracy: 0.7068
#
# Epoch 00170: val_categorical_accuracy did not improve from 0.71020
# Epoch 171/300
#  - 7s - loss: 0.7050 - categorical_accuracy: 0.7027 - val_loss: 0.6880 - val_categorical_accuracy: 0.7106
#
# Epoch 00171: val_categorical_accuracy improved from 0.71020 to 0.71063, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 172/300
#  - 7s - loss: 0.7070 - categorical_accuracy: 0.6992 - val_loss: 0.6880 - val_categorical_accuracy: 0.7111
#
# Epoch 00172: val_categorical_accuracy improved from 0.71063 to 0.71105, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 173/300
#  - 7s - loss: 0.7054 - categorical_accuracy: 0.7004 - val_loss: 0.6885 - val_categorical_accuracy: 0.7047
#
# Epoch 00173: val_categorical_accuracy did not improve from 0.71105
# Epoch 174/300
#  - 7s - loss: 0.7132 - categorical_accuracy: 0.6984 - val_loss: 0.6887 - val_categorical_accuracy: 0.7102
#
# Epoch 00174: val_categorical_accuracy did not improve from 0.71105
# Epoch 175/300
#  - 7s - loss: 0.7113 - categorical_accuracy: 0.6996 - val_loss: 0.6881 - val_categorical_accuracy: 0.7098
#
# Epoch 00175: val_categorical_accuracy did not improve from 0.71105
# Epoch 176/300
#  - 7s - loss: 0.7131 - categorical_accuracy: 0.6948 - val_loss: 0.6894 - val_categorical_accuracy: 0.7132
#
# Epoch 00176: val_categorical_accuracy improved from 0.71105 to 0.71319, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 177/300
#  - 7s - loss: 0.7112 - categorical_accuracy: 0.6964 - val_loss: 0.6922 - val_categorical_accuracy: 0.7081
#
# Epoch 00177: val_categorical_accuracy did not improve from 0.71319
# Epoch 178/300
#  - 7s - loss: 0.7108 - categorical_accuracy: 0.6984 - val_loss: 0.6896 - val_categorical_accuracy: 0.7115
#
# Epoch 00178: val_categorical_accuracy did not improve from 0.71319
# Epoch 179/300
#  - 7s - loss: 0.7106 - categorical_accuracy: 0.6987 - val_loss: 0.6884 - val_categorical_accuracy: 0.7085
#
# Epoch 00179: val_categorical_accuracy did not improve from 0.71319
# Epoch 180/300
#  - 7s - loss: 0.7060 - categorical_accuracy: 0.6994 - val_loss: 0.6882 - val_categorical_accuracy: 0.7102
#
# Epoch 00180: val_categorical_accuracy did not improve from 0.71319
# Epoch 181/300
#  - 7s - loss: 0.7040 - categorical_accuracy: 0.6972 - val_loss: 0.6878 - val_categorical_accuracy: 0.7093
#
# Epoch 00181: val_categorical_accuracy did not improve from 0.71319
# Epoch 182/300
#  - 7s - loss: 0.7076 - categorical_accuracy: 0.6998 - val_loss: 0.6875 - val_categorical_accuracy: 0.7098
#
# Epoch 00182: val_categorical_accuracy did not improve from 0.71319
# Epoch 183/300
#  - 7s - loss: 0.7062 - categorical_accuracy: 0.7000 - val_loss: 0.6872 - val_categorical_accuracy: 0.7115
#
# Epoch 00183: val_categorical_accuracy did not improve from 0.71319
# Epoch 184/300
#  - 7s - loss: 0.7025 - categorical_accuracy: 0.6987 - val_loss: 0.6873 - val_categorical_accuracy: 0.7076
#
# Epoch 00184: val_categorical_accuracy did not improve from 0.71319
# Epoch 185/300
#  - 7s - loss: 0.7077 - categorical_accuracy: 0.6990 - val_loss: 0.6879 - val_categorical_accuracy: 0.7119
#
# Epoch 00185: val_categorical_accuracy did not improve from 0.71319
# Epoch 186/300
#  - 7s - loss: 0.7068 - categorical_accuracy: 0.6999 - val_loss: 0.6865 - val_categorical_accuracy: 0.7111
#
# Epoch 00186: val_categorical_accuracy did not improve from 0.71319
# Epoch 187/300
#  - 7s - loss: 0.7076 - categorical_accuracy: 0.6980 - val_loss: 0.6869 - val_categorical_accuracy: 0.7085
#
# Epoch 00187: val_categorical_accuracy did not improve from 0.71319
# Epoch 188/300
#  - 7s - loss: 0.7039 - categorical_accuracy: 0.7050 - val_loss: 0.6863 - val_categorical_accuracy: 0.7123
#
# Epoch 00188: val_categorical_accuracy did not improve from 0.71319
# Epoch 189/300
#  - 7s - loss: 0.7078 - categorical_accuracy: 0.7020 - val_loss: 0.6865 - val_categorical_accuracy: 0.7123
#
# Epoch 00189: val_categorical_accuracy did not improve from 0.71319
# Epoch 190/300
#  - 7s - loss: 0.7069 - categorical_accuracy: 0.6964 - val_loss: 0.6859 - val_categorical_accuracy: 0.7136
#
# Epoch 00190: val_categorical_accuracy improved from 0.71319 to 0.71362, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM1_model_basic_1hot_try.hdf5
# Epoch 191/300
#  - 7s - loss: 0.7050 - categorical_accuracy: 0.7001 - val_loss: 0.6866 - val_categorical_accuracy: 0.7106
#
# Epoch 00191: val_categorical_accuracy did not improve from 0.71362
# Epoch 192/300
#  - 7s - loss: 0.7082 - categorical_accuracy: 0.6975 - val_loss: 0.6864 - val_categorical_accuracy: 0.7111
#
# Epoch 00192: val_categorical_accuracy did not improve from 0.71362
# Epoch 193/300
#  - 7s - loss: 0.7045 - categorical_accuracy: 0.7032 - val_loss: 0.6863 - val_categorical_accuracy: 0.7098
#
# Epoch 00193: val_categorical_accuracy did not improve from 0.71362
# Epoch 194/300
#  - 7s - loss: 0.7134 - categorical_accuracy: 0.6983 - val_loss: 0.6865 - val_categorical_accuracy: 0.7128
#
# Epoch 00194: val_categorical_accuracy did not improve from 0.71362
# Epoch 195/300
#  - 7s - loss: 0.7049 - categorical_accuracy: 0.6996 - val_loss: 0.6877 - val_categorical_accuracy: 0.7076
#
# Epoch 00195: val_categorical_accuracy did not improve from 0.71362
# Epoch 196/300
#  - 7s - loss: 0.7022 - categorical_accuracy: 0.7023 - val_loss: 0.6858 - val_categorical_accuracy: 0.7123
#
# Epoch 00196: val_categorical_accuracy did not improve from 0.71362
# Epoch 197/300
#  - 7s - loss: 0.7094 - categorical_accuracy: 0.7014 - val_loss: 0.6863 - val_categorical_accuracy: 0.7132
#
# Epoch 00197: val_categorical_accuracy did not improve from 0.71362
# Epoch 198/300
#  - 7s - loss: 0.7045 - categorical_accuracy: 0.7007 - val_loss: 0.6856 - val_categorical_accuracy: 0.7115
#
# Epoch 00198: val_categorical_accuracy did not improve from 0.71362
# Epoch 199/300
#  - 7s - loss: 0.7095 - categorical_accuracy: 0.7004 - val_loss: 0.6858 - val_categorical_accuracy: 0.7132
#
# Epoch 00199: val_categorical_accuracy did not improve from 0.71362
# Epoch 200/300
#  - 7s - loss: 0.7038 - categorical_accuracy: 0.7007 - val_loss: 0.6855 - val_categorical_accuracy: 0.7119
#
# Epoch 00200: val_categorical_accuracy did not improve from 0.71362
# Epoch 201/300
#  - 7s - loss: 0.7025 - categorical_accuracy: 0.6968 - val_loss: 0.6856 - val_categorical_accuracy: 0.7123
#
# Epoch 00201: val_categorical_accuracy did not improve from 0.71362
# Epoch 202/300
#  - 7s - loss: 0.7041 - categorical_accuracy: 0.7021 - val_loss: 0.6857 - val_categorical_accuracy: 0.7128
#
# Epoch 00202: val_categorical_accuracy did not improve from 0.71362
# Epoch 203/300
#  - 7s - loss: 0.7028 - categorical_accuracy: 0.7035 - val_loss: 0.6857 - val_categorical_accuracy: 0.7132
#
# Epoch 00203: val_categorical_accuracy did not improve from 0.71362
# Epoch 204/300
#  - 7s - loss: 0.7042 - categorical_accuracy: 0.7021 - val_loss: 0.6858 - val_categorical_accuracy: 0.7128
#
# Epoch 00204: val_categorical_accuracy did not improve from 0.71362
# Epoch 205/300
#  - 7s - loss: 0.7008 - categorical_accuracy: 0.6995 - val_loss: 0.6857 - val_categorical_accuracy: 0.7123
#
# Epoch 00205: val_categorical_accuracy did not improve from 0.71362
# Epoch 206/300
#  - 7s - loss: 0.7024 - categorical_accuracy: 0.7001 - val_loss: 0.6857 - val_categorical_accuracy: 0.7128
#
# Epoch 00206: val_categorical_accuracy did not improve from 0.71362
# Epoch 207/300
#  - 7s - loss: 0.7018 - categorical_accuracy: 0.6998 - val_loss: 0.6858 - val_categorical_accuracy: 0.7136
#
# Epoch 00207: val_categorical_accuracy did not improve from 0.71362
# Epoch 208/300
#  - 7s - loss: 0.7076 - categorical_accuracy: 0.6976 - val_loss: 0.6859 - val_categorical_accuracy: 0.7128
#
# Epoch 00208: val_categorical_accuracy did not improve from 0.71362
# Epoch 209/300
#  - 7s - loss: 0.7064 - categorical_accuracy: 0.7006 - val_loss: 0.6856 - val_categorical_accuracy: 0.7132
#
# Epoch 00209: val_categorical_accuracy did not improve from 0.71362
# Epoch 210/300
#  - 7s - loss: 0.7017 - categorical_accuracy: 0.6986 - val_loss: 0.6856 - val_categorical_accuracy: 0.7123
#
# Epoch 00210: val_categorical_accuracy did not improve from 0.71362
# Epoch 211/300
#  - 7s - loss: 0.7037 - categorical_accuracy: 0.7009 - val_loss: 0.6858 - val_categorical_accuracy: 0.7128
#
# Epoch 00211: val_categorical_accuracy did not improve from 0.71362
# Epoch 212/300
#  - 7s - loss: 0.7007 - categorical_accuracy: 0.7062 - val_loss: 0.6855 - val_categorical_accuracy: 0.7132
#
# Epoch 00212: val_categorical_accuracy did not improve from 0.71362
# Epoch 213/300
#  - 7s - loss: 0.7012 - categorical_accuracy: 0.7000 - val_loss: 0.6855 - val_categorical_accuracy: 0.7132
#
# Epoch 00213: val_categorical_accuracy did not improve from 0.71362
# Epoch 214/300
#  - 7s - loss: 0.7042 - categorical_accuracy: 0.7038 - val_loss: 0.6855 - val_categorical_accuracy: 0.7123
#
# Epoch 00214: val_categorical_accuracy did not improve from 0.71362
# Epoch 215/300
#  - 7s - loss: 0.7073 - categorical_accuracy: 0.7009 - val_loss: 0.6855 - val_categorical_accuracy: 0.7132
#
# Epoch 00215: val_categorical_accuracy did not improve from 0.71362
# Epoch 216/300
#  - 7s - loss: 0.7034 - categorical_accuracy: 0.6978 - val_loss: 0.6855 - val_categorical_accuracy: 0.7132
#
# Epoch 00216: val_categorical_accuracy did not improve from 0.71362
# Epoch 217/300
#  - 7s - loss: 0.7047 - categorical_accuracy: 0.7050 - val_loss: 0.6856 - val_categorical_accuracy: 0.7123
#
# Epoch 00217: val_categorical_accuracy did not improve from 0.71362
# Epoch 218/300
#  - 7s - loss: 0.7062 - categorical_accuracy: 0.6994 - val_loss: 0.6854 - val_categorical_accuracy: 0.7128
#
# Epoch 00218: val_categorical_accuracy did not improve from 0.71362
# Epoch 219/300
#  - 7s - loss: 0.6999 - categorical_accuracy: 0.7063 - val_loss: 0.6856 - val_categorical_accuracy: 0.7123
#
# Epoch 00219: val_categorical_accuracy did not improve from 0.71362
# Epoch 220/300
#  - 7s - loss: 0.6992 - categorical_accuracy: 0.7031 - val_loss: 0.6856 - val_categorical_accuracy: 0.7123
#
# Epoch 00220: val_categorical_accuracy did not improve from 0.71362
# Epoch 221/300
#  - 7s - loss: 0.7032 - categorical_accuracy: 0.7049 - val_loss: 0.6855 - val_categorical_accuracy: 0.7128
#
# Epoch 00221: val_categorical_accuracy did not improve from 0.71362
# Epoch 222/300
#  - 7s - loss: 0.7008 - categorical_accuracy: 0.7021 - val_loss: 0.6855 - val_categorical_accuracy: 0.7123
#
# Epoch 00222: val_categorical_accuracy did not improve from 0.71362
# Epoch 223/300
#  - 7s - loss: 0.7013 - categorical_accuracy: 0.6999 - val_loss: 0.6855 - val_categorical_accuracy: 0.7123
#
# Epoch 00223: val_categorical_accuracy did not improve from 0.71362
# Epoch 224/300
#  - 7s - loss: 0.7033 - categorical_accuracy: 0.7010 - val_loss: 0.6855 - val_categorical_accuracy: 0.7119
#
# Epoch 00224: val_categorical_accuracy did not improve from 0.71362
# Epoch 225/300
#  - 7s - loss: 0.7079 - categorical_accuracy: 0.7000 - val_loss: 0.6857 - val_categorical_accuracy: 0.7106
#
# Epoch 00225: val_categorical_accuracy did not improve from 0.71362
# Epoch 226/300
#  - 7s - loss: 0.7013 - categorical_accuracy: 0.7020 - val_loss: 0.6856 - val_categorical_accuracy: 0.7123
#
# Epoch 00226: val_categorical_accuracy did not improve from 0.71362
# Epoch 227/300
#  - 7s - loss: 0.7031 - categorical_accuracy: 0.7017 - val_loss: 0.6854 - val_categorical_accuracy: 0.7128
#
# Epoch 00227: val_categorical_accuracy did not improve from 0.71362
# Epoch 228/300
#  - 7s - loss: 0.7011 - categorical_accuracy: 0.7012 - val_loss: 0.6853 - val_categorical_accuracy: 0.7136
#
# Epoch 00228: val_categorical_accuracy did not improve from 0.71362
# Epoch 229/300
#  - 7s - loss: 0.7049 - categorical_accuracy: 0.7034 - val_loss: 0.6854 - val_categorical_accuracy: 0.7132
#
# Epoch 00229: val_categorical_accuracy did not improve from 0.71362
# Epoch 230/300
#  - 7s - loss: 0.7063 - categorical_accuracy: 0.6951 - val_loss: 0.6854 - val_categorical_accuracy: 0.7128
#
# Epoch 00230: val_categorical_accuracy did not improve from 0.71362
# Epoch 231/300
#  - 7s - loss: 0.7071 - categorical_accuracy: 0.7066 - val_loss: 0.6853 - val_categorical_accuracy: 0.7132
#
# Epoch 00231: val_categorical_accuracy did not improve from 0.71362
# Epoch 232/300
#  - 7s - loss: 0.7008 - categorical_accuracy: 0.7031 - val_loss: 0.6854 - val_categorical_accuracy: 0.7132
#
# Epoch 00232: val_categorical_accuracy did not improve from 0.71362
# Epoch 233/300
#  - 7s - loss: 0.7053 - categorical_accuracy: 0.6990 - val_loss: 0.6854 - val_categorical_accuracy: 0.7132
#
# Epoch 00233: val_categorical_accuracy did not improve from 0.71362
# Epoch 234/300
#  - 7s - loss: 0.7029 - categorical_accuracy: 0.7015 - val_loss: 0.6853 - val_categorical_accuracy: 0.7128
#
# Epoch 00234: val_categorical_accuracy did not improve from 0.71362
# Epoch 235/300
#  - 7s - loss: 0.7067 - categorical_accuracy: 0.7041 - val_loss: 0.6853 - val_categorical_accuracy: 0.7132
#
# Epoch 00235: val_categorical_accuracy did not improve from 0.71362
# Epoch 236/300
#  - 7s - loss: 0.7045 - categorical_accuracy: 0.7000 - val_loss: 0.6853 - val_categorical_accuracy: 0.7132
#
# Epoch 00236: val_categorical_accuracy did not improve from 0.71362
# Epoch 237/300
#  - 7s - loss: 0.7019 - categorical_accuracy: 0.6988 - val_loss: 0.6854 - val_categorical_accuracy: 0.7128
#
# Epoch 00237: val_categorical_accuracy did not improve from 0.71362
# Epoch 238/300
#  - 7s - loss: 0.7057 - categorical_accuracy: 0.6986 - val_loss: 0.6853 - val_categorical_accuracy: 0.7132
#
# Epoch 00238: val_categorical_accuracy did not improve from 0.71362
# Epoch 239/300
#  - 7s - loss: 0.7027 - categorical_accuracy: 0.6999 - val_loss: 0.6858 - val_categorical_accuracy: 0.7119
#
# Epoch 00239: val_categorical_accuracy did not improve from 0.71362
# Epoch 240/300
#  - 7s - loss: 0.7036 - categorical_accuracy: 0.7043 - val_loss: 0.6853 - val_categorical_accuracy: 0.7128
#
# Epoch 00240: val_categorical_accuracy did not improve from 0.71362
# Epoch 241/300
#  - 7s - loss: 0.7065 - categorical_accuracy: 0.7012 - val_loss: 0.6853 - val_categorical_accuracy: 0.7123
#
# Epoch 00241: val_categorical_accuracy did not improve from 0.71362
# Epoch 242/300
#  - 7s - loss: 0.7007 - categorical_accuracy: 0.7005 - val_loss: 0.6853 - val_categorical_accuracy: 0.7132
#
# Epoch 00242: val_categorical_accuracy did not improve from 0.71362
# Epoch 243/300
#  - 7s - loss: 0.7010 - categorical_accuracy: 0.7032 - val_loss: 0.6852 - val_categorical_accuracy: 0.7132
#
# Epoch 00243: val_categorical_accuracy did not improve from 0.71362
# Epoch 244/300
#  - 7s - loss: 0.7099 - categorical_accuracy: 0.6944 - val_loss: 0.6853 - val_categorical_accuracy: 0.7123
#
# Epoch 00244: val_categorical_accuracy did not improve from 0.71362
# Epoch 245/300
#  - 7s - loss: 0.7000 - categorical_accuracy: 0.7003 - val_loss: 0.6851 - val_categorical_accuracy: 0.7123
#
# Epoch 00245: val_categorical_accuracy did not improve from 0.71362
# Epoch 246/300
#  - 8s - loss: 0.7044 - categorical_accuracy: 0.6974 - val_loss: 0.6852 - val_categorical_accuracy: 0.7132
#
# Epoch 00246: val_categorical_accuracy did not improve from 0.71362
# Epoch 247/300
#  - 7s - loss: 0.7025 - categorical_accuracy: 0.6989 - val_loss: 0.6852 - val_categorical_accuracy: 0.7132
#
# Epoch 00247: val_categorical_accuracy did not improve from 0.71362
# Epoch 248/300
#  - 7s - loss: 0.7046 - categorical_accuracy: 0.6982 - val_loss: 0.6853 - val_categorical_accuracy: 0.7123
#
# Epoch 00248: val_categorical_accuracy did not improve from 0.71362
# Epoch 249/300
#  - 7s - loss: 0.7054 - categorical_accuracy: 0.7034 - val_loss: 0.6853 - val_categorical_accuracy: 0.7123
#
# Epoch 00249: val_categorical_accuracy did not improve from 0.71362
# Epoch 250/300
#  - 7s - loss: 0.7084 - categorical_accuracy: 0.7010 - val_loss: 0.6852 - val_categorical_accuracy: 0.7123
#
# Epoch 00250: val_categorical_accuracy did not improve from 0.71362
# Epoch 251/300
#  - 7s - loss: 0.6999 - categorical_accuracy: 0.7067 - val_loss: 0.6852 - val_categorical_accuracy: 0.7123
#
# Epoch 00251: val_categorical_accuracy did not improve from 0.71362
# Epoch 252/300
#  - 7s - loss: 0.7074 - categorical_accuracy: 0.7023 - val_loss: 0.6852 - val_categorical_accuracy: 0.7123
#
# Epoch 00252: val_categorical_accuracy did not improve from 0.71362
# Epoch 253/300
#  - 7s - loss: 0.7011 - categorical_accuracy: 0.7011 - val_loss: 0.6854 - val_categorical_accuracy: 0.7136
#
# Epoch 00253: val_categorical_accuracy did not improve from 0.71362
# Epoch 254/300
#  - 7s - loss: 0.7002 - categorical_accuracy: 0.7012 - val_loss: 0.6853 - val_categorical_accuracy: 0.7119
#
# Epoch 00254: val_categorical_accuracy did not improve from 0.71362
# Epoch 255/300
#  - 7s - loss: 0.7030 - categorical_accuracy: 0.7004 - val_loss: 0.6851 - val_categorical_accuracy: 0.7132
#
# Epoch 00255: val_categorical_accuracy did not improve from 0.71362
# Epoch 256/300
#  - 7s - loss: 0.7043 - categorical_accuracy: 0.7025 - val_loss: 0.6851 - val_categorical_accuracy: 0.7128
#
# Epoch 00256: val_categorical_accuracy did not improve from 0.71362
# Epoch 257/300
#  - 7s - loss: 0.7007 - categorical_accuracy: 0.7072 - val_loss: 0.6852 - val_categorical_accuracy: 0.7128
#
# Epoch 00257: val_categorical_accuracy did not improve from 0.71362
# Epoch 258/300
#  - 7s - loss: 0.7019 - categorical_accuracy: 0.7036 - val_loss: 0.6850 - val_categorical_accuracy: 0.7132
#
# Epoch 00258: val_categorical_accuracy did not improve from 0.71362
# Epoch 259/300
#  - 7s - loss: 0.7055 - categorical_accuracy: 0.7051 - val_loss: 0.6851 - val_categorical_accuracy: 0.7123
#
# Epoch 00259: val_categorical_accuracy did not improve from 0.71362
# Epoch 260/300
#  - 7s - loss: 0.7062 - categorical_accuracy: 0.7008 - val_loss: 0.6851 - val_categorical_accuracy: 0.7128
#
# Epoch 00260: val_categorical_accuracy did not improve from 0.71362
# Epoch 261/300
#  - 7s - loss: 0.7069 - categorical_accuracy: 0.6977 - val_loss: 0.6851 - val_categorical_accuracy: 0.7128
#
# Epoch 00261: val_categorical_accuracy did not improve from 0.71362
# Epoch 262/300
#  - 7s - loss: 0.7056 - categorical_accuracy: 0.7027 - val_loss: 0.6852 - val_categorical_accuracy: 0.7128
#
# Epoch 00262: val_categorical_accuracy did not improve from 0.71362
# Epoch 263/300
#  - 7s - loss: 0.7015 - categorical_accuracy: 0.7040 - val_loss: 0.6852 - val_categorical_accuracy: 0.7128
#
# Epoch 00263: val_categorical_accuracy did not improve from 0.71362
# Epoch 264/300
#  - 7s - loss: 0.7037 - categorical_accuracy: 0.7049 - val_loss: 0.6852 - val_categorical_accuracy: 0.7123
#
# Epoch 00264: val_categorical_accuracy did not improve from 0.71362
# Epoch 265/300
#  - 7s - loss: 0.6969 - categorical_accuracy: 0.7100 - val_loss: 0.6850 - val_categorical_accuracy: 0.7132
#
# Epoch 00265: val_categorical_accuracy did not improve from 0.71362
# Epoch 266/300
#  - 7s - loss: 0.7024 - categorical_accuracy: 0.7045 - val_loss: 0.6850 - val_categorical_accuracy: 0.7132
#
# Epoch 00266: val_categorical_accuracy did not improve from 0.71362
# Epoch 267/300
#  - 7s - loss: 0.7039 - categorical_accuracy: 0.7042 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00267: val_categorical_accuracy did not improve from 0.71362
# Epoch 268/300
#  - 7s - loss: 0.7041 - categorical_accuracy: 0.7006 - val_loss: 0.6849 - val_categorical_accuracy: 0.7132
#
# Epoch 00268: val_categorical_accuracy did not improve from 0.71362
# Epoch 269/300
#  - 7s - loss: 0.7058 - categorical_accuracy: 0.7003 - val_loss: 0.6850 - val_categorical_accuracy: 0.7128
#
# Epoch 00269: val_categorical_accuracy did not improve from 0.71362
# Epoch 270/300
#  - 7s - loss: 0.7036 - categorical_accuracy: 0.6986 - val_loss: 0.6850 - val_categorical_accuracy: 0.7132
#
# Epoch 00270: val_categorical_accuracy did not improve from 0.71362
# Epoch 271/300
#  - 7s - loss: 0.7065 - categorical_accuracy: 0.7000 - val_loss: 0.6851 - val_categorical_accuracy: 0.7123
#
# Epoch 00271: val_categorical_accuracy did not improve from 0.71362
# Epoch 272/300
#  - 7s - loss: 0.7044 - categorical_accuracy: 0.7012 - val_loss: 0.6851 - val_categorical_accuracy: 0.7132
#
# Epoch 00272: val_categorical_accuracy did not improve from 0.71362
# Epoch 273/300
#  - 7s - loss: 0.7021 - categorical_accuracy: 0.7000 - val_loss: 0.6851 - val_categorical_accuracy: 0.7128
#
# Epoch 00273: val_categorical_accuracy did not improve from 0.71362
# Epoch 274/300
#  - 7s - loss: 0.7093 - categorical_accuracy: 0.7009 - val_loss: 0.6850 - val_categorical_accuracy: 0.7123
#
# Epoch 00274: val_categorical_accuracy did not improve from 0.71362
# Epoch 275/300
#  - 7s - loss: 0.7024 - categorical_accuracy: 0.7040 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00275: val_categorical_accuracy did not improve from 0.71362
# Epoch 276/300
#  - 7s - loss: 0.7046 - categorical_accuracy: 0.7063 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00276: val_categorical_accuracy did not improve from 0.71362
# Epoch 277/300
#  - 8s - loss: 0.7021 - categorical_accuracy: 0.7002 - val_loss: 0.6850 - val_categorical_accuracy: 0.7128
#
# Epoch 00277: val_categorical_accuracy did not improve from 0.71362
# Epoch 278/300
#  - 7s - loss: 0.7040 - categorical_accuracy: 0.7019 - val_loss: 0.6850 - val_categorical_accuracy: 0.7128
#
# Epoch 00278: val_categorical_accuracy did not improve from 0.71362
# Epoch 279/300
#  - 7s - loss: 0.7034 - categorical_accuracy: 0.7053 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00279: val_categorical_accuracy did not improve from 0.71362
# Epoch 280/300
#  - 7s - loss: 0.7009 - categorical_accuracy: 0.7037 - val_loss: 0.6850 - val_categorical_accuracy: 0.7123
#
# Epoch 00280: val_categorical_accuracy did not improve from 0.71362
# Epoch 281/300
#  - 7s - loss: 0.7065 - categorical_accuracy: 0.6999 - val_loss: 0.6850 - val_categorical_accuracy: 0.7123
#
# Epoch 00281: val_categorical_accuracy did not improve from 0.71362
# Epoch 282/300
#  - 7s - loss: 0.7035 - categorical_accuracy: 0.6990 - val_loss: 0.6850 - val_categorical_accuracy: 0.7123
#
# Epoch 00282: val_categorical_accuracy did not improve from 0.71362
# Epoch 283/300
#  - 7s - loss: 0.7025 - categorical_accuracy: 0.7004 - val_loss: 0.6850 - val_categorical_accuracy: 0.7128
#
# Epoch 00283: val_categorical_accuracy did not improve from 0.71362
# Epoch 284/300
#  - 7s - loss: 0.7007 - categorical_accuracy: 0.7047 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00284: val_categorical_accuracy did not improve from 0.71362
# Epoch 285/300
#  - 7s - loss: 0.7056 - categorical_accuracy: 0.7024 - val_loss: 0.6848 - val_categorical_accuracy: 0.7132
#
# Epoch 00285: val_categorical_accuracy did not improve from 0.71362
# Epoch 286/300
#  - 7s - loss: 0.7066 - categorical_accuracy: 0.7012 - val_loss: 0.6849 - val_categorical_accuracy: 0.7123
#
# Epoch 00286: val_categorical_accuracy did not improve from 0.71362
# Epoch 287/300
#  - 7s - loss: 0.7075 - categorical_accuracy: 0.7054 - val_loss: 0.6850 - val_categorical_accuracy: 0.7123
#
# Epoch 00287: val_categorical_accuracy did not improve from 0.71362
# Epoch 288/300
#  - 7s - loss: 0.6953 - categorical_accuracy: 0.7018 - val_loss: 0.6850 - val_categorical_accuracy: 0.7128
#
# Epoch 00288: val_categorical_accuracy did not improve from 0.71362
# Epoch 289/300
#  - 7s - loss: 0.7019 - categorical_accuracy: 0.6980 - val_loss: 0.6849 - val_categorical_accuracy: 0.7132
#
# Epoch 00289: val_categorical_accuracy did not improve from 0.71362
# Epoch 290/300
#  - 7s - loss: 0.7058 - categorical_accuracy: 0.6952 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00290: val_categorical_accuracy did not improve from 0.71362
# Epoch 291/300
#  - 7s - loss: 0.7079 - categorical_accuracy: 0.7011 - val_loss: 0.6848 - val_categorical_accuracy: 0.7132
#
# Epoch 00291: val_categorical_accuracy did not improve from 0.71362
# Epoch 292/300
#  - 7s - loss: 0.7021 - categorical_accuracy: 0.7033 - val_loss: 0.6850 - val_categorical_accuracy: 0.7128
#
# Epoch 00292: val_categorical_accuracy did not improve from 0.71362
# Epoch 293/300
#  - 8s - loss: 0.7049 - categorical_accuracy: 0.7015 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00293: val_categorical_accuracy did not improve from 0.71362
# Epoch 294/300
#  - 7s - loss: 0.7074 - categorical_accuracy: 0.7016 - val_loss: 0.6848 - val_categorical_accuracy: 0.7132
#
# Epoch 00294: val_categorical_accuracy did not improve from 0.71362
# Epoch 295/300
#  - 7s - loss: 0.7019 - categorical_accuracy: 0.7031 - val_loss: 0.6848 - val_categorical_accuracy: 0.7132
#
# Epoch 00295: val_categorical_accuracy did not improve from 0.71362
# Epoch 296/300
#  - 7s - loss: 0.7050 - categorical_accuracy: 0.7008 - val_loss: 0.6849 - val_categorical_accuracy: 0.7132
#
# Epoch 00296: val_categorical_accuracy did not improve from 0.71362
# Epoch 297/300
#  - 7s - loss: 0.7013 - categorical_accuracy: 0.7045 - val_loss: 0.6849 - val_categorical_accuracy: 0.7132
#
# Epoch 00297: val_categorical_accuracy did not improve from 0.71362
# Epoch 298/300
#  - 8s - loss: 0.7000 - categorical_accuracy: 0.7042 - val_loss: 0.6849 - val_categorical_accuracy: 0.7128
#
# Epoch 00298: val_categorical_accuracy did not improve from 0.71362
# Epoch 299/300
#  - 7s - loss: 0.7038 - categorical_accuracy: 0.7018 - val_loss: 0.6850 - val_categorical_accuracy: 0.7128
#
# Epoch 00299: val_categorical_accuracy did not improve from 0.71362
# Epoch 300/300
#  - 7s - loss: 0.6991 - categorical_accuracy: 0.7047 - val_loss: 0.6848 - val_categorical_accuracy: 0.7132
#
# Epoch 00300: val_categorical_accuracy did not improve from 0.71362

# %%
loss = model_basic_1hot_trained.history['loss']
val_loss = model_basic_1hot_trained.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = model_basic_1hot_trained.history['categorical_accuracy']
val_acc = model_basic_1hot_trained.history['val_categorical_accuracy']
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# The model learns very slowly and reached it ceiling at 71.32% for validation set. I will use now Embeddings layer instead of 1-hot encoding to see if it can improve the score.

# %% [markdown]
# ## Model 2 - LSTM based on self generated embeddings

# %%
model_basic_enc = Sequential()
model_basic_enc.add(Embedding(8209, 300, input_length=22))
model_basic_enc.add(Dropout(0.3))
model_basic_enc.add(CuDNNLSTM(100, return_sequences=False))
model_basic_enc.add(Dropout(0.2))
model_basic_enc.add(Dense(3, activation='softmax'))
optimizer = RMSprop(lr=0.0001)
model_basic_enc.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])

print(model_basic_enc.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 22, 300)           2462700
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 22, 300)           0
# _________________________________________________________________
# cu_dnnlstm_16 (CuDNNLSTM)    (None, 100)               160800
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 2,623,803
# Trainable params: 2,623,803
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def scheduler(epoch):
    if epoch == 30:
        K.set_value(model_basic_enc.optimizer.lr, .00001)
    if epoch == 200:
        K.set_value(model_basic_enc.optimizer.lr, .000001)
    return K.get_value(model_basic_enc.optimizer.lr)

print('Train...')


checkpoint = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5', monitor="val_categorical_accuracy", save_best_only=True, mode='max', verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", mode='min', verbose=1, patience=50)
change_lr = LearningRateScheduler(scheduler)
callbacks_list = [checkpoint, early_stopping, change_lr]

model_basic_enc_trained=model_basic_enc.fit(trainX_DL, 
                                            trainY_DL, 
                                            batch_size=16, 
                                            callbacks=callbacks_list,                      
                                            epochs=500, 
                                            validation_data=(valX_DL, valY_DL), 
                                            verbose=2)
# Out:
# Train...
# Train on 9369 samples, validate on 2343 samples
# Epoch 1/500
#  - 8s - loss: 0.8612 - categorical_accuracy: 0.6366 - val_loss: 0.7800 - val_categorical_accuracy: 0.6603
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.66026, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 2/500
#  - 6s - loss: 0.7320 - categorical_accuracy: 0.6708 - val_loss: 0.6841 - val_categorical_accuracy: 0.7102
#
# Epoch 00002: val_categorical_accuracy improved from 0.66026 to 0.71020, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 3/500
#  - 6s - loss: 0.6523 - categorical_accuracy: 0.7267 - val_loss: 0.6248 - val_categorical_accuracy: 0.7388
#
# Epoch 00003: val_categorical_accuracy improved from 0.71020 to 0.73880, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 4/500
#  - 6s - loss: 0.5984 - categorical_accuracy: 0.7543 - val_loss: 0.5903 - val_categorical_accuracy: 0.7576
#
# Epoch 00004: val_categorical_accuracy improved from 0.73880 to 0.75758, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 5/500
#  - 6s - loss: 0.5657 - categorical_accuracy: 0.7672 - val_loss: 0.6124 - val_categorical_accuracy: 0.7486
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.75758
# Epoch 6/500
#  - 6s - loss: 0.5415 - categorical_accuracy: 0.7815 - val_loss: 0.5561 - val_categorical_accuracy: 0.7751
#
# Epoch 00006: val_categorical_accuracy improved from 0.75758 to 0.77507, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 7/500
#  - 6s - loss: 0.5216 - categorical_accuracy: 0.7953 - val_loss: 0.5502 - val_categorical_accuracy: 0.7798
#
# Epoch 00007: val_categorical_accuracy improved from 0.77507 to 0.77977, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 8/500
#  - 6s - loss: 0.5050 - categorical_accuracy: 0.7997 - val_loss: 0.5373 - val_categorical_accuracy: 0.7828
#
# Epoch 00008: val_categorical_accuracy improved from 0.77977 to 0.78276, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 9/500
#  - 6s - loss: 0.4907 - categorical_accuracy: 0.8061 - val_loss: 0.5449 - val_categorical_accuracy: 0.7810
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.78276
# Epoch 10/500
#  - 6s - loss: 0.4817 - categorical_accuracy: 0.8123 - val_loss: 0.5286 - val_categorical_accuracy: 0.7870
#
# Epoch 00010: val_categorical_accuracy improved from 0.78276 to 0.78703, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 11/500
#  - 6s - loss: 0.4717 - categorical_accuracy: 0.8135 - val_loss: 0.5298 - val_categorical_accuracy: 0.7896
#
# Epoch 00011: val_categorical_accuracy improved from 0.78703 to 0.78959, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 12/500
#  - 6s - loss: 0.4583 - categorical_accuracy: 0.8187 - val_loss: 0.5309 - val_categorical_accuracy: 0.7887
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.78959
# Epoch 13/500
#  - 6s - loss: 0.4531 - categorical_accuracy: 0.8262 - val_loss: 0.5227 - val_categorical_accuracy: 0.7921
#
# Epoch 00013: val_categorical_accuracy improved from 0.78959 to 0.79215, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 14/500
#  - 6s - loss: 0.4440 - categorical_accuracy: 0.8245 - val_loss: 0.5196 - val_categorical_accuracy: 0.7951
#
# Epoch 00014: val_categorical_accuracy improved from 0.79215 to 0.79513, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 15/500
#  - 6s - loss: 0.4356 - categorical_accuracy: 0.8322 - val_loss: 0.5270 - val_categorical_accuracy: 0.7917
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.79513
# Epoch 16/500
#  - 6s - loss: 0.4264 - categorical_accuracy: 0.8369 - val_loss: 0.5247 - val_categorical_accuracy: 0.7892
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.79513
# Epoch 17/500
#  - 6s - loss: 0.4222 - categorical_accuracy: 0.8374 - val_loss: 0.5254 - val_categorical_accuracy: 0.7968
#
# Epoch 00017: val_categorical_accuracy improved from 0.79513 to 0.79684, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 18/500
#  - 6s - loss: 0.4151 - categorical_accuracy: 0.8424 - val_loss: 0.5290 - val_categorical_accuracy: 0.7943
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.79684
# Epoch 19/500
#  - 6s - loss: 0.4101 - categorical_accuracy: 0.8443 - val_loss: 0.5334 - val_categorical_accuracy: 0.7917
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.79684
# Epoch 20/500
#  - 6s - loss: 0.4023 - categorical_accuracy: 0.8440 - val_loss: 0.5327 - val_categorical_accuracy: 0.7934
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.79684
# Epoch 21/500
#  - 6s - loss: 0.3960 - categorical_accuracy: 0.8500 - val_loss: 0.5441 - val_categorical_accuracy: 0.7973
#
# Epoch 00021: val_categorical_accuracy improved from 0.79684 to 0.79727, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 22/500
#  - 6s - loss: 0.3891 - categorical_accuracy: 0.8544 - val_loss: 0.5358 - val_categorical_accuracy: 0.7900
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.79727
# Epoch 23/500
#  - 6s - loss: 0.3834 - categorical_accuracy: 0.8570 - val_loss: 0.5229 - val_categorical_accuracy: 0.7977
#
# Epoch 00023: val_categorical_accuracy improved from 0.79727 to 0.79770, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 24/500
#  - 6s - loss: 0.3806 - categorical_accuracy: 0.8537 - val_loss: 0.5492 - val_categorical_accuracy: 0.7981
#
# Epoch 00024: val_categorical_accuracy improved from 0.79770 to 0.79812, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM2-embeddings.hdf5
# Epoch 25/500
#  - 6s - loss: 0.3727 - categorical_accuracy: 0.8608 - val_loss: 0.5395 - val_categorical_accuracy: 0.7934
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.79812
# Epoch 26/500
#  - 6s - loss: 0.3678 - categorical_accuracy: 0.8585 - val_loss: 0.5420 - val_categorical_accuracy: 0.7960
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.79812
# Epoch 27/500
#  - 6s - loss: 0.3632 - categorical_accuracy: 0.8634 - val_loss: 0.5552 - val_categorical_accuracy: 0.7840
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.79812
# Epoch 28/500
#  - 6s - loss: 0.3556 - categorical_accuracy: 0.8665 - val_loss: 0.5340 - val_categorical_accuracy: 0.7909
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.79812
# Epoch 29/500
#  - 6s - loss: 0.3480 - categorical_accuracy: 0.8680 - val_loss: 0.5410 - val_categorical_accuracy: 0.7879
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.79812
# Epoch 30/500
#  - 6s - loss: 0.3470 - categorical_accuracy: 0.8686 - val_loss: 0.5410 - val_categorical_accuracy: 0.7875
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.79812
# Epoch 31/500
#  - 6s - loss: 0.3291 - categorical_accuracy: 0.8768 - val_loss: 0.5496 - val_categorical_accuracy: 0.7939
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.79812
# Epoch 32/500
#  - 6s - loss: 0.3302 - categorical_accuracy: 0.8771 - val_loss: 0.5503 - val_categorical_accuracy: 0.7909
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.79812
# Epoch 33/500
#  - 6s - loss: 0.3325 - categorical_accuracy: 0.8755 - val_loss: 0.5509 - val_categorical_accuracy: 0.7930
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.79812
# Epoch 34/500
#  - 6s - loss: 0.3263 - categorical_accuracy: 0.8796 - val_loss: 0.5582 - val_categorical_accuracy: 0.7930
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.79812
# Epoch 35/500
#  - 6s - loss: 0.3236 - categorical_accuracy: 0.8749 - val_loss: 0.5612 - val_categorical_accuracy: 0.7853
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.79812
# Epoch 36/500
#  - 6s - loss: 0.3260 - categorical_accuracy: 0.8771 - val_loss: 0.5568 - val_categorical_accuracy: 0.7926
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.79812
# Epoch 37/500
#  - 6s - loss: 0.3238 - categorical_accuracy: 0.8776 - val_loss: 0.5551 - val_categorical_accuracy: 0.7904
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.79812
# Epoch 38/500
#  - 6s - loss: 0.3252 - categorical_accuracy: 0.8775 - val_loss: 0.5530 - val_categorical_accuracy: 0.7904
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.79812
# Epoch 39/500
#  - 6s - loss: 0.3235 - categorical_accuracy: 0.8794 - val_loss: 0.5517 - val_categorical_accuracy: 0.7879
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.79812
# Epoch 40/500
#  - 6s - loss: 0.3232 - categorical_accuracy: 0.8760 - val_loss: 0.5544 - val_categorical_accuracy: 0.7896
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.79812
# Epoch 41/500
#  - 6s - loss: 0.3242 - categorical_accuracy: 0.8786 - val_loss: 0.5617 - val_categorical_accuracy: 0.7913
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.79812
# Epoch 42/500
#  - 6s - loss: 0.3237 - categorical_accuracy: 0.8775 - val_loss: 0.5512 - val_categorical_accuracy: 0.7951
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.79812
# Epoch 43/500
#  - 6s - loss: 0.3209 - categorical_accuracy: 0.8808 - val_loss: 0.5604 - val_categorical_accuracy: 0.7904
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.79812
# Epoch 44/500
#  - 6s - loss: 0.3204 - categorical_accuracy: 0.8798 - val_loss: 0.5621 - val_categorical_accuracy: 0.7913
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.79812
# Epoch 45/500
#  - 6s - loss: 0.3233 - categorical_accuracy: 0.8786 - val_loss: 0.5566 - val_categorical_accuracy: 0.7909
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.79812
# Epoch 46/500
#  - 6s - loss: 0.3210 - categorical_accuracy: 0.8791 - val_loss: 0.5600 - val_categorical_accuracy: 0.7921
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.79812
# Epoch 47/500
#  - 6s - loss: 0.3195 - categorical_accuracy: 0.8789 - val_loss: 0.5597 - val_categorical_accuracy: 0.7904
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.79812
# Epoch 48/500
#  - 6s - loss: 0.3175 - categorical_accuracy: 0.8804 - val_loss: 0.5593 - val_categorical_accuracy: 0.7909
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.79812
# Epoch 49/500
#  - 6s - loss: 0.3189 - categorical_accuracy: 0.8807 - val_loss: 0.5627 - val_categorical_accuracy: 0.7892
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.79812
# Epoch 50/500
#  - 6s - loss: 0.3185 - categorical_accuracy: 0.8823 - val_loss: 0.5644 - val_categorical_accuracy: 0.7883
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.79812
# Epoch 51/500
#  - 6s - loss: 0.3177 - categorical_accuracy: 0.8795 - val_loss: 0.5552 - val_categorical_accuracy: 0.7900
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.79812
# Epoch 52/500
#  - 6s - loss: 0.3205 - categorical_accuracy: 0.8790 - val_loss: 0.5657 - val_categorical_accuracy: 0.7879
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.79812
# Epoch 53/500
#  - 6s - loss: 0.3136 - categorical_accuracy: 0.8815 - val_loss: 0.5654 - val_categorical_accuracy: 0.7909
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.79812
# Epoch 54/500
#  - 6s - loss: 0.3163 - categorical_accuracy: 0.8821 - val_loss: 0.5601 - val_categorical_accuracy: 0.7926
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.79812
# Epoch 55/500
#  - 6s - loss: 0.3156 - categorical_accuracy: 0.8813 - val_loss: 0.5644 - val_categorical_accuracy: 0.7904
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.79812
# Epoch 56/500
#  - 6s - loss: 0.3131 - categorical_accuracy: 0.8832 - val_loss: 0.5675 - val_categorical_accuracy: 0.7930
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.79812
# Epoch 57/500
#  - 6s - loss: 0.3106 - categorical_accuracy: 0.8850 - val_loss: 0.5681 - val_categorical_accuracy: 0.7875
#
# Epoch 00057: val_categorical_accuracy did not improve from 0.79812
# Epoch 58/500
#  - 6s - loss: 0.3134 - categorical_accuracy: 0.8830 - val_loss: 0.5621 - val_categorical_accuracy: 0.7892
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.79812
# Epoch 59/500
#  - 6s - loss: 0.3112 - categorical_accuracy: 0.8853 - val_loss: 0.5619 - val_categorical_accuracy: 0.7947
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.79812
# Epoch 60/500
#  - 6s - loss: 0.3143 - categorical_accuracy: 0.8840 - val_loss: 0.5641 - val_categorical_accuracy: 0.7960
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.79812
# Epoch 61/500
#  - 6s - loss: 0.3138 - categorical_accuracy: 0.8824 - val_loss: 0.5679 - val_categorical_accuracy: 0.7943
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.79812
# Epoch 62/500
#  - 6s - loss: 0.3121 - categorical_accuracy: 0.8852 - val_loss: 0.5689 - val_categorical_accuracy: 0.7909
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.79812
# Epoch 63/500
#  - 6s - loss: 0.3051 - categorical_accuracy: 0.8847 - val_loss: 0.5801 - val_categorical_accuracy: 0.7875
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.79812
# Epoch 64/500
#  - 6s - loss: 0.3106 - categorical_accuracy: 0.8847 - val_loss: 0.5660 - val_categorical_accuracy: 0.7917
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.79812
# Epoch 00064: early stopping

# %%
loss = model_basic_enc_trained.history['loss']
val_loss = model_basic_enc_trained.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = model_basic_enc_trained.history['categorical_accuracy']
val_acc = model_basic_enc_trained.history['val_categorical_accuracy']
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# The LSTM trained using embeddings improved in comparison to first 1-hot encoded LSTM model.
# The validation accuracy equals now 79.81%. This model however strongly overfits to training, using different dropout, LSTM cell sizes did not help me with reducing this effect.
# I will check LSTM using pre-trained word2vec weights now.

# %% [markdown]
# ## Model 3 - LSTM based on pretrained embeddings trained in twitter400 dataset

# %%
model_twitter = Sequential()
model_twitter.add(embedding_layer_twitter_pr)
model_twitter.add(Dropout(0.3))
model_twitter.add(CuDNNLSTM(100, return_sequences=False))
model_twitter.add(Dropout(0.2))
model_twitter.add(Dense(3, activation='softmax'))
optimizer = RMSprop(lr=0.0001)
model_twitter.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])

print(model_twitter.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 22, 400)           3283600
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 22, 400)           0
# _________________________________________________________________
# cu_dnnlstm_21 (CuDNNLSTM)    (None, 100)               200800
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 3,484,703
# Trainable params: 201,103
# Non-trainable params: 3,283,600
# _________________________________________________________________
# None

# %%
def scheduler(epoch):
    if epoch == 20:
        K.set_value(model_twitter.optimizer.lr, .00001)
    if epoch == 100:
        K.set_value(model_twitter.optimizer.lr, .000001)
    return K.get_value(model_twitter.optimizer.lr)

print('Train...')

checkpoint = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5', monitor="val_categorical_accuracy", save_best_only=True, mode='max', verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", mode='min', verbose=1, patience=50)
change_lr = LearningRateScheduler(scheduler)
callbacks_list = [checkpoint, early_stopping, change_lr]

model_twitter_trained=model_twitter.fit(trainX_DL, 
                                        trainY_DL, 
                                        batch_size=16,
                                        callbacks=callbacks_list,                      
                                        epochs=500,                       
                                        validation_data=(valX_DL, valY_DL), 
                                        verbose=2)
# Out:
# Train...
# Train on 9369 samples, validate on 2343 samples
# Epoch 1/500
#  - 8s - loss: 0.7633 - categorical_accuracy: 0.6830 - val_loss: 0.6421 - val_categorical_accuracy: 0.7512
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.75117, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 2/500
#  - 5s - loss: 0.6233 - categorical_accuracy: 0.7573 - val_loss: 0.5743 - val_categorical_accuracy: 0.7678
#
# Epoch 00002: val_categorical_accuracy improved from 0.75117 to 0.76782, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 3/500
#  - 5s - loss: 0.5823 - categorical_accuracy: 0.7620 - val_loss: 0.5518 - val_categorical_accuracy: 0.7772
#
# Epoch 00003: val_categorical_accuracy improved from 0.76782 to 0.77721, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 4/500
#  - 5s - loss: 0.5613 - categorical_accuracy: 0.7687 - val_loss: 0.5388 - val_categorical_accuracy: 0.7810
#
# Epoch 00004: val_categorical_accuracy improved from 0.77721 to 0.78105, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 5/500
#  - 5s - loss: 0.5470 - categorical_accuracy: 0.7741 - val_loss: 0.5413 - val_categorical_accuracy: 0.7845
#
# Epoch 00005: val_categorical_accuracy improved from 0.78105 to 0.78446, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 6/500
#  - 5s - loss: 0.5367 - categorical_accuracy: 0.7812 - val_loss: 0.5195 - val_categorical_accuracy: 0.7947
#
# Epoch 00006: val_categorical_accuracy improved from 0.78446 to 0.79471, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 7/500
#  - 5s - loss: 0.5290 - categorical_accuracy: 0.7851 - val_loss: 0.5165 - val_categorical_accuracy: 0.7926
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.79471
# Epoch 8/500
#  - 6s - loss: 0.5222 - categorical_accuracy: 0.7880 - val_loss: 0.5128 - val_categorical_accuracy: 0.7985
#
# Epoch 00008: val_categorical_accuracy improved from 0.79471 to 0.79855, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 9/500
#  - 5s - loss: 0.5156 - categorical_accuracy: 0.7913 - val_loss: 0.5139 - val_categorical_accuracy: 0.7956
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.79855
# Epoch 10/500
#  - 6s - loss: 0.5118 - categorical_accuracy: 0.7945 - val_loss: 0.5137 - val_categorical_accuracy: 0.7960
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.79855
# Epoch 11/500
#  - 5s - loss: 0.4996 - categorical_accuracy: 0.7990 - val_loss: 0.5038 - val_categorical_accuracy: 0.8011
#
# Epoch 00011: val_categorical_accuracy improved from 0.79855 to 0.80111, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 12/500
#  - 6s - loss: 0.4955 - categorical_accuracy: 0.7997 - val_loss: 0.5046 - val_categorical_accuracy: 0.7968
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.80111
# Epoch 13/500
#  - 5s - loss: 0.4891 - categorical_accuracy: 0.8025 - val_loss: 0.5000 - val_categorical_accuracy: 0.8045
#
# Epoch 00013: val_categorical_accuracy improved from 0.80111 to 0.80452, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 14/500
#  - 6s - loss: 0.4835 - categorical_accuracy: 0.8010 - val_loss: 0.5103 - val_categorical_accuracy: 0.7977
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.80452
# Epoch 15/500
#  - 5s - loss: 0.4770 - categorical_accuracy: 0.8102 - val_loss: 0.5163 - val_categorical_accuracy: 0.7977
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.80452
# Epoch 16/500
#  - 5s - loss: 0.4707 - categorical_accuracy: 0.8109 - val_loss: 0.5157 - val_categorical_accuracy: 0.7960
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.80452
# Epoch 17/500
#  - 5s - loss: 0.4658 - categorical_accuracy: 0.8161 - val_loss: 0.4980 - val_categorical_accuracy: 0.7985
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.80452
# Epoch 18/500
#  - 5s - loss: 0.4582 - categorical_accuracy: 0.8161 - val_loss: 0.5012 - val_categorical_accuracy: 0.7981
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.80452
# Epoch 19/500
#  - 5s - loss: 0.4567 - categorical_accuracy: 0.8147 - val_loss: 0.5077 - val_categorical_accuracy: 0.7977
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.80452
# Epoch 20/500
#  - 5s - loss: 0.4506 - categorical_accuracy: 0.8229 - val_loss: 0.5152 - val_categorical_accuracy: 0.7892
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.80452
# Epoch 21/500
#  - 5s - loss: 0.4350 - categorical_accuracy: 0.8263 - val_loss: 0.4980 - val_categorical_accuracy: 0.8041
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.80452
# Epoch 22/500
#  - 5s - loss: 0.4334 - categorical_accuracy: 0.8242 - val_loss: 0.5029 - val_categorical_accuracy: 0.7998
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.80452
# Epoch 23/500
#  - 5s - loss: 0.4346 - categorical_accuracy: 0.8187 - val_loss: 0.4990 - val_categorical_accuracy: 0.8041
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.80452
# Epoch 24/500
#  - 5s - loss: 0.4307 - categorical_accuracy: 0.8293 - val_loss: 0.5002 - val_categorical_accuracy: 0.8028
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.80452
# Epoch 25/500
#  - 5s - loss: 0.4324 - categorical_accuracy: 0.8242 - val_loss: 0.5054 - val_categorical_accuracy: 0.8011
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.80452
# Epoch 26/500
#  - 5s - loss: 0.4322 - categorical_accuracy: 0.8245 - val_loss: 0.5018 - val_categorical_accuracy: 0.8011
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.80452
# Epoch 27/500
#  - 5s - loss: 0.4285 - categorical_accuracy: 0.8300 - val_loss: 0.4999 - val_categorical_accuracy: 0.8037
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.80452
# Epoch 28/500
#  - 5s - loss: 0.4235 - categorical_accuracy: 0.8303 - val_loss: 0.5010 - val_categorical_accuracy: 0.8037
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.80452
# Epoch 29/500
#  - 5s - loss: 0.4277 - categorical_accuracy: 0.8253 - val_loss: 0.4999 - val_categorical_accuracy: 0.8045
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.80452
# Epoch 30/500
#  - 5s - loss: 0.4286 - categorical_accuracy: 0.8276 - val_loss: 0.5007 - val_categorical_accuracy: 0.8024
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.80452
# Epoch 31/500
#  - 5s - loss: 0.4248 - categorical_accuracy: 0.8331 - val_loss: 0.5007 - val_categorical_accuracy: 0.8032
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.80452
# Epoch 32/500
#  - 5s - loss: 0.4304 - categorical_accuracy: 0.8285 - val_loss: 0.5009 - val_categorical_accuracy: 0.8007
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.80452
# Epoch 33/500
#  - 5s - loss: 0.4235 - categorical_accuracy: 0.8263 - val_loss: 0.5014 - val_categorical_accuracy: 0.8011
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.80452
# Epoch 34/500
#  - 5s - loss: 0.4237 - categorical_accuracy: 0.8256 - val_loss: 0.5019 - val_categorical_accuracy: 0.8020
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.80452
# Epoch 35/500
#  - 5s - loss: 0.4164 - categorical_accuracy: 0.8348 - val_loss: 0.5008 - val_categorical_accuracy: 0.8028
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.80452
# Epoch 36/500
#  - 5s - loss: 0.4199 - categorical_accuracy: 0.8338 - val_loss: 0.5018 - val_categorical_accuracy: 0.8041
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.80452
# Epoch 37/500
#  - 5s - loss: 0.4207 - categorical_accuracy: 0.8325 - val_loss: 0.5045 - val_categorical_accuracy: 0.8037
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.80452
# Epoch 38/500
#  - 5s - loss: 0.4228 - categorical_accuracy: 0.8298 - val_loss: 0.5038 - val_categorical_accuracy: 0.8050
#
# Epoch 00038: val_categorical_accuracy improved from 0.80452 to 0.80495, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 39/500
#  - 5s - loss: 0.4223 - categorical_accuracy: 0.8274 - val_loss: 0.5037 - val_categorical_accuracy: 0.8020
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.80495
# Epoch 40/500
#  - 5s - loss: 0.4203 - categorical_accuracy: 0.8319 - val_loss: 0.5053 - val_categorical_accuracy: 0.8007
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.80495
# Epoch 41/500
#  - 5s - loss: 0.4215 - categorical_accuracy: 0.8299 - val_loss: 0.5027 - val_categorical_accuracy: 0.8058
#
# Epoch 00041: val_categorical_accuracy improved from 0.80495 to 0.80580, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 42/500
#  - 5s - loss: 0.4163 - categorical_accuracy: 0.8332 - val_loss: 0.5056 - val_categorical_accuracy: 0.8024
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.80580
# Epoch 43/500
#  - 6s - loss: 0.4208 - categorical_accuracy: 0.8317 - val_loss: 0.5066 - val_categorical_accuracy: 0.8024
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.80580
# Epoch 44/500
#  - 5s - loss: 0.4154 - categorical_accuracy: 0.8351 - val_loss: 0.5055 - val_categorical_accuracy: 0.8054
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.80580
# Epoch 45/500
#  - 5s - loss: 0.4145 - categorical_accuracy: 0.8335 - val_loss: 0.5066 - val_categorical_accuracy: 0.8024
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.80580
# Epoch 46/500
#  - 5s - loss: 0.4187 - categorical_accuracy: 0.8332 - val_loss: 0.5065 - val_categorical_accuracy: 0.8045
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.80580
# Epoch 47/500
#  - 5s - loss: 0.4083 - categorical_accuracy: 0.8359 - val_loss: 0.5060 - val_categorical_accuracy: 0.8054
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.80580
# Epoch 48/500
#  - 5s - loss: 0.4148 - categorical_accuracy: 0.8295 - val_loss: 0.5031 - val_categorical_accuracy: 0.8062
#
# Epoch 00048: val_categorical_accuracy improved from 0.80580 to 0.80623, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 49/500
#  - 6s - loss: 0.4067 - categorical_accuracy: 0.8353 - val_loss: 0.5054 - val_categorical_accuracy: 0.8071
#
# Epoch 00049: val_categorical_accuracy improved from 0.80623 to 0.80708, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3-embeddings.hdf5
# Epoch 50/500
#  - 6s - loss: 0.4143 - categorical_accuracy: 0.8365 - val_loss: 0.5054 - val_categorical_accuracy: 0.8045
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.80708
# Epoch 51/500
#  - 5s - loss: 0.4177 - categorical_accuracy: 0.8336 - val_loss: 0.5021 - val_categorical_accuracy: 0.8062
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.80708
# Epoch 52/500
#  - 5s - loss: 0.4150 - categorical_accuracy: 0.8365 - val_loss: 0.5018 - val_categorical_accuracy: 0.8058
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.80708
# Epoch 53/500
#  - 5s - loss: 0.4070 - categorical_accuracy: 0.8338 - val_loss: 0.5014 - val_categorical_accuracy: 0.8050
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.80708
# Epoch 54/500
#  - 5s - loss: 0.4035 - categorical_accuracy: 0.8386 - val_loss: 0.5070 - val_categorical_accuracy: 0.8045
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.80708
# Epoch 55/500
#  - 5s - loss: 0.4089 - categorical_accuracy: 0.8364 - val_loss: 0.5066 - val_categorical_accuracy: 0.8028
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.80708
# Epoch 56/500
#  - 5s - loss: 0.4034 - categorical_accuracy: 0.8388 - val_loss: 0.5050 - val_categorical_accuracy: 0.8041
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.80708
# Epoch 57/500
#  - 5s - loss: 0.4052 - categorical_accuracy: 0.8345 - val_loss: 0.5082 - val_categorical_accuracy: 0.8037
#
# Epoch 00057: val_categorical_accuracy did not improve from 0.80708
# Epoch 58/500
#  - 5s - loss: 0.4065 - categorical_accuracy: 0.8362 - val_loss: 0.5052 - val_categorical_accuracy: 0.8032
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.80708
# Epoch 59/500
#  - 5s - loss: 0.4001 - categorical_accuracy: 0.8396 - val_loss: 0.5089 - val_categorical_accuracy: 0.8041
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.80708
# Epoch 60/500
#  - 5s - loss: 0.4073 - categorical_accuracy: 0.8339 - val_loss: 0.5065 - val_categorical_accuracy: 0.8037
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.80708
# Epoch 61/500
#  - 5s - loss: 0.4057 - categorical_accuracy: 0.8359 - val_loss: 0.5084 - val_categorical_accuracy: 0.8028
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.80708
# Epoch 62/500
#  - 5s - loss: 0.4041 - categorical_accuracy: 0.8354 - val_loss: 0.5064 - val_categorical_accuracy: 0.8024
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.80708
# Epoch 63/500
#  - 5s - loss: 0.4069 - categorical_accuracy: 0.8367 - val_loss: 0.5110 - val_categorical_accuracy: 0.8037
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.80708
# Epoch 64/500
#  - 6s - loss: 0.4009 - categorical_accuracy: 0.8414 - val_loss: 0.5080 - val_categorical_accuracy: 0.8028
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.80708
# Epoch 65/500
#  - 5s - loss: 0.4000 - categorical_accuracy: 0.8353 - val_loss: 0.5091 - val_categorical_accuracy: 0.8045
#
# Epoch 00065: val_categorical_accuracy did not improve from 0.80708
# Epoch 66/500
#  - 5s - loss: 0.4046 - categorical_accuracy: 0.8374 - val_loss: 0.5118 - val_categorical_accuracy: 0.8041
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.80708
# Epoch 67/500
#  - 5s - loss: 0.4009 - categorical_accuracy: 0.8390 - val_loss: 0.5064 - val_categorical_accuracy: 0.8015
#
# Epoch 00067: val_categorical_accuracy did not improve from 0.80708
# Epoch 68/500
#  - 5s - loss: 0.3981 - categorical_accuracy: 0.8390 - val_loss: 0.5081 - val_categorical_accuracy: 0.8020
#
# Epoch 00068: val_categorical_accuracy did not improve from 0.80708
# Epoch 69/500
#  - 5s - loss: 0.3992 - categorical_accuracy: 0.8375 - val_loss: 0.5068 - val_categorical_accuracy: 0.8032
#
# Epoch 00069: val_categorical_accuracy did not improve from 0.80708
# Epoch 70/500
#  - 5s - loss: 0.4041 - categorical_accuracy: 0.8372 - val_loss: 0.5070 - val_categorical_accuracy: 0.8032
#
# Epoch 00070: val_categorical_accuracy did not improve from 0.80708
# Epoch 71/500
#  - 5s - loss: 0.4009 - categorical_accuracy: 0.8381 - val_loss: 0.5081 - val_categorical_accuracy: 0.8024
#
# Epoch 00071: val_categorical_accuracy did not improve from 0.80708
# Epoch 00071: early stopping

# %%
loss = model_twitter_trained.history['loss']
val_loss = model_twitter_trained.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = model_twitter_trained.history['categorical_accuracy']
val_acc = model_twitter_trained.history['val_categorical_accuracy']
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# The best score now equals to **80.71%**. I gained 2.5% percents over ML models' best score.
# I tried to experiment with differnt Dropout values, LSTM cell size and Learning Rate scheduler to get longer learning rates to decrease overfitting. However my attempts were not sucessful in this case. I also decided to stack additional LSTM layers, which allow me maybe to better fit to data. On the other hand I decreased the LSTM cells complexity hoping to have better generalization power of the model.

# %%
model_twitter_alt = Sequential()
model_twitter_alt.add(embedding_layer_twitter_pr)
model_twitter_alt.add(Dropout(0.4))
model_twitter_alt.add(CuDNNLSTM(50, return_sequences=True)) # I decreased the cell number, but created two layers. 
model_twitter_alt.add(Dropout(0.4))
model_twitter_alt.add(CuDNNLSTM(50, return_sequences=False))
model_twitter_alt.add(Dropout(0.2))
model_twitter_alt.add(Dense(3, activation='softmax'))
optimizer = RMSprop(lr=0.0001)
model_twitter_alt.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])

print(model_twitter_alt.summary())

def scheduler(epoch):
    if epoch == 20:
        K.set_value(model_twitter_alt.optimizer.lr, .00001)
    if epoch == 100:
        K.set_value(model_twitter_alt.optimizer.lr, .000001)
    return K.get_value(model_twitter_alt.optimizer.lr)

print('Train...')

checkpoint = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5', monitor="val_categorical_accuracy", save_best_only=True, mode='max', verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", mode='min', verbose=1, patience=20)
change_lr = LearningRateScheduler(scheduler)
callbacks_list = [checkpoint, early_stopping, change_lr]

model_twitter_alt_trained=model_twitter_alt.fit(trainX_DL, 
                                                trainY_DL, 
                                                batch_size=16,
                                                callbacks=callbacks_list,                      
                                                epochs=500,                       
                                                validation_data=(valX_DL, valY_DL, 
                                                verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 22, 400)           3283600
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 22, 400)           0
# _________________________________________________________________
# cu_dnnlstm_33 (CuDNNLSTM)    (None, 22, 50)            90400
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 22, 50)            0
# _________________________________________________________________
# cu_dnnlstm_34 (CuDNNLSTM)    (None, 50)                20400
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 3,394,553
# Trainable params: 110,953
# Non-trainable params: 3,283,600
# _________________________________________________________________
# None
# Train...
# Train on 9369 samples, validate on 2343 samples
# Epoch 1/500
#  - 15s - loss: 0.8223 - categorical_accuracy: 0.6456 - val_loss: 0.7266 - val_categorical_accuracy: 0.6901
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.69014, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 2/500
#  - 10s - loss: 0.6974 - categorical_accuracy: 0.7152 - val_loss: 0.6278 - val_categorical_accuracy: 0.7397
#
# Epoch 00002: val_categorical_accuracy improved from 0.69014 to 0.73965, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 3/500
#  - 10s - loss: 0.6508 - categorical_accuracy: 0.7302 - val_loss: 0.6081 - val_categorical_accuracy: 0.7563
#
# Epoch 00003: val_categorical_accuracy improved from 0.73965 to 0.75630, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 4/500
#  - 10s - loss: 0.6261 - categorical_accuracy: 0.7449 - val_loss: 0.5818 - val_categorical_accuracy: 0.7674
#
# Epoch 00004: val_categorical_accuracy improved from 0.75630 to 0.76739, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 5/500
#  - 10s - loss: 0.6112 - categorical_accuracy: 0.7499 - val_loss: 0.5610 - val_categorical_accuracy: 0.7755
#
# Epoch 00005: val_categorical_accuracy improved from 0.76739 to 0.77550, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 6/500
#  - 10s - loss: 0.5957 - categorical_accuracy: 0.7572 - val_loss: 0.5507 - val_categorical_accuracy: 0.7836
#
# Epoch 00006: val_categorical_accuracy improved from 0.77550 to 0.78361, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 7/500
#  - 10s - loss: 0.5866 - categorical_accuracy: 0.7568 - val_loss: 0.5450 - val_categorical_accuracy: 0.7798
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.78361
# Epoch 8/500
#  - 10s - loss: 0.5794 - categorical_accuracy: 0.7642 - val_loss: 0.5386 - val_categorical_accuracy: 0.7840
#
# Epoch 00008: val_categorical_accuracy improved from 0.78361 to 0.78404, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 9/500
#  - 10s - loss: 0.5707 - categorical_accuracy: 0.7652 - val_loss: 0.5451 - val_categorical_accuracy: 0.7853
#
# Epoch 00009: val_categorical_accuracy improved from 0.78404 to 0.78532, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 10/500
#  - 10s - loss: 0.5594 - categorical_accuracy: 0.7759 - val_loss: 0.5246 - val_categorical_accuracy: 0.7913
#
# Epoch 00010: val_categorical_accuracy improved from 0.78532 to 0.79129, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 11/500
#  - 10s - loss: 0.5561 - categorical_accuracy: 0.7741 - val_loss: 0.5228 - val_categorical_accuracy: 0.7909
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.79129
# Epoch 12/500
#  - 10s - loss: 0.5446 - categorical_accuracy: 0.7774 - val_loss: 0.5184 - val_categorical_accuracy: 0.7951
#
# Epoch 00012: val_categorical_accuracy improved from 0.79129 to 0.79513, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 13/500
#  - 10s - loss: 0.5444 - categorical_accuracy: 0.7772 - val_loss: 0.5126 - val_categorical_accuracy: 0.7968
#
# Epoch 00013: val_categorical_accuracy improved from 0.79513 to 0.79684, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 14/500
#  - 10s - loss: 0.5341 - categorical_accuracy: 0.7846 - val_loss: 0.5328 - val_categorical_accuracy: 0.7883
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.79684
# Epoch 15/500
#  - 10s - loss: 0.5366 - categorical_accuracy: 0.7812 - val_loss: 0.5313 - val_categorical_accuracy: 0.7896
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.79684
# Epoch 16/500
#  - 10s - loss: 0.5325 - categorical_accuracy: 0.7820 - val_loss: 0.5088 - val_categorical_accuracy: 0.7977
#
# Epoch 00016: val_categorical_accuracy improved from 0.79684 to 0.79770, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 17/500
#  - 10s - loss: 0.5268 - categorical_accuracy: 0.7856 - val_loss: 0.5124 - val_categorical_accuracy: 0.7994
#
# Epoch 00017: val_categorical_accuracy improved from 0.79770 to 0.79940, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 18/500
#  - 10s - loss: 0.5265 - categorical_accuracy: 0.7851 - val_loss: 0.5043 - val_categorical_accuracy: 0.8007
#
# Epoch 00018: val_categorical_accuracy improved from 0.79940 to 0.80068, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 19/500
#  - 10s - loss: 0.5184 - categorical_accuracy: 0.7892 - val_loss: 0.5033 - val_categorical_accuracy: 0.8041
#
# Epoch 00019: val_categorical_accuracy improved from 0.80068 to 0.80410, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 20/500
#  - 10s - loss: 0.5146 - categorical_accuracy: 0.7869 - val_loss: 0.4988 - val_categorical_accuracy: 0.8050
#
# Epoch 00020: val_categorical_accuracy improved from 0.80410 to 0.80495, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 21/500
#  - 10s - loss: 0.5027 - categorical_accuracy: 0.7949 - val_loss: 0.5004 - val_categorical_accuracy: 0.8050
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.80495
# Epoch 22/500
#  - 10s - loss: 0.5056 - categorical_accuracy: 0.7912 - val_loss: 0.4997 - val_categorical_accuracy: 0.8050
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.80495
# Epoch 23/500
#  - 10s - loss: 0.5085 - categorical_accuracy: 0.7899 - val_loss: 0.4989 - val_categorical_accuracy: 0.8050
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.80495
# Epoch 24/500
#  - 10s - loss: 0.5064 - categorical_accuracy: 0.7936 - val_loss: 0.5001 - val_categorical_accuracy: 0.8054
#
# Epoch 00024: val_categorical_accuracy improved from 0.80495 to 0.80538, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 25/500
#  - 10s - loss: 0.5053 - categorical_accuracy: 0.7928 - val_loss: 0.4995 - val_categorical_accuracy: 0.8058
#
# Epoch 00025: val_categorical_accuracy improved from 0.80538 to 0.80580, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 26/500
#  - 10s - loss: 0.5122 - categorical_accuracy: 0.7904 - val_loss: 0.4990 - val_categorical_accuracy: 0.8054
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.80580
# Epoch 27/500
#  - 10s - loss: 0.5093 - categorical_accuracy: 0.7917 - val_loss: 0.4991 - val_categorical_accuracy: 0.8050
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.80580
# Epoch 28/500
#  - 10s - loss: 0.5080 - categorical_accuracy: 0.7910 - val_loss: 0.4991 - val_categorical_accuracy: 0.8050
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.80580
# Epoch 29/500
#  - 10s - loss: 0.5064 - categorical_accuracy: 0.7924 - val_loss: 0.4982 - val_categorical_accuracy: 0.8054
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.80580
# Epoch 30/500
#  - 10s - loss: 0.5074 - categorical_accuracy: 0.7928 - val_loss: 0.4997 - val_categorical_accuracy: 0.8028
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.80580
# Epoch 31/500
#  - 10s - loss: 0.5077 - categorical_accuracy: 0.7910 - val_loss: 0.4977 - val_categorical_accuracy: 0.8050
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.80580
# Epoch 32/500
#  - 10s - loss: 0.4983 - categorical_accuracy: 0.7943 - val_loss: 0.4982 - val_categorical_accuracy: 0.8058
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.80580
# Epoch 33/500
#  - 10s - loss: 0.5045 - categorical_accuracy: 0.7941 - val_loss: 0.4973 - val_categorical_accuracy: 0.8045
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.80580
# Epoch 34/500
#  - 10s - loss: 0.5028 - categorical_accuracy: 0.7915 - val_loss: 0.4984 - val_categorical_accuracy: 0.8050
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.80580
# Epoch 35/500
#  - 10s - loss: 0.5042 - categorical_accuracy: 0.7956 - val_loss: 0.4988 - val_categorical_accuracy: 0.8045
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.80580
# Epoch 36/500
#  - 10s - loss: 0.5025 - categorical_accuracy: 0.7987 - val_loss: 0.4960 - val_categorical_accuracy: 0.8054
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.80580
# Epoch 37/500
#  - 10s - loss: 0.4987 - categorical_accuracy: 0.7957 - val_loss: 0.4968 - val_categorical_accuracy: 0.8050
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.80580
# Epoch 38/500
#  - 10s - loss: 0.5020 - categorical_accuracy: 0.7936 - val_loss: 0.4970 - val_categorical_accuracy: 0.8028
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.80580
# Epoch 39/500
#  - 10s - loss: 0.4965 - categorical_accuracy: 0.7946 - val_loss: 0.4965 - val_categorical_accuracy: 0.8037
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.80580
# Epoch 40/500
#  - 10s - loss: 0.4947 - categorical_accuracy: 0.8022 - val_loss: 0.4976 - val_categorical_accuracy: 0.8050
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.80580
# Epoch 41/500
#  - 10s - loss: 0.5029 - categorical_accuracy: 0.7935 - val_loss: 0.4957 - val_categorical_accuracy: 0.8041
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.80580
# Epoch 42/500
#  - 10s - loss: 0.4945 - categorical_accuracy: 0.7988 - val_loss: 0.4966 - val_categorical_accuracy: 0.8028
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.80580
# Epoch 43/500
#  - 10s - loss: 0.4956 - categorical_accuracy: 0.7924 - val_loss: 0.4955 - val_categorical_accuracy: 0.8067
#
# Epoch 00043: val_categorical_accuracy improved from 0.80580 to 0.80666, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 44/500
#  - 10s - loss: 0.5032 - categorical_accuracy: 0.7935 - val_loss: 0.4955 - val_categorical_accuracy: 0.8050
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.80666
# Epoch 45/500
#  - 10s - loss: 0.5004 - categorical_accuracy: 0.7938 - val_loss: 0.4949 - val_categorical_accuracy: 0.8054
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.80666
# Epoch 46/500
#  - 10s - loss: 0.4990 - categorical_accuracy: 0.7910 - val_loss: 0.4956 - val_categorical_accuracy: 0.8050
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.80666
# Epoch 47/500
#  - 10s - loss: 0.4982 - categorical_accuracy: 0.7978 - val_loss: 0.4968 - val_categorical_accuracy: 0.8041
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.80666
# Epoch 48/500
#  - 10s - loss: 0.5017 - categorical_accuracy: 0.7934 - val_loss: 0.4951 - val_categorical_accuracy: 0.8045
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.80666
# Epoch 49/500
#  - 10s - loss: 0.4896 - categorical_accuracy: 0.7993 - val_loss: 0.4964 - val_categorical_accuracy: 0.8041
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.80666
# Epoch 50/500
#  - 10s - loss: 0.4960 - categorical_accuracy: 0.7955 - val_loss: 0.4948 - val_categorical_accuracy: 0.8062
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.80666
# Epoch 51/500
#  - 10s - loss: 0.4957 - categorical_accuracy: 0.7973 - val_loss: 0.4944 - val_categorical_accuracy: 0.8058
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.80666
# Epoch 52/500
#  - 10s - loss: 0.4972 - categorical_accuracy: 0.7961 - val_loss: 0.4948 - val_categorical_accuracy: 0.8054
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.80666
# Epoch 53/500
#  - 10s - loss: 0.5010 - categorical_accuracy: 0.7958 - val_loss: 0.4938 - val_categorical_accuracy: 0.8058
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.80666
# Epoch 54/500
#  - 10s - loss: 0.4982 - categorical_accuracy: 0.7944 - val_loss: 0.4964 - val_categorical_accuracy: 0.8028
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.80666
# Epoch 55/500
#  - 10s - loss: 0.4976 - categorical_accuracy: 0.7966 - val_loss: 0.4939 - val_categorical_accuracy: 0.8062
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.80666
# Epoch 56/500
#  - 10s - loss: 0.5021 - categorical_accuracy: 0.7973 - val_loss: 0.4950 - val_categorical_accuracy: 0.8037
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.80666
# Epoch 57/500
#  - 10s - loss: 0.4921 - categorical_accuracy: 0.7996 - val_loss: 0.4965 - val_categorical_accuracy: 0.8045
#
# Epoch 00057: val_categorical_accuracy did not improve from 0.80666
# Epoch 58/500
#  - 10s - loss: 0.5002 - categorical_accuracy: 0.7913 - val_loss: 0.4938 - val_categorical_accuracy: 0.8075
#
# Epoch 00058: val_categorical_accuracy improved from 0.80666 to 0.80751, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 59/500
#  - 10s - loss: 0.4922 - categorical_accuracy: 0.7977 - val_loss: 0.4950 - val_categorical_accuracy: 0.8058
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.80751
# Epoch 60/500
#  - 10s - loss: 0.4946 - categorical_accuracy: 0.7942 - val_loss: 0.4943 - val_categorical_accuracy: 0.8041
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.80751
# Epoch 61/500
#  - 10s - loss: 0.4930 - categorical_accuracy: 0.8004 - val_loss: 0.4953 - val_categorical_accuracy: 0.8041
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.80751
# Epoch 62/500
#  - 10s - loss: 0.4954 - categorical_accuracy: 0.8004 - val_loss: 0.4952 - val_categorical_accuracy: 0.8032
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.80751
# Epoch 63/500
#  - 10s - loss: 0.4919 - categorical_accuracy: 0.8007 - val_loss: 0.4946 - val_categorical_accuracy: 0.8054
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.80751
# Epoch 64/500
#  - 10s - loss: 0.4941 - categorical_accuracy: 0.7967 - val_loss: 0.4944 - val_categorical_accuracy: 0.8037
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.80751
# Epoch 65/500
#  - 10s - loss: 0.4918 - categorical_accuracy: 0.8010 - val_loss: 0.4929 - val_categorical_accuracy: 0.8071
#
# Epoch 00065: val_categorical_accuracy did not improve from 0.80751
# Epoch 66/500
#  - 10s - loss: 0.4879 - categorical_accuracy: 0.7989 - val_loss: 0.4956 - val_categorical_accuracy: 0.8037
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.80751
# Epoch 67/500
#  - 10s - loss: 0.4941 - categorical_accuracy: 0.8021 - val_loss: 0.4929 - val_categorical_accuracy: 0.8088
#
# Epoch 00067: val_categorical_accuracy improved from 0.80751 to 0.80879, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 68/500
#  - 10s - loss: 0.4948 - categorical_accuracy: 0.8018 - val_loss: 0.4932 - val_categorical_accuracy: 0.8067
#
# Epoch 00068: val_categorical_accuracy did not improve from 0.80879
# Epoch 69/500
#  - 10s - loss: 0.4882 - categorical_accuracy: 0.8012 - val_loss: 0.4960 - val_categorical_accuracy: 0.8041
#
# Epoch 00069: val_categorical_accuracy did not improve from 0.80879
# Epoch 70/500
#  - 10s - loss: 0.4938 - categorical_accuracy: 0.7992 - val_loss: 0.4937 - val_categorical_accuracy: 0.8062
#
# Epoch 00070: val_categorical_accuracy did not improve from 0.80879
# Epoch 71/500
#  - 10s - loss: 0.4929 - categorical_accuracy: 0.7999 - val_loss: 0.4933 - val_categorical_accuracy: 0.8050
#
# Epoch 00071: val_categorical_accuracy did not improve from 0.80879
# Epoch 72/500
#  - 10s - loss: 0.4919 - categorical_accuracy: 0.7992 - val_loss: 0.4945 - val_categorical_accuracy: 0.8024
#
# Epoch 00072: val_categorical_accuracy did not improve from 0.80879
# Epoch 73/500
#  - 10s - loss: 0.4901 - categorical_accuracy: 0.8015 - val_loss: 0.4933 - val_categorical_accuracy: 0.8088
#
# Epoch 00073: val_categorical_accuracy did not improve from 0.80879
# Epoch 74/500
#  - 10s - loss: 0.4943 - categorical_accuracy: 0.7994 - val_loss: 0.4934 - val_categorical_accuracy: 0.8067
#
# Epoch 00074: val_categorical_accuracy did not improve from 0.80879
# Epoch 75/500
#  - 10s - loss: 0.4906 - categorical_accuracy: 0.7971 - val_loss: 0.4954 - val_categorical_accuracy: 0.8028
#
# Epoch 00075: val_categorical_accuracy did not improve from 0.80879
# Epoch 76/500
#  - 10s - loss: 0.4894 - categorical_accuracy: 0.7975 - val_loss: 0.4933 - val_categorical_accuracy: 0.8071
#
# Epoch 00076: val_categorical_accuracy did not improve from 0.80879
# Epoch 77/500
#  - 10s - loss: 0.4897 - categorical_accuracy: 0.8018 - val_loss: 0.4929 - val_categorical_accuracy: 0.8067
#
# Epoch 00077: val_categorical_accuracy did not improve from 0.80879
# Epoch 78/500
#  - 10s - loss: 0.4804 - categorical_accuracy: 0.8080 - val_loss: 0.4948 - val_categorical_accuracy: 0.8067
#
# Epoch 00078: val_categorical_accuracy did not improve from 0.80879
# Epoch 79/500
#  - 10s - loss: 0.4921 - categorical_accuracy: 0.7986 - val_loss: 0.4928 - val_categorical_accuracy: 0.8071
#
# Epoch 00079: val_categorical_accuracy did not improve from 0.80879
# Epoch 80/500
#  - 10s - loss: 0.4825 - categorical_accuracy: 0.8049 - val_loss: 0.4926 - val_categorical_accuracy: 0.8088
#
# Epoch 00080: val_categorical_accuracy did not improve from 0.80879
# Epoch 81/500
#  - 10s - loss: 0.4903 - categorical_accuracy: 0.7999 - val_loss: 0.4930 - val_categorical_accuracy: 0.8092
#
# Epoch 00081: val_categorical_accuracy improved from 0.80879 to 0.80922, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 82/500
#  - 10s - loss: 0.4891 - categorical_accuracy: 0.8019 - val_loss: 0.4926 - val_categorical_accuracy: 0.8058
#
# Epoch 00082: val_categorical_accuracy did not improve from 0.80922
# Epoch 83/500
#  - 10s - loss: 0.4908 - categorical_accuracy: 0.7982 - val_loss: 0.4924 - val_categorical_accuracy: 0.8075
#
# Epoch 00083: val_categorical_accuracy did not improve from 0.80922
# Epoch 84/500
#  - 10s - loss: 0.4790 - categorical_accuracy: 0.8068 - val_loss: 0.4943 - val_categorical_accuracy: 0.8054
#
# Epoch 00084: val_categorical_accuracy did not improve from 0.80922
# Epoch 85/500
#  - 10s - loss: 0.4859 - categorical_accuracy: 0.7993 - val_loss: 0.4920 - val_categorical_accuracy: 0.8084
#
# Epoch 00085: val_categorical_accuracy did not improve from 0.80922
# Epoch 86/500
#  - 10s - loss: 0.4824 - categorical_accuracy: 0.8025 - val_loss: 0.4918 - val_categorical_accuracy: 0.8092
#
# Epoch 00086: val_categorical_accuracy did not improve from 0.80922
# Epoch 87/500
#  - 10s - loss: 0.4823 - categorical_accuracy: 0.8050 - val_loss: 0.4942 - val_categorical_accuracy: 0.8075
#
# Epoch 00087: val_categorical_accuracy did not improve from 0.80922
# Epoch 88/500
#  - 10s - loss: 0.4865 - categorical_accuracy: 0.7981 - val_loss: 0.4922 - val_categorical_accuracy: 0.8088
#
# Epoch 00088: val_categorical_accuracy did not improve from 0.80922
# Epoch 89/500
#  - 10s - loss: 0.4864 - categorical_accuracy: 0.8032 - val_loss: 0.4914 - val_categorical_accuracy: 0.8071
#
# Epoch 00089: val_categorical_accuracy did not improve from 0.80922
# Epoch 90/500
#  - 10s - loss: 0.4819 - categorical_accuracy: 0.8012 - val_loss: 0.4921 - val_categorical_accuracy: 0.8084
#
# Epoch 00090: val_categorical_accuracy did not improve from 0.80922
# Epoch 91/500
#  - 10s - loss: 0.4821 - categorical_accuracy: 0.8015 - val_loss: 0.4915 - val_categorical_accuracy: 0.8088
#
# Epoch 00091: val_categorical_accuracy did not improve from 0.80922
# Epoch 92/500
#  - 10s - loss: 0.4828 - categorical_accuracy: 0.8022 - val_loss: 0.4925 - val_categorical_accuracy: 0.8088
#
# Epoch 00092: val_categorical_accuracy did not improve from 0.80922
# Epoch 93/500
#  - 10s - loss: 0.4892 - categorical_accuracy: 0.7992 - val_loss: 0.4921 - val_categorical_accuracy: 0.8088
#
# Epoch 00093: val_categorical_accuracy did not improve from 0.80922
# Epoch 94/500
#  - 10s - loss: 0.4859 - categorical_accuracy: 0.8009 - val_loss: 0.4919 - val_categorical_accuracy: 0.8084
#
# Epoch 00094: val_categorical_accuracy did not improve from 0.80922
# Epoch 95/500
#  - 10s - loss: 0.4876 - categorical_accuracy: 0.7981 - val_loss: 0.4911 - val_categorical_accuracy: 0.8101
#
# Epoch 00095: val_categorical_accuracy improved from 0.80922 to 0.81007, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5
# Epoch 96/500
#  - 10s - loss: 0.4837 - categorical_accuracy: 0.7996 - val_loss: 0.4915 - val_categorical_accuracy: 0.8075
#
# Epoch 00096: val_categorical_accuracy did not improve from 0.81007
# Epoch 97/500
#  - 10s - loss: 0.4837 - categorical_accuracy: 0.8037 - val_loss: 0.4916 - val_categorical_accuracy: 0.8071
#
# Epoch 00097: val_categorical_accuracy did not improve from 0.81007
# Epoch 98/500
#  - 10s - loss: 0.4737 - categorical_accuracy: 0.8100 - val_loss: 0.4922 - val_categorical_accuracy: 0.8079
#
# Epoch 00098: val_categorical_accuracy did not improve from 0.81007
# Epoch 99/500
#  - 10s - loss: 0.4751 - categorical_accuracy: 0.8061 - val_loss: 0.4916 - val_categorical_accuracy: 0.8088
#
# Epoch 00099: val_categorical_accuracy did not improve from 0.81007
# Epoch 100/500
#  - 10s - loss: 0.4856 - categorical_accuracy: 0.8052 - val_loss: 0.4908 - val_categorical_accuracy: 0.8084
#
# Epoch 00100: val_categorical_accuracy did not improve from 0.81007
# Epoch 101/500
#  - 10s - loss: 0.4800 - categorical_accuracy: 0.8082 - val_loss: 0.4909 - val_categorical_accuracy: 0.8079
#
# Epoch 00101: val_categorical_accuracy did not improve from 0.81007
# Epoch 102/500
#  - 10s - loss: 0.4810 - categorical_accuracy: 0.8021 - val_loss: 0.4909 - val_categorical_accuracy: 0.8079
#
# Epoch 00102: val_categorical_accuracy did not improve from 0.81007
# Epoch 103/500
#  - 10s - loss: 0.4777 - categorical_accuracy: 0.8063 - val_loss: 0.4909 - val_categorical_accuracy: 0.8079
#
# Epoch 00103: val_categorical_accuracy did not improve from 0.81007
# Epoch 104/500
#  - 10s - loss: 0.4828 - categorical_accuracy: 0.8034 - val_loss: 0.4910 - val_categorical_accuracy: 0.8075
#
# Epoch 00104: val_categorical_accuracy did not improve from 0.81007
# Epoch 105/500
#  - 10s - loss: 0.4744 - categorical_accuracy: 0.8067 - val_loss: 0.4910 - val_categorical_accuracy: 0.8079
#
# Epoch 00105: val_categorical_accuracy did not improve from 0.81007
# Epoch 106/500
#  - 10s - loss: 0.4774 - categorical_accuracy: 0.8042 - val_loss: 0.4907 - val_categorical_accuracy: 0.8084
#
# Epoch 00106: val_categorical_accuracy did not improve from 0.81007
# Epoch 107/500
#  - 10s - loss: 0.4797 - categorical_accuracy: 0.8015 - val_loss: 0.4907 - val_categorical_accuracy: 0.8079
#
# Epoch 00107: val_categorical_accuracy did not improve from 0.81007
# Epoch 108/500
#  - 10s - loss: 0.4787 - categorical_accuracy: 0.8029 - val_loss: 0.4908 - val_categorical_accuracy: 0.8079
#
# Epoch 00108: val_categorical_accuracy did not improve from 0.81007
# Epoch 109/500
#  - 10s - loss: 0.4730 - categorical_accuracy: 0.8058 - val_loss: 0.4909 - val_categorical_accuracy: 0.8079
#
# Epoch 00109: val_categorical_accuracy did not improve from 0.81007
# Epoch 110/500
#  - 10s - loss: 0.4776 - categorical_accuracy: 0.8094 - val_loss: 0.4908 - val_categorical_accuracy: 0.8092
#
# Epoch 00110: val_categorical_accuracy did not improve from 0.81007
# Epoch 111/500
#  - 10s - loss: 0.4744 - categorical_accuracy: 0.8083 - val_loss: 0.4908 - val_categorical_accuracy: 0.8092
#
# Epoch 00111: val_categorical_accuracy did not improve from 0.81007
# Epoch 112/500
#  - 10s - loss: 0.4814 - categorical_accuracy: 0.8044 - val_loss: 0.4909 - val_categorical_accuracy: 0.8084
#
# Epoch 00112: val_categorical_accuracy did not improve from 0.81007
# Epoch 113/500
#  - 10s - loss: 0.4790 - categorical_accuracy: 0.8053 - val_loss: 0.4909 - val_categorical_accuracy: 0.8084
#
# Epoch 00113: val_categorical_accuracy did not improve from 0.81007
# Epoch 114/500
#  - 10s - loss: 0.4750 - categorical_accuracy: 0.8089 - val_loss: 0.4908 - val_categorical_accuracy: 0.8096
#
# Epoch 00114: val_categorical_accuracy did not improve from 0.81007
# Epoch 115/500
#  - 10s - loss: 0.4750 - categorical_accuracy: 0.8072 - val_loss: 0.4908 - val_categorical_accuracy: 0.8092
#
# Epoch 00115: val_categorical_accuracy did not improve from 0.81007
# Epoch 116/500
#  - 10s - loss: 0.4838 - categorical_accuracy: 0.8036 - val_loss: 0.4910 - val_categorical_accuracy: 0.8079
#
# Epoch 00116: val_categorical_accuracy did not improve from 0.81007
# Epoch 117/500
#  - 10s - loss: 0.4772 - categorical_accuracy: 0.8042 - val_loss: 0.4911 - val_categorical_accuracy: 0.8079
#
# Epoch 00117: val_categorical_accuracy did not improve from 0.81007
# Epoch 118/500
#  - 10s - loss: 0.4771 - categorical_accuracy: 0.8032 - val_loss: 0.4910 - val_categorical_accuracy: 0.8079
#
# Epoch 00118: val_categorical_accuracy did not improve from 0.81007
# Epoch 119/500
#  - 10s - loss: 0.4802 - categorical_accuracy: 0.8036 - val_loss: 0.4910 - val_categorical_accuracy: 0.8096
#
# Epoch 00119: val_categorical_accuracy did not improve from 0.81007
# Epoch 120/500
#  - 10s - loss: 0.4770 - categorical_accuracy: 0.8058 - val_loss: 0.4911 - val_categorical_accuracy: 0.8079
#
# Epoch 00120: val_categorical_accuracy did not improve from 0.81007
# Epoch 121/500
#  - 10s - loss: 0.4693 - categorical_accuracy: 0.8072 - val_loss: 0.4911 - val_categorical_accuracy: 0.8079
#
# Epoch 00121: val_categorical_accuracy did not improve from 0.81007
# Epoch 122/500
#  - 10s - loss: 0.4832 - categorical_accuracy: 0.8029 - val_loss: 0.4910 - val_categorical_accuracy: 0.8101
#
# Epoch 00122: val_categorical_accuracy did not improve from 0.81007
# Epoch 123/500
#  - 10s - loss: 0.4810 - categorical_accuracy: 0.8046 - val_loss: 0.4911 - val_categorical_accuracy: 0.8084
#
# Epoch 00123: val_categorical_accuracy did not improve from 0.81007
# Epoch 124/500
#  - 10s - loss: 0.4771 - categorical_accuracy: 0.8055 - val_loss: 0.4912 - val_categorical_accuracy: 0.8079
#
# Epoch 00124: val_categorical_accuracy did not improve from 0.81007
# Epoch 125/500
#  - 10s - loss: 0.4790 - categorical_accuracy: 0.8026 - val_loss: 0.4914 - val_categorical_accuracy: 0.8075
#
# Epoch 00125: val_categorical_accuracy did not improve from 0.81007
# Epoch 126/500
#  - 10s - loss: 0.4821 - categorical_accuracy: 0.8026 - val_loss: 0.4912 - val_categorical_accuracy: 0.8084
#
# Epoch 00126: val_categorical_accuracy did not improve from 0.81007
# Epoch 127/500
#  - 10s - loss: 0.4729 - categorical_accuracy: 0.8071 - val_loss: 0.4914 - val_categorical_accuracy: 0.8079
#
# Epoch 00127: val_categorical_accuracy did not improve from 0.81007
# Epoch 00127: early stopping

# %%
loss = model_twitter_alt_trained.history['loss']
val_loss = model_twitter_alt_trained.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = model_twitter_alt_trained.history['categorical_accuracy']
val_acc = model_twitter_alt_trained.history['val_categorical_accuracy']
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# My new score is **81.01%** ! The level of overfitting is much lower here. The model looks good and reliable.
# Now I check how the pretrained google embeddings works.

# %% [markdown]
# ## Model 4 - LSTM based on pretrained embeddings trained on google news300 dataset

# %%
model_google = Sequential()
model_google.add(embedding_layer_google_pr)
model_google.add(Dropout(0.3))
model_google.add(CuDNNLSTM(100, return_sequences=False))
model_google.add(Dropout(0.2))
model_google.add(Dense(3, activation='softmax'))
optimizer = RMSprop(lr=0.0001)
model_google.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])

print(model_google.summary())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 22, 300)           2462700
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 300)           0
# _________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)     (None, 100)               160800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 2,623,803
# Trainable params: 161,103
# Non-trainable params: 2,462,700
# _________________________________________________________________
# None

# %%
def scheduler(epoch):
    if epoch == 20:
        K.set_value(model_google.optimizer.lr, .00001)
    if epoch == 100:
        K.set_value(model_google.optimizer.lr, .000001)
    return K.get_value(model_google.optimizer.lr)

print('Train...')

checkpoint = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5', monitor="val_categorical_accuracy", save_best_only=True, mode='max', verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=20)
change_lr = LearningRateScheduler(scheduler)
callbacks_list = [checkpoint, early_stopping, change_lr]

model_google_trained=model_google.fit(trainX_DL, 
                                      trainY_DL, 
                                      batch_size=16,
                                      callbacks=callbacks_list,                      
                                      epochs=500, 
                                      validation_data=(valX_DL, valY_DL), 
                                      verbose=2)
# Out:
# Train...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 9369 samples, validate on 2343 samples
# Epoch 1/500
#  - 9s - loss: 0.7990 - categorical_accuracy: 0.6508 - val_loss: 0.6821 - val_categorical_accuracy: 0.7311
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.73111, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 2/500
#  - 5s - loss: 0.6544 - categorical_accuracy: 0.7359 - val_loss: 0.6067 - val_categorical_accuracy: 0.7601
#
# Epoch 00002: val_categorical_accuracy improved from 0.73111 to 0.76014, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 3/500
#  - 5s - loss: 0.6081 - categorical_accuracy: 0.7533 - val_loss: 0.5789 - val_categorical_accuracy: 0.7657
#
# Epoch 00003: val_categorical_accuracy improved from 0.76014 to 0.76569, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 4/500
#  - 5s - loss: 0.5844 - categorical_accuracy: 0.7630 - val_loss: 0.5624 - val_categorical_accuracy: 0.7708
#
# Epoch 00004: val_categorical_accuracy improved from 0.76569 to 0.77081, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 5/500
#  - 5s - loss: 0.5735 - categorical_accuracy: 0.7686 - val_loss: 0.5535 - val_categorical_accuracy: 0.7695
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.77081
# Epoch 6/500
#  - 5s - loss: 0.5673 - categorical_accuracy: 0.7671 - val_loss: 0.5486 - val_categorical_accuracy: 0.7729
#
# Epoch 00006: val_categorical_accuracy improved from 0.77081 to 0.77294, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 7/500
#  - 5s - loss: 0.5580 - categorical_accuracy: 0.7734 - val_loss: 0.5459 - val_categorical_accuracy: 0.7776
#
# Epoch 00007: val_categorical_accuracy improved from 0.77294 to 0.77764, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 8/500
#  - 5s - loss: 0.5524 - categorical_accuracy: 0.7739 - val_loss: 0.5346 - val_categorical_accuracy: 0.7785
#
# Epoch 00008: val_categorical_accuracy improved from 0.77764 to 0.77849, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 9/500
#  - 5s - loss: 0.5445 - categorical_accuracy: 0.7787 - val_loss: 0.5368 - val_categorical_accuracy: 0.7772
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.77849
# Epoch 10/500
#  - 5s - loss: 0.5389 - categorical_accuracy: 0.7809 - val_loss: 0.5355 - val_categorical_accuracy: 0.7819
#
# Epoch 00010: val_categorical_accuracy improved from 0.77849 to 0.78190, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 11/500
#  - 5s - loss: 0.5367 - categorical_accuracy: 0.7818 - val_loss: 0.5326 - val_categorical_accuracy: 0.7815
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.78190
# Epoch 12/500
#  - 5s - loss: 0.5337 - categorical_accuracy: 0.7797 - val_loss: 0.5428 - val_categorical_accuracy: 0.7845
#
# Epoch 00012: val_categorical_accuracy improved from 0.78190 to 0.78446, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 13/500
#  - 5s - loss: 0.5283 - categorical_accuracy: 0.7854 - val_loss: 0.5390 - val_categorical_accuracy: 0.7845
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.78446
# Epoch 14/500
#  - 5s - loss: 0.5204 - categorical_accuracy: 0.7869 - val_loss: 0.5253 - val_categorical_accuracy: 0.7819
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.78446
# Epoch 15/500
#  - 5s - loss: 0.5220 - categorical_accuracy: 0.7885 - val_loss: 0.5227 - val_categorical_accuracy: 0.7866
#
# Epoch 00015: val_categorical_accuracy improved from 0.78446 to 0.78660, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 16/500
#  - 5s - loss: 0.5163 - categorical_accuracy: 0.7918 - val_loss: 0.5195 - val_categorical_accuracy: 0.7896
#
# Epoch 00016: val_categorical_accuracy improved from 0.78660 to 0.78959, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 17/500
#  - 5s - loss: 0.5145 - categorical_accuracy: 0.7912 - val_loss: 0.5240 - val_categorical_accuracy: 0.7823
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.78959
# Epoch 18/500
#  - 5s - loss: 0.5130 - categorical_accuracy: 0.7927 - val_loss: 0.5255 - val_categorical_accuracy: 0.7857
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.78959
# Epoch 19/500
#  - 5s - loss: 0.5051 - categorical_accuracy: 0.7966 - val_loss: 0.5262 - val_categorical_accuracy: 0.7815
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.78959
# Epoch 20/500
#  - 5s - loss: 0.5103 - categorical_accuracy: 0.7919 - val_loss: 0.5158 - val_categorical_accuracy: 0.7896
#
# Epoch 00020: val_categorical_accuracy improved from 0.78959 to 0.78959, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 21/500
#  - 5s - loss: 0.4907 - categorical_accuracy: 0.7977 - val_loss: 0.5174 - val_categorical_accuracy: 0.7883
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.78959
# Epoch 22/500
#  - 5s - loss: 0.4929 - categorical_accuracy: 0.7996 - val_loss: 0.5170 - val_categorical_accuracy: 0.7900
#
# Epoch 00022: val_categorical_accuracy improved from 0.78959 to 0.79001, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 23/500
#  - 5s - loss: 0.4892 - categorical_accuracy: 0.8049 - val_loss: 0.5180 - val_categorical_accuracy: 0.7870
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.79001
# Epoch 24/500
#  - 5s - loss: 0.4919 - categorical_accuracy: 0.7999 - val_loss: 0.5182 - val_categorical_accuracy: 0.7892
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.79001
# Epoch 25/500
#  - 5s - loss: 0.4923 - categorical_accuracy: 0.7996 - val_loss: 0.5182 - val_categorical_accuracy: 0.7883
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.79001
# Epoch 26/500
#  - 5s - loss: 0.4906 - categorical_accuracy: 0.7977 - val_loss: 0.5167 - val_categorical_accuracy: 0.7904
#
# Epoch 00026: val_categorical_accuracy improved from 0.79001 to 0.79044, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 27/500
#  - 5s - loss: 0.4881 - categorical_accuracy: 0.7975 - val_loss: 0.5160 - val_categorical_accuracy: 0.7913
#
# Epoch 00027: val_categorical_accuracy improved from 0.79044 to 0.79129, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 28/500
#  - 5s - loss: 0.4862 - categorical_accuracy: 0.7977 - val_loss: 0.5179 - val_categorical_accuracy: 0.7879
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.79129
# Epoch 29/500
#  - 5s - loss: 0.4870 - categorical_accuracy: 0.7992 - val_loss: 0.5176 - val_categorical_accuracy: 0.7875
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.79129
# Epoch 30/500
#  - 5s - loss: 0.4846 - categorical_accuracy: 0.8050 - val_loss: 0.5176 - val_categorical_accuracy: 0.7917
#
# Epoch 00030: val_categorical_accuracy improved from 0.79129 to 0.79172, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 31/500
#  - 5s - loss: 0.4838 - categorical_accuracy: 0.8028 - val_loss: 0.5172 - val_categorical_accuracy: 0.7921
#
# Epoch 00031: val_categorical_accuracy improved from 0.79172 to 0.79215, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM4-embeddings.hdf5
# Epoch 32/500
#  - 5s - loss: 0.4873 - categorical_accuracy: 0.8044 - val_loss: 0.5174 - val_categorical_accuracy: 0.7892
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.79215
# Epoch 33/500
#  - 5s - loss: 0.4922 - categorical_accuracy: 0.7994 - val_loss: 0.5172 - val_categorical_accuracy: 0.7900
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.79215
# Epoch 34/500
#  - 5s - loss: 0.4879 - categorical_accuracy: 0.8007 - val_loss: 0.5196 - val_categorical_accuracy: 0.7921
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.79215
# Epoch 35/500
#  - 5s - loss: 0.4870 - categorical_accuracy: 0.8001 - val_loss: 0.5159 - val_categorical_accuracy: 0.7913
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.79215
# Epoch 36/500
#  - 5s - loss: 0.4866 - categorical_accuracy: 0.8014 - val_loss: 0.5165 - val_categorical_accuracy: 0.7904
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.79215
# Epoch 37/500
#  - 5s - loss: 0.4851 - categorical_accuracy: 0.8069 - val_loss: 0.5171 - val_categorical_accuracy: 0.7896
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.79215
# Epoch 38/500
#  - 5s - loss: 0.4814 - categorical_accuracy: 0.8057 - val_loss: 0.5184 - val_categorical_accuracy: 0.7909
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.79215
# Epoch 39/500
#  - 5s - loss: 0.4891 - categorical_accuracy: 0.8001 - val_loss: 0.5166 - val_categorical_accuracy: 0.7887
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.79215
# Epoch 40/500
#  - 5s - loss: 0.4807 - categorical_accuracy: 0.8053 - val_loss: 0.5174 - val_categorical_accuracy: 0.7909
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.79215

# %%
loss = model_google_trained.history['loss']
val_loss = model_google_trained.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = model_google_trained.history['categorical_accuracy']
val_acc = model_google_trained.history['val_categorical_accuracy']
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# It looks like best LSTM model is achieved by twitter-pretrained embeddings (similarly as ML models score).
# Google embeddings seem to provide slightly worse result.
# Now I will try to use the combination of LSTM and CNN. The CNN-LSTM are commonly used for the sequence of images use cases.
# However I have seen online, the approaches for CNN-LSTM classification based on text sequences.
# The intuition behind is that the convolution layer
# is able to extract better local features using Max Pooling then representing them via Embedding Layer.

# %% [markdown]
# ## Model 5 - CNN-LSTM based on pretrained embeddings trained on twitter400 dataset

# %%
model_twitter_CNN = Sequential()
model_twitter_CNN.add(embedding_layer_twitter_pr)
model_twitter_CNN.add(Dropout(0.3))
model_twitter_CNN.add(Conv1D(filters=24, kernel_size=2, padding='same', activation='relu'))
model_twitter_CNN.add(MaxPooling1D(pool_size=2))
model_twitter_CNN.add(Dropout(0.3))
model_twitter_CNN.add(CuDNNLSTM(16))
model_twitter_CNN.add(Dropout(0.2))
model_twitter_CNN.add(Dense(3, activation='softmax'))
optimizer = RMSprop(lr=0.0001)
model_twitter_CNN.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])
print(model_twitter_CNN.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 22, 400)           3283600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 22, 400)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 22, 24)            19224
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 11, 24)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 11, 24)            0
# _________________________________________________________________
# cu_dnnlstm_3 (CuDNNLSTM)     (None, 16)                2688
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 3,305,563
# Trainable params: 21,963
# Non-trainable params: 3,283,600
# _________________________________________________________________
# None

# %%
def scheduler(epoch):
    if epoch == 50:
        K.set_value(model_twitter_CNN.optimizer.lr, .00001)
    if epoch == 200:
        K.set_value(model_twitter_CNN.optimizer.lr, .000001)
    return K.get_value(model_twitter_CNN.optimizer.lr)

print('Train...')
#with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:


checkpoint = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5', monitor="val_categorical_accuracy", save_best_only=True, mode='max', verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=20)
change_lr = LearningRateScheduler(scheduler)
callbacks_list = [checkpoint, early_stopping, change_lr]

model_twitter_CNN_trained=model_twitter_CNN.fit(trainX_DL, 
                                                trainY_DL, 
                                                batch_size=16,
                                                callbacks=callbacks_list,                      
                                                epochs=500,                       
                                                validation_data=(valX_DL, valY_DL), 
                                                verbose=2)
# Out:
# Train...
# Train on 9369 samples, validate on 2343 samples
# Epoch 1/500
#  - 5s - loss: 0.8781 - categorical_accuracy: 0.6213 - val_loss: 0.8041 - val_categorical_accuracy: 0.6500
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.65002, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 2/500
#  - 4s - loss: 0.7974 - categorical_accuracy: 0.6579 - val_loss: 0.7194 - val_categorical_accuracy: 0.7051
#
# Epoch 00002: val_categorical_accuracy improved from 0.65002 to 0.70508, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 3/500
#  - 4s - loss: 0.7381 - categorical_accuracy: 0.6992 - val_loss: 0.6518 - val_categorical_accuracy: 0.7482
#
# Epoch 00003: val_categorical_accuracy improved from 0.70508 to 0.74819, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 4/500
#  - 4s - loss: 0.6889 - categorical_accuracy: 0.7231 - val_loss: 0.6138 - val_categorical_accuracy: 0.7606
#
# Epoch 00004: val_categorical_accuracy improved from 0.74819 to 0.76056, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 5/500
#  - 4s - loss: 0.6619 - categorical_accuracy: 0.7376 - val_loss: 0.5887 - val_categorical_accuracy: 0.7721
#
# Epoch 00005: val_categorical_accuracy improved from 0.76056 to 0.77209, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 6/500
#  - 4s - loss: 0.6383 - categorical_accuracy: 0.7487 - val_loss: 0.5750 - val_categorical_accuracy: 0.7759
#
# Epoch 00006: val_categorical_accuracy improved from 0.77209 to 0.77593, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 7/500
#  - 4s - loss: 0.6227 - categorical_accuracy: 0.7494 - val_loss: 0.5651 - val_categorical_accuracy: 0.7789
#
# Epoch 00007: val_categorical_accuracy improved from 0.77593 to 0.77892, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 8/500
#  - 4s - loss: 0.6081 - categorical_accuracy: 0.7570 - val_loss: 0.5516 - val_categorical_accuracy: 0.7849
#
# Epoch 00008: val_categorical_accuracy improved from 0.77892 to 0.78489, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 9/500
#  - 4s - loss: 0.5986 - categorical_accuracy: 0.7617 - val_loss: 0.5457 - val_categorical_accuracy: 0.7828
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.78489
# Epoch 10/500
#  - 4s - loss: 0.5877 - categorical_accuracy: 0.7649 - val_loss: 0.5393 - val_categorical_accuracy: 0.7857
#
# Epoch 00010: val_categorical_accuracy improved from 0.78489 to 0.78574, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 11/500
#  - 4s - loss: 0.5869 - categorical_accuracy: 0.7630 - val_loss: 0.5308 - val_categorical_accuracy: 0.7870
#
# Epoch 00011: val_categorical_accuracy improved from 0.78574 to 0.78703, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 12/500
#  - 4s - loss: 0.5815 - categorical_accuracy: 0.7665 - val_loss: 0.5279 - val_categorical_accuracy: 0.7870
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.78703
# Epoch 13/500
#  - 4s - loss: 0.5713 - categorical_accuracy: 0.7715 - val_loss: 0.5222 - val_categorical_accuracy: 0.7849
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.78703
# Epoch 14/500
#  - 4s - loss: 0.5659 - categorical_accuracy: 0.7731 - val_loss: 0.5171 - val_categorical_accuracy: 0.7896
#
# Epoch 00014: val_categorical_accuracy improved from 0.78703 to 0.78959, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 15/500
#  - 4s - loss: 0.5552 - categorical_accuracy: 0.7786 - val_loss: 0.5144 - val_categorical_accuracy: 0.7887
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.78959
# Epoch 16/500
#  - 4s - loss: 0.5588 - categorical_accuracy: 0.7774 - val_loss: 0.5183 - val_categorical_accuracy: 0.7956
#
# Epoch 00016: val_categorical_accuracy improved from 0.78959 to 0.79556, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 17/500
#  - 4s - loss: 0.5517 - categorical_accuracy: 0.7770 - val_loss: 0.5126 - val_categorical_accuracy: 0.7951
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.79556
# Epoch 18/500
#  - 5s - loss: 0.5505 - categorical_accuracy: 0.7793 - val_loss: 0.5086 - val_categorical_accuracy: 0.7930
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.79556
# Epoch 19/500
#  - 4s - loss: 0.5441 - categorical_accuracy: 0.7815 - val_loss: 0.5081 - val_categorical_accuracy: 0.7930
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.79556
# Epoch 20/500
#  - 4s - loss: 0.5415 - categorical_accuracy: 0.7822 - val_loss: 0.5067 - val_categorical_accuracy: 0.7981
#
# Epoch 00020: val_categorical_accuracy improved from 0.79556 to 0.79812, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 21/500
#  - 4s - loss: 0.5286 - categorical_accuracy: 0.7866 - val_loss: 0.5030 - val_categorical_accuracy: 0.7960
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.79812
# Epoch 22/500
#  - 4s - loss: 0.5352 - categorical_accuracy: 0.7861 - val_loss: 0.5022 - val_categorical_accuracy: 0.7964
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.79812
# Epoch 23/500
#  - 4s - loss: 0.5313 - categorical_accuracy: 0.7885 - val_loss: 0.5010 - val_categorical_accuracy: 0.7985
#
# Epoch 00023: val_categorical_accuracy improved from 0.79812 to 0.79855, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 24/500
#  - 4s - loss: 0.5283 - categorical_accuracy: 0.7891 - val_loss: 0.4995 - val_categorical_accuracy: 0.7994
#
# Epoch 00024: val_categorical_accuracy improved from 0.79855 to 0.79940, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 25/500
#  - 4s - loss: 0.5247 - categorical_accuracy: 0.7871 - val_loss: 0.4980 - val_categorical_accuracy: 0.7998
#
# Epoch 00025: val_categorical_accuracy improved from 0.79940 to 0.79983, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 26/500
#  - 4s - loss: 0.5259 - categorical_accuracy: 0.7919 - val_loss: 0.5003 - val_categorical_accuracy: 0.8015
#
# Epoch 00026: val_categorical_accuracy improved from 0.79983 to 0.80154, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 27/500
#  - 4s - loss: 0.5196 - categorical_accuracy: 0.7927 - val_loss: 0.4960 - val_categorical_accuracy: 0.7994
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.80154
# Epoch 28/500
#  - 4s - loss: 0.5204 - categorical_accuracy: 0.7921 - val_loss: 0.4944 - val_categorical_accuracy: 0.7998
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.80154
# Epoch 29/500
#  - 4s - loss: 0.5157 - categorical_accuracy: 0.7970 - val_loss: 0.4967 - val_categorical_accuracy: 0.8024
#
# Epoch 00029: val_categorical_accuracy improved from 0.80154 to 0.80239, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 30/500
#  - 4s - loss: 0.5099 - categorical_accuracy: 0.7967 - val_loss: 0.4937 - val_categorical_accuracy: 0.8020
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.80239
# Epoch 31/500
#  - 4s - loss: 0.5171 - categorical_accuracy: 0.7934 - val_loss: 0.5019 - val_categorical_accuracy: 0.7926
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.80239
# Epoch 32/500
#  - 4s - loss: 0.5057 - categorical_accuracy: 0.7973 - val_loss: 0.4918 - val_categorical_accuracy: 0.8007
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.80239
# Epoch 33/500
#  - 4s - loss: 0.5005 - categorical_accuracy: 0.8023 - val_loss: 0.4930 - val_categorical_accuracy: 0.8054
#
# Epoch 00033: val_categorical_accuracy improved from 0.80239 to 0.80538, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 34/500
#  - 4s - loss: 0.5053 - categorical_accuracy: 0.8021 - val_loss: 0.4924 - val_categorical_accuracy: 0.8037
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.80538
# Epoch 35/500
#  - 4s - loss: 0.4995 - categorical_accuracy: 0.8046 - val_loss: 0.4943 - val_categorical_accuracy: 0.7994
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.80538
# Epoch 36/500
#  - 4s - loss: 0.4961 - categorical_accuracy: 0.8055 - val_loss: 0.4915 - val_categorical_accuracy: 0.8084
#
# Epoch 00036: val_categorical_accuracy improved from 0.80538 to 0.80837, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 37/500
#  - 4s - loss: 0.4963 - categorical_accuracy: 0.8029 - val_loss: 0.4902 - val_categorical_accuracy: 0.8079
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.80837
# Epoch 38/500
#  - 4s - loss: 0.4975 - categorical_accuracy: 0.7993 - val_loss: 0.4902 - val_categorical_accuracy: 0.8088
#
# Epoch 00038: val_categorical_accuracy improved from 0.80837 to 0.80879, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 39/500
#  - 4s - loss: 0.4960 - categorical_accuracy: 0.8080 - val_loss: 0.4894 - val_categorical_accuracy: 0.8062
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.80879
# Epoch 40/500
#  - 4s - loss: 0.4911 - categorical_accuracy: 0.8049 - val_loss: 0.4909 - val_categorical_accuracy: 0.8028
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.80879
# Epoch 41/500
#  - 4s - loss: 0.4890 - categorical_accuracy: 0.8038 - val_loss: 0.4886 - val_categorical_accuracy: 0.8062
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.80879
# Epoch 42/500
#  - 4s - loss: 0.4857 - categorical_accuracy: 0.8113 - val_loss: 0.4891 - val_categorical_accuracy: 0.8041
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.80879
# Epoch 43/500
#  - 4s - loss: 0.4875 - categorical_accuracy: 0.8082 - val_loss: 0.4888 - val_categorical_accuracy: 0.8079
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.80879
# Epoch 44/500
#  - 4s - loss: 0.4790 - categorical_accuracy: 0.8109 - val_loss: 0.4878 - val_categorical_accuracy: 0.8084
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.80879
# Epoch 45/500
#  - 4s - loss: 0.4802 - categorical_accuracy: 0.8156 - val_loss: 0.4887 - val_categorical_accuracy: 0.8045
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.80879
# Epoch 46/500
#  - 4s - loss: 0.4822 - categorical_accuracy: 0.8107 - val_loss: 0.4860 - val_categorical_accuracy: 0.8088
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.80879
# Epoch 47/500
#  - 4s - loss: 0.4747 - categorical_accuracy: 0.8139 - val_loss: 0.4875 - val_categorical_accuracy: 0.8054
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.80879
# Epoch 48/500
#  - 4s - loss: 0.4734 - categorical_accuracy: 0.8103 - val_loss: 0.4875 - val_categorical_accuracy: 0.8079
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.80879
# Epoch 49/500
#  - 4s - loss: 0.4727 - categorical_accuracy: 0.8131 - val_loss: 0.4869 - val_categorical_accuracy: 0.8101
#
# Epoch 00049: val_categorical_accuracy improved from 0.80879 to 0.81007, saving model to /content/gdrive/My Drive/Colab Notebooks/LSTM5-embeddings.hdf5
# Epoch 50/500
#  - 4s - loss: 0.4695 - categorical_accuracy: 0.8197 - val_loss: 0.4882 - val_categorical_accuracy: 0.8050
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.81007
# Epoch 51/500
#  - 4s - loss: 0.4670 - categorical_accuracy: 0.8142 - val_loss: 0.4871 - val_categorical_accuracy: 0.8075
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.81007
# Epoch 52/500
#  - 4s - loss: 0.4708 - categorical_accuracy: 0.8158 - val_loss: 0.4871 - val_categorical_accuracy: 0.8079
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.81007
# Epoch 53/500
#  - 4s - loss: 0.4683 - categorical_accuracy: 0.8140 - val_loss: 0.4869 - val_categorical_accuracy: 0.8088
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.81007
# Epoch 54/500
#  - 4s - loss: 0.4726 - categorical_accuracy: 0.8143 - val_loss: 0.4869 - val_categorical_accuracy: 0.8075
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.81007
# Epoch 55/500
#  - 4s - loss: 0.4636 - categorical_accuracy: 0.8163 - val_loss: 0.4866 - val_categorical_accuracy: 0.8075
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.81007
# Epoch 56/500
#  - 4s - loss: 0.4674 - categorical_accuracy: 0.8159 - val_loss: 0.4864 - val_categorical_accuracy: 0.8088
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.81007
# Epoch 57/500
#  - 4s - loss: 0.4658 - categorical_accuracy: 0.8173 - val_loss: 0.4865 - val_categorical_accuracy: 0.8088
#
# Epoch 00057: val_categorical_accuracy did not improve from 0.81007
# Epoch 58/500
#  - 4s - loss: 0.4691 - categorical_accuracy: 0.8187 - val_loss: 0.4863 - val_categorical_accuracy: 0.8096
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.81007
# Epoch 59/500
#  - 4s - loss: 0.4698 - categorical_accuracy: 0.8161 - val_loss: 0.4863 - val_categorical_accuracy: 0.8084
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.81007
# Epoch 60/500
#  - 4s - loss: 0.4681 - categorical_accuracy: 0.8113 - val_loss: 0.4866 - val_categorical_accuracy: 0.8092
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.81007
# Epoch 61/500
#  - 4s - loss: 0.4683 - categorical_accuracy: 0.8183 - val_loss: 0.4862 - val_categorical_accuracy: 0.8079
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.81007
# Epoch 62/500
#  - 4s - loss: 0.4595 - categorical_accuracy: 0.8193 - val_loss: 0.4863 - val_categorical_accuracy: 0.8079
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.81007
# Epoch 63/500
#  - 4s - loss: 0.4706 - categorical_accuracy: 0.8141 - val_loss: 0.4867 - val_categorical_accuracy: 0.8088
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.81007
# Epoch 64/500
#  - 4s - loss: 0.4646 - categorical_accuracy: 0.8172 - val_loss: 0.4864 - val_categorical_accuracy: 0.8079
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.81007
# Epoch 65/500
#  - 4s - loss: 0.4620 - categorical_accuracy: 0.8178 - val_loss: 0.4865 - val_categorical_accuracy: 0.8088
#
# Epoch 00065: val_categorical_accuracy did not improve from 0.81007
# Epoch 66/500
#  - 4s - loss: 0.4688 - categorical_accuracy: 0.8135 - val_loss: 0.4862 - val_categorical_accuracy: 0.8084
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.81007

# %%
loss = model_twitter_CNN_trained.history['loss']
val_loss = model_twitter_CNN_trained.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = model_twitter_CNN_trained.history['categorical_accuracy']
val_acc = model_twitter_CNN_trained.history['val_categorical_accuracy']
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# CNN-LSTM architecture reached exactly the same accuracy as my 2-layer LSTM model :).
# For prediction on the test set I will use the LSTM model from point 2.3.

# %% [markdown]
# ## Prediction done on test set using best LSTM

# %%
#  Load weights
model=keras.models.load_model('/content/gdrive/My Drive/Colab Notebooks/LSTM3_alt_embeddings.hdf5')
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[categorical_accuracy])

# %%
# make predictions
yhat = model.predict(x_test_seq_pad, verbose=0)

# %%
#Define normlized confusion matrix plot

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    #plt.grid('off')
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    #classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=0)[np.newaxis, :]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='Predicted label',
           xlabel='True label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    ax.grid(False)
    return ax

# %%
plot_confusion_matrix(Y_test.tolist(), np.argmax(yhat,axis=1).tolist(), classes=['Negative','Medium','Positive'], normalize=True,
                      title='Normalized confusion matrix')
print()
print('Accuracy score:',accuracy_score(Y_test.tolist(), np.argmax(yhat,axis=1).tolist()))
None
# Out:
# Normalized confusion matrix
# [[0.850361 0.242086 0.125828]
#  [0.111971 0.651769 0.143488]
#  [0.037668 0.106145 0.730684]]
#
# Accuracy score: 0.7954234972677595

# %% [markdown]
# Looking at the test sample my prediction increased from 78.2% (ML model) to **79.5%** (LSTM model). On validation I reached a bit more, which means I could slighly overfit to validation sample choosing different LSTM parameters. I expected a bit more but almost 1.5% improvement might be also considered as going into good direction.
# Now I move to ULMFIT modelling.

# %% [markdown]
# # Modelling - Deep Learning - ULMFIT

# %% [markdown]
# ## ULMFIT 1 - learned on cleaned by me twitter text

# %% [markdown]
# After experimenting with LSTM models and reaching 79.5% accuracy, I move to ULMFIT.
#
# Watching fast.ai videos and reading forum a bit I try to understand how ULMFIT works.
# I understand its processing is divided into two main steps:
# * Language Model Tuning - here the language model trained on wikipedia is fine-tuned on my data
#   * Slanted Triangular Learning Rates - the changing learning rate should dynamically adjust to learning process.
#     The algorithm quickly converges to searched optimization local area (increasing Learning Rate) and then algortihm tries to find optimum there in this region doing it slower (decreasing Learning Rate).
#   * Discriminative Fine-Tuning - Learning rate is varied across hidden layers as they represent other information and require other learning process pace.
# * Classifier Tuning - here I take my Language Model network, put my softmax layer for sentiment classification instead of language model classification (in simple terms).
#   * Concat Pooling - I take maxpooling and averagepooling and use them together to screen words in sequences.
#   * BPT3C - BPTT extension to capture not the fixed size chunks but the whole tweet.
#   * Gradual Unfreezing - Instead of learning everything at once, we teach gradually the hidden layers to preserve the benefit of wikipedia pretraining structure in the network.
#
# <br>Quite a lot  to grasp :), happy to learn more further. </br>
#
# Having not much experience with this kind of model I do not have specified expectations. Intuition tells me that:
# * The model during a few epochs will achieve the 80% as I did in LSTM  for dozens of epochs.
# * I am not sure if for my shallow vocabulary and small dataset, the multi layer hidden weights transfer learning will show its full potential, therefore I do not expect huge jump in accuracy.
#
# Mostly I follow the Jeremy's IMDB example.

# %% [markdown]
# ### Prepare the dataset

# %%
# Install the libraries
# !pip install torch_nightly -f https://download.pytorch.org/whl/nightly/cu92/torch_nightly.html
# !pip install fastai
# Out:
# Looking in links: https://download.pytorch.org/whl/nightly/cu92/torch_nightly.html
# Collecting torch_nightly
#   Downloading https://download.pytorch.org/whl/nightly/cu92/torch_nightly-1.0.0.dev20181206-cp36-cp36m-linux_x86_64.whl (576.2MB)
#     100% |████████████████████████████████| 576.2MB 27kB/s
# Installing collected packages: torch-nightly
# Successfully installed torch-nightly-1.0.0.dev20181206
# Requirement already satisfied: fastai in /usr/local/lib/python3.6/dist-packages (1.0.46)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from fastai) (1.0.1.post2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from fastai) (0.2.2.post3)
# Requirement already satisfied: nvidia-ml-py3 in /usr/local/lib/python3.6/dist-packages (from fastai) (7.352.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from fastai) (19.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai) (3.0.3)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.6/dist-packages (from fastai) (1.2.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai) (4.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fastai) (3.13)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from fastai) (3.6.6)
# Requirement already satisfied: fastprogress>=0.1.19 in /usr/local/lib/python3.6/dist-packages (from fastai) (0.1.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fastai) (2.18.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from fastai) (4.6.3)
# Requirement already satisfied: spacy>=2.0.18 in /usr/local/lib/python3.6/dist-packages (from fastai) (2.0.18)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from fastai) (0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai) (0.22.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.6/dist-packages (from fastai) (2.6.9)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from fastai) (1.16.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision->fastai) (1.11.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->fastai) (2.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai) (2.5.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->fastai) (0.46)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (2018.11.29)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (1.22)
# Requirement already satisfied: regex==2018.01.10 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (2018.1.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (2.0.2)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (1.35)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (2.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (1.0.2)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (0.9.6)
# Requirement already satisfied: dill<0.3,>=0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (0.2.9)
# Requirement already satisfied: thinc<6.13.0,>=6.12.1 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (6.12.1)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->fastai) (2018.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib->fastai) (40.8.0)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.9.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (4.28.1)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (1.10.11)
# Requirement already satisfied: msgpack-numpy<0.4.4 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.4.3.2)
# Requirement already satisfied: msgpack<0.6.0,>=0.5.6 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.5.6)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.9.0)

# %%
# I converrt data frame to suggeted structure Labels, Texts
# I take the previously defined train sample.

train_ULMFIT = Y_train.to_frame().merge(pd.DataFrame(X_train['cleaned_text_joined']), left_index=True, right_index=True)
train_ULMFIT.columns=['labels','text']
train_ULMFIT.shape
# Out:
# (11712, 2)

# %%
train_ULMFIT.head(5)
# Out:
#        labels                                               text
# 4058        2  amaze fly mile unitedairlines amp alliance las...
# 382         1                need receipt flight change send one
# 1668        2                     finally make rep solve problem
# 3766        1  southwest u mechanical problem least give u ro...
# 12677       0  airport extra night hotel heard anything embar...

# %%
# I  split the training into train and validation again.
# As I do not fully know what is done under the hood I do not want to overfit to test set with chosen hyper-parameters.
# I keep test set aside and compare model results against validation set.

train_ULMFIT_, val_ULMFIT_ = train_test_split(train_ULMFIT, 
                                              test_size = 0.2, 
                                              random_state = 88)

# %%
train_ULMFIT_.shape,val_ULMFIT_.shape
# Out:
# ((9369, 2), (2343, 2))

# %%
train_ULMFIT_.head()
# Out:
#       labels                                               text
# 9119       0                          pretty sure actually take
# 1921       1  de ice tax maybe makestoomuchsense shouldhavef...
# 1809       0  biz day calendar respond inquiry hope standard...
# 5928       0  pricing cache book flight refresh page amp pri...
# 3721       0  vegan meal creative noodle pea zukes non vegan...

# %% [markdown]
# ### Fine-tuning language model

# %% [markdown]
# I use the TextLMDataBunch method which do the tokenization under the hood. I input my conseratively cleaned tweet text for this function.

# %%
# Language model data
data_lm = TextLMDataBunch.from_df('./', train_ULMFIT_,val_ULMFIT_)
data_lm
# Out:
# TextLMDataBunch;
#
# Train: LabelList (9369 items)
# x: LMTextList
# xxbos pretty sure actually take,xxbos de ice tax maybe xxunk shouldhaveflowndelta unitedsucks,xxbos biz day calendar respond inquiry hope standard xxunk adopt badcustomerservice,xxbos pricing cache book flight refresh page amp price jumped ridiculous,xxbos vegan meal creative xxunk xxunk xxunk non vegan xxunk acceptable vegan well
# y: LMLabelList
# ,,,,
# Path: .;
#
# Valid: LabelList (2343 items)
# x: LMTextList
# xxbos new ceo seek right balance please passenger wall xxunk daily xxunk,xxbos oh get ticket,xxbos xxunk aa take hr call back end pay extra statement true,xxbos please explain cost almost price full roundtrip fair change departure time flight,xxbos except wait time phone system hang continue hold help
# y: LMLabelList
# ,,,,
# Path: .;
#
# Test: None

# %%
# Vocabulary - first 20 words
data_lm.vocab.itos[:20]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  'flight',
#  'get',
#  'hour',
#  'u',
#  'thanks',
#  'cancel',
#  'time',
#  'service',
#  'help',
#  'customer',
#  'call',
#  'go']

# %% [markdown]
# We can see here the new tags specified by fast.ai tokenizer:
# * xxbos: begining of a sentence
# * xxfld: separate parts of a document
# * xxup: capitalization
# * xxunk: uncommon words
# * xxmaj: first letter up
# * xxrep: reapeated characters

# %%
len(data_lm.vocab.itos)
# Out:
# 3635

# %%
learn1 = language_model_learner(data_lm, AWD_LSTM, drop_mult=0.5)
learn1.fit_one_cycle(1, 1e-2)
# Out:
# Total time: 00:07 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>8.359239</td>
#       <td>7.090025</td>
#       <td>0.042336</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn1.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn1.recorder.plot()

# %% [markdown]
# Here is my learning rate for language model which adapsts the idea of "Cyclical Learning Rates".
# Having my learning rate I learn 1 epoch of my language model choosing such rate which still drops the learning rate value but is enough distance to minimum (here 1e-02).

# %%
learn1.fit_one_cycle(1, 1e-2, moms=(0.8,0.7)) #1e-2 looks like good choice, learning rate is decreasing and still not the closest to minimum
# Out:
# Total time: 00:07 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.871571</td>
#       <td>6.181429</td>
#       <td>0.104278</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# I unfreeze whole network and learn 5 epochs (later it does not improve)

# %%
learn1.unfreeze()
learn1.fit_one_cycle(5, 5e-3, moms=(0.8,0.7)) #let's get a bit further from the minimum with learning rate (5e-3)
# Out:
# Total time: 00:47 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.267880</td>
#       <td>5.848715</td>
#       <td>0.138690</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.194613</td>
#       <td>5.689003</td>
#       <td>0.152195</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.944240</td>
#       <td>5.548275</td>
#       <td>0.161719</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.705519</td>
#       <td>5.517415</td>
#       <td>0.162574</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.509694</td>
#       <td>5.527777</td>
#       <td>0.162909</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save learning model.
learn1.save('fine_tuned')
learn1.save_encoder('fine_tuned_enc') # this encoder is used for classification tuning

# %% [markdown]
# ### Fine-tuning classification model

# %%
# Similarly as previously, I create the object of tokenized words + this time also having my Y response vector ready for classification.

data_clas = TextClasDataBunch.from_df('./', train_ULMFIT_,val_ULMFIT_, vocab=data_lm.train_ds.vocab, bs=32)
data_clas
# Out:
# TextClasDataBunch;
#
# Train: LabelList (9369 items)
# x: TextList
# xxbos pretty sure actually take,xxbos de ice tax maybe xxunk shouldhaveflowndelta unitedsucks,xxbos biz day calendar respond inquiry hope standard xxunk adopt badcustomerservice,xxbos pricing cache book flight refresh page amp price jumped ridiculous,xxbos vegan meal creative xxunk xxunk xxunk non vegan xxunk acceptable vegan well
# y: CategoryList
# 0,1,0,0,0
# Path: .;
#
# Valid: LabelList (2343 items)
# x: TextList
# xxbos new ceo seek right balance please passenger wall xxunk daily xxunk,xxbos oh get ticket,xxbos xxunk aa take hr call back end pay extra statement true,xxbos please explain cost almost price full roundtrip fair change departure time flight,xxbos except wait time phone system hang continue hold help
# y: CategoryList
# 1,1,0,0,0
# Path: .;
#
# Test: None

# %%
data_clas.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos rude cust xxunk agent busy chat yell bc take pic put xxunk seat diff agent give seat min late flightr platinum</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos delayed hr flight pit iad finally board plane sit half hour amp crew hr limit amp deplane unacceptable</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos i m try call book reward ticket one world partner automate system wo nt let talk great job</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos basically need leave hawaii late flight even midnight get back philly late flight monday night trip get tues</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>xxbos hr tarmac yest b cancel flight today hr delay send txt email jfk close amp save trip sit</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Let's see the structure of the model
learn1 = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5)
learn1.load_encoder('fine_tuned_enc')

# %%
list(learn1.model.children())
# Out:
# [MultiBatchEncoder(
#    (module): AWD_LSTM(
#      (encoder): Embedding(3635, 400, padding_idx=1)
#      (encoder_dp): EmbeddingDropout(
#        (emb): Embedding(3635, 400, padding_idx=1)
#      )
#      (rnns): ModuleList(
#        (0): WeightDropout(
#          (module): LSTM(400, 1150, batch_first=True)
#        )
#        (1): WeightDropout(
#          (module): LSTM(1150, 1150, batch_first=True)
#        )
#        (2): WeightDropout(
#          (module): LSTM(1150, 400, batch_first=True)
#        )
#      )
#      (input_dp): RNNDropout()
#      (hidden_dps): ModuleList(
#        (0): RNNDropout()
#        (1): RNNDropout()
#        (2): RNNDropout()
#      )
#    )
#  ), PoolingLinearClassifier(
#    (layers): Sequential(
#      (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (1): Dropout(p=0.2)
#      (2): Linear(in_features=1200, out_features=50, bias=True)
#      (3): ReLU(inplace)
#      (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (5): Dropout(p=0.1)
#      (6): Linear(in_features=50, out_features=3, bias=True)
#    )
#  )]

# %% [markdown]
# Quite complex architecture for me. Need study a bit to understand it. The architecture looks as follows:
#
# * Embedding layer trained on wikitext103 and fine tuned in language model stage. (it should be similar to Word2vec learned on wikipedia available on _gensim_ website).
# * Three-layer LSTM  cells trained on wikitext again and tuned in previous step. (In LSTM section I stacked maximum 2 layers).
# * Two linear layers to transform high dimensions to number of prediction classes. (similar to dense I think).
# A lot of regularization happens here including dropouts and batch normalization.

# %%
# Looking for Learning rate for the classification model
learn1.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn1.recorder.plot()

# %%
#Applying gradual unfreezing for the tuning process
learn1.fit_one_cycle(1, 1e-2)
learn1.save('first')
# Out:
# Total time: 00:10 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.773841</td>
#       <td>0.611324</td>
#       <td>0.743918</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn1.load('first');
learn1.freeze_to(-2)
learn1.fit_one_cycle(1, slice(1e-2/(2.6**4), 1e-2))
learn1.save('second')
# Out:
# Total time: 00:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.690841</td>
#       <td>0.586456</td>
#       <td>0.758429</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn1.load('second')
learn1.freeze_to(-3)
learn1.fit_one_cycle(1, slice(5e-3/(2.6**4),5e-3))
learn1.save('third')
# Out:
# Total time: 00:19 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.638488</td>
#       <td>0.573238</td>
#       <td>0.772514</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn1.load('third');
learn1.unfreeze()
learn1.fit_one_cycle(5, 1e-3, callbacks=[callbacks.SaveModelCallback(learn1, every='improvement', monitor='accuracy', name='best')])
# Out:
# Total time: 02:08 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.649485</td>
#       <td>0.560210</td>
#       <td>0.771660</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.597899</td>
#       <td>0.517203</td>
#       <td>0.791293</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.556742</td>
#       <td>0.518161</td>
#       <td>0.799829</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.491365</td>
#       <td>0.502915</td>
#       <td>0.799829</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.464773</td>
#       <td>0.497091</td>
#       <td>0.808365</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 1 with accuracy value: 0.7716602683067322.
# Better model found at epoch 2 with accuracy value: 0.791293203830719.
# Better model found at epoch 3 with accuracy value: 0.7998293042182922.
# Better model found at epoch 5 with accuracy value: 0.8083653450012207.

# %% [markdown]
# I did not train the model further (it produced massive overfitting). Setting different parameters of fit_one_cycle function did not improved the overfitting issue. I would need to optimize these parameters (wd, slice momentum) in some way, but now I do not have the tools to do it.
# So I consider that this is not tuned ULMFIT model. Almost 81% on validation looks promising.
# Now I will test this model against the test set.

# %% [markdown]
# ### Test set accuracy

# %%
# Prepare the test set in specific format (labels, text)
test_ULMFIT = Y_test.to_frame().merge(pd.DataFrame(X_test['cleaned_text_joined']), left_index=True, right_index=True)
test_ULMFIT.columns=['labels','text']
test_ULMFIT.shape
# Out:
# (2928, 2)

# %%
test_ULMFIT.head(10)
# Out:
#        labels                                               text
# 1022        2                         soon do article thanks tom
# 11109       2                                                lol
# 682         0  luckily make flight time disappointed lack com...
# 9981        0                         cancel flight every flight
# 13686       0  word failure mean act instance fail prove unsu...
# 13568       0  try reach american airline since last even can...
# 13363       0  get travel question answer quickly online call...
# 13138       2  thank help p guy best americanairlines america...
# 12291       1  forgot select ksml flight la minute hour mark ...
# 7757        0  hey jetblue strand entire plane suppose go jfk...

# %%
# Read the best model from 10 I have learned
learn1.load('best')
None

# %%
# Predict the using 'text' column
test_ULMFIT['Prediction'] = test_ULMFIT['text'].apply(lambda row: str(learn1.predict(row)[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3265f1d70105> in <module>
#       1 # Make the predictions
# ----> 2 test_ULMFIT['Prediction'] = test_ULMFIT['text'].apply(lambda row: str(learn1.predict(row)[0]))
#
# NameError: name 'test_ULMFIT' is not defined

# %%
test_ULMFIT.head(10)
# Out:
#        labels                                               text Prediction
# 1022        2                         soon do article thanks tom          2
# 11109       2                                                lol          2
# 682         0  luckily make flight time disappointed lack com...          0
# 9981        0                         cancel flight every flight          0
# 13686       0  word failure mean act instance fail prove unsu...          0
# 13568       0  try reach american airline since last even can...          0
# 13363       0  get travel question answer quickly online call...          0
# 13138       2  thank help p guy best americanairlines america...          2
# 12291       1  forgot select ksml flight la minute hour mark ...          0
# 7757        0  hey jetblue strand entire plane suppose go jfk...          0

# %%
# Plot normalized confusion matrix
plot_confusion_matrix(test_ULMFIT['labels'].astype(int), test_ULMFIT['Prediction'].astype(int), classes=['Negative','Medium','Positive'], normalize=True,
                      title='Normalized confusion matrix')
print()
print('Accuracy score:',accuracy_score(test_ULMFIT['labels'].astype(int), test_ULMFIT['Prediction'].astype(int)))
None
# Out:
# Normalized confusion matrix
# [[0.84     0.236515 0.091928]
#  [0.123    0.659751 0.152466]
#  [0.037    0.103734 0.755605]]
#
# Accuracy score: 0.7974726775956285

# %% [markdown]
# I reached with ULMfit (**79.74%**) similar accuracy to my best LSTM network (**79.54%**). Quite good result which is achievable in first 5 epochs.
# Probably with this way of preparing the twitter text data, I reached the ceiling of predictive power. I end here the search of an optimal algorithm. So far I got the following scores checked on 20% test sample:
# * Best Machine Learning Algorithm - Logistic regression (twitter pretrained embeddings) found by TPOT - 78.2%
# * Best LSTM network (2 hidden layers, unidirectional, 50 unit LSTM) - 79.54%
# * UMLFIT - 79.74%
#
# As next step I will try to change my X matrix (twitter text) so that it better captures semantic characteristics,
# I will use ULMFIT for next experiments as I get very good results very quickly training a few epochs only.

# %% [markdown]
# ##  ULMFIT 2 - Changing the cleaning of the twitter text

# %% [markdown]
# Instead of cleaning twitter text in classical NLP way (lower cases, lemmatization etc. ) I will use fast.ai tokenizer. I used it before in previous section, but I used it on text which has been preprocessed before using clean_text_full function. Due to that, I probably lost some meaningful piece of information. Now I will use lighter cleansing approach, removing the twitter user and https only. Then applying fast.ai tokenizer.

# %% [markdown]
# ### Prepare the dataset

# %%
def clean_tweets_light(tweet):
    # remove the owner
    tweet = re.sub(r'@[A-Za-z0-9]+','', tweet)
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    return tweet

# %%
df_tweet['text_ulmfit2']=df_tweet['text']

# %%
X_train_ULMFIT2, X_test_ULMFIT2, Y_train_ULMFIT2, Y_test_ULMFIT2 = train_test_split(df_tweet['text'].apply(lambda x: clean_tweets_light(x)), df_tweet['airline_sentiment'].astype('category').cat.codes, test_size=0.2, random_state=88)

# %%
X_train_ULMFIT2.shape, X_test_ULMFIT2.shape
# Out:
# ((11712,), (2928,))

# %%
# Show exemplary tweets - cleaned lightly
pd.set_option('display.max_colwidth', -1)
train_ULMFIT2 = Y_train_ULMFIT2.to_frame().merge(pd.DataFrame(X_train_ULMFIT2), left_index=True, right_index=True)
train_ULMFIT2.columns=['labels','text']
print(f'Shape : {train_ULMFIT2.shape}')
train_ULMFIT2.sample(5)
# Out:
# Shape : (11712, 2)
#       labels  \
# 6117  2
# 4332  0
# 2353  0
# 6408  0
# 5839  1
#
#                                                                                                                                           text
# 6117   thank u for not leaving me \n nice job running thru the airport to catch your connecting flight
# 4332   your agents were the ones who were rude and unhelpful and prompted my initial tweet. This is so easy to fix.
# 2353   who is in charge of making decisions over there? Cancelled Flightling flight UA1150 was unacceptable. I should be in #Belize right now.
# 6408   you're 4/4 on blowing it with your customer service. Shotwest Airlines.
# 5839   please reply to my DM ♥️

# %% [markdown]
# The texts looks much wealthier now.

# %%
# Split the training into training and validation
train_ULMFIT2_, val_ULMFIT2_ = train_test_split(train_ULMFIT2, 
                                                test_size = 0.2, 
                                                random_state = 88)

# %%
train_ULMFIT2_.shape
# Out:
# (9369, 2)

# %% [markdown]
# ### Fine-tuning language model

# %%
# Tokenize the words for LM
data_lm2 = TextLMDataBunch.from_df('./', train_ULMFIT2_,val_ULMFIT2_)
data_lm2
# Out:
# TextLMDataBunch;
#
# Train: LabelList (9369 items)
# x: LMTextList
# xxbos pretty sure we did n't actually take off at xxunk,xxbos why de - ice before taxing ? xxmaj maybe it # xxunk ? # shouldhaveflowndelta # unitedsucks,xxbos xxmaj only 14 biz days ( 18 calendar ) to respond to my xxunk ? i hope your standards are xxunk adopted : - / # badcustomerservice,xxbos xxmaj what 's with the pricing xxunk ? ! xxmaj about to book a flight , refreshed the page , & & the price jumped from $ 73 to $ xxunk . xxmaj ridiculous . 😑,xxbos # vegan meals can be more creative than xxunk , xxunk , and xxunk . xxmaj non - vegan xxunk is not acceptable for a vegan . xxmaj can you do better ?
# y: LMLabelList
# ,,,,
# Path: .;
#
# Valid: LabelList (2343 items)
# x: LMTextList
# xxbos 's new xxup ceo seeks the right balance to please passengers and xxmaj wall ... - xxmaj xxunk xxmaj daily xxmaj xxunk,xxbos how oh how do we get tickets ! ? !,xxbos xxmaj only xxunk because aa took 2 hrs to call me back . xxmaj ended up paying ( extra ) in $ xxup us so above statement not true,xxbos xxmaj please explain why it costs almost the same price of a full roundtrip fair to only change the departure time of a flight ?,xxbos xxmaj except now there is no wait time , the phone system just hangs up on you . xxmaj so continuing to hold wo n't help .
# y: LMLabelList
# ,,,,
# Path: .;
#
# Test: None

# %%
# Compare number of tokens between first and second data model
len(data_lm2.vocab.itos), len(data_lm.vocab.itos)
# Out:
# (5007, 3635)

# %% [markdown]
# Now we have around 1,5k more tokens to use for prediction!

# %%
# Fit the pretrained language model
learn2 = language_model_learner(data_lm2, AWD_LSTM, drop_mult=0.5)
learn2.fit_one_cycle(1, 1e-2)
# Out:
# Total time: 00:17 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.482459</td>
#       <td>4.665331</td>
#       <td>0.205227</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Find learning rate
learn2.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn2.recorder.plot()

# %%
# Train further learning model
learn2.unfreeze()
learn2.fit_one_cycle(10, 1e-3, moms=(0.8,0.7))
# Out:
# Total time: 03:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.738094</td>
#       <td>4.369100</td>
#       <td>0.226990</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.550375</td>
#       <td>4.166926</td>
#       <td>0.248977</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.358357</td>
#       <td>4.037368</td>
#       <td>0.265327</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.179216</td>
#       <td>3.964646</td>
#       <td>0.271447</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.018961</td>
#       <td>3.908320</td>
#       <td>0.277083</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.878852</td>
#       <td>3.881935</td>
#       <td>0.279408</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.753724</td>
#       <td>3.866576</td>
#       <td>0.281101</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.659350</td>
#       <td>3.863448</td>
#       <td>0.281771</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.601789</td>
#       <td>3.866054</td>
#       <td>0.281920</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.560535</td>
#       <td>3.865941</td>
#       <td>0.281417</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Looking at the quality of language model one can notice the improvement, previously we had around 16%, now 28%.

# %%
learn2.save('fine_tuned2')
learn2.save_encoder('fine_tuned_enc2')

# %% [markdown]
# ### Fine-tuning classification model

# %%
data_clas2 = TextClasDataBunch.from_df('./', train_ULMFIT2_,val_ULMFIT2_, vocab=data_lm2.train_ds.vocab, bs=32)
data_clas2
# Out:
# TextClasDataBunch;
#
# Train: LabelList (9369 items)
# x: TextList
# xxbos pretty sure we did n't actually take off at xxunk,xxbos why de - ice before taxing ? xxmaj maybe it # xxunk ? # shouldhaveflowndelta # unitedsucks,xxbos xxmaj only 14 biz days ( 18 calendar ) to respond to my xxunk ? i hope your standards are xxunk adopted : - / # badcustomerservice,xxbos xxmaj what 's with the pricing xxunk ? ! xxmaj about to book a flight , refreshed the page , & & the price jumped from $ 73 to $ xxunk . xxmaj ridiculous . 😑,xxbos # vegan meals can be more creative than xxunk , xxunk , and xxunk . xxmaj non - vegan xxunk is not acceptable for a vegan . xxmaj can you do better ?
# y: CategoryList
# 0,1,0,0,0
# Path: .;
#
# Valid: LabelList (2343 items)
# x: TextList
# xxbos 's new xxup ceo seeks the right balance to please passengers and xxmaj wall ... - xxmaj xxunk xxmaj daily xxmaj xxunk,xxbos how oh how do we get tickets ! ? !,xxbos xxmaj only xxunk because aa took 2 hrs to call me back . xxmaj ended up paying ( extra ) in $ xxup us so above statement not true,xxbos xxmaj please explain why it costs almost the same price of a full roundtrip fair to only change the departure time of a flight ?,xxbos xxmaj except now there is no wait time , the phone system just hangs up on you . xxmaj so continuing to hold wo n't help .
# y: CategoryList
# 1,1,0,0,0
# Path: .;
#
# Test: None

# %%
# Let's see the exemplary tokenized batch of tweets
data_clas2.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos i xxup just xxup asked xxup my xxup boyfriend xxup to xxup prom xxup over xxup the xxup xxunk xxup on xxup flight xxunk xxup he xxup said xxup yes xxrep 4 ! xxup best xxup day xxup ever ! ! ! xxup thank u xxup so xxup much xxrep 6 !</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup fail xxmaj you xxmaj cancelled xxmaj flightled our flight frm xxup xxunk and then used our reserv home to xxup iah ( from xxup sea ) for reflight xxmaj booking xxmaj problems w / out xxup our xxup xxunk ! ! # xxup xxunk</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos file loc : xxup xxunk . xxmaj bag at airport since last nite . xxmaj not " scheduled " to get xxup xxunk xxunk xxunk 8 ? xxup why ? u shld b ashamed . i 'm disgusted w / u</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj is your xxup bwi - xxup sjd service xxunk ? xxmaj was n't part of extension . xxmaj called intl desk . xxmaj they did n't know . xxmaj want to fly in xxmaj sept on xxmaj sat .</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos sorry for the delayed response . xxmaj it was xxup ua # xxunk xxmaj chicago to xxmaj san xxmaj fran . xxmaj held up for almost an hour on the xxmaj tarmac . xxmaj also , lost my bags</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here we can notice how more types of tokens exist in training column, especially the special ones in form of xxmaj, xxup and so on. We have also the emojis which might have an important role in semantic classification.

# %%
learn2 = text_classifier_learner(data_clas2, AWD_LSTM, drop_mult=0.5)
learn2.load_encoder('fine_tuned_enc2')

# %%
learn2.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn2.recorder.plot()

# %%
learn2.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
learn2.save('first2')
# Out:
# Total time: 00:19 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.730748</td>
#       <td>0.570215</td>
#       <td>0.756722</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.load('first2');
learn2.freeze_to(-2)
learn2.fit_one_cycle(1, slice(1e-2/(2.6**4), 1e-2))
learn2.save('second2')
# Out:
# Total time: 00:22 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.645903</td>
#       <td>0.517806</td>
#       <td>0.791720</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.load('second2')
learn2.freeze_to(-3)
learn2.fit_one_cycle(1, slice(5e-3/(2.6**4),5e-3))
learn2.save('third2')
# Out:
# Total time: 00:35 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.596749</td>
#       <td>0.487471</td>
#       <td>0.807512</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.load('third2');
learn2.unfreeze()
learn2.fit_one_cycle(10, slice(1e-3/(2.6**4), 1e-3), moms=(0.8,0.7),callbacks=[callbacks.SaveModelCallback(learn2, every='improvement', monitor='accuracy', name='best2')])
# Out:
# Total time: 07:30 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.556570</td>
#       <td>0.484862</td>
#       <td>0.808365</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.561681</td>
#       <td>0.470055</td>
#       <td>0.815621</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.528490</td>
#       <td>0.461279</td>
#       <td>0.818182</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.541219</td>
#       <td>0.454627</td>
#       <td>0.823730</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.507327</td>
#       <td>0.467937</td>
#       <td>0.818182</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.487745</td>
#       <td>0.461016</td>
#       <td>0.822023</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.455202</td>
#       <td>0.449329</td>
#       <td>0.827145</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.447676</td>
#       <td>0.452216</td>
#       <td>0.825437</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.436913</td>
#       <td>0.448857</td>
#       <td>0.826291</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.414660</td>
#       <td>0.457231</td>
#       <td>0.826291</td>
#       <td>00:44</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 1 with accuracy value: 0.8083653450012207.
# Better model found at epoch 2 with accuracy value: 0.815621018409729.
# Better model found at epoch 3 with accuracy value: 0.8181818127632141.
# Better model found at epoch 4 with accuracy value: 0.8237302899360657.
# Better model found at epoch 7 with accuracy value: 0.8271446824073792.

# %% [markdown]
# By comparing validation scores I gained 2%! Let's check the result on the test set.

# %% [markdown]
# ### Test set accuracy

# %%
# Create test set in approapraite structure
test_ULMFIT2 = Y_test_ULMFIT2.to_frame().merge(pd.DataFrame(X_test_ULMFIT2), left_index=True, right_index=True)
test_ULMFIT2.columns=['labels','text']
test_ULMFIT2.shape
# Out:
# (2928, 2)

# %%
# Read the best model
learn2.load('best2')
None

# %%
# Compare the test sample betweet UMLFIT1 and UMLFIT2 models
pd.set_option('display.max_colwidth', -1)
test_set_comparison=test_ULMFIT2.head(5).merge(test_ULMFIT.iloc[:,[0,1]].head(5),left_index=True, right_index=True)
test_set_comparison.columns=['labels1','text1','labels2','text2']
test_set_comparison
# Out:
#        labels1  \
# 1022   2
# 11109  2
# 682    0
# 9981   0
# 13686  0
#
#                                                                                                                                   text1  \
# 1022    I will, as soon as I am done with my article.  Thanks!  ~Tom
# 11109   lol me too
# 682     Luckily I made my flights this time but was so disappointed with the lack of communication :(
# 9981    Just Cancelled Flight every flight I have why don't you.
# 13686   The word failure means: an act or instance of failing or proving unsuccessful; lack of success nonperformance of something due.
#
#        labels2  \
# 1022   2
# 11109  2
# 682    0
# 9981   0
# 13686  0
#
#                                                                                                   text2
# 1022   soon do article thanks tom
# 11109  lol
# 682    luckily make flight time disappointed lack communication
# 9981   cancel flight every flight
# 13686  word failure mean act instance fail prove unsuccessful lack success nonperformance something due

# %% [markdown]
# Here one can notice the difference in wealthiness between two cleansing approaches.

# %%
# Let's do the prediction
test_ULMFIT2['Prediction'] = test_ULMFIT2['text'].apply(lambda row: str(learn2.predict(row)[0]))

# %%
# Let's plot the confusion matrix
plot_confusion_matrix(test_ULMFIT2['labels'].astype(int), test_ULMFIT2['Prediction'].astype(int), classes=['Negative','Medium','Positive'], normalize=True,
                      title='Normalized confusion matrix')
print()
print('Accuracy score:',accuracy_score(test_ULMFIT2['labels'].astype(int), test_ULMFIT2['Prediction'].astype(int)))
None
# Out:
# Normalized confusion matrix
# [[0.867563 0.202703 0.111111]
#  [0.102431 0.708494 0.140461]
#  [0.030005 0.088803 0.748428]]
#
# Accuracy score: 0.8200136612021858

# %% [markdown]
# Great improvement!. Now my score equals to **82%**. By abandoning classical cleansing methods and applying the fast.ai tokenizer I gained next 2%.

# %% [markdown]
# ## ULMFIT 3 - Choosing the observation with high confidence score for analysis.

# %% [markdown]
# Having analysed the words in split of sentiment confidence in my EDA section in Notebook-part1, I noticed that for some cases there were significant differences of vocabulary between strong and medium confident tweets.
# I think that I can select only these tweets which have very strong sentiment confidence and train the algorithm on them. They should emphasize the signals much better than all the tweets analysed together.

# %% [markdown]
# ### Prepare the dataset

# %%
# Airline sentiment score
df_tweet['airline_sentiment_confidence'].plot.kde(bw_method=0.1)
None

# %% [markdown]
# I choose the observation with score higher than 80%.

# %%
# Subselect the tweets

df_tweet[(df_tweet.airline_sentiment_confidence >= 0.8)].shape
# Out:
# (10459, 18)

# %%
# Split train nad test
X_train_ULMFIT3, _ , Y_train_ULMFIT3, _ = train_test_split(df_tweet[(df_tweet.airline_sentiment_confidence >= 0.8)]['text_ulmfit2'].apply(lambda x: clean_tweets_light(x)), df_tweet[(df_tweet.airline_sentiment_confidence >= 0.8)]['airline_sentiment'].astype('category').cat.codes, test_size=0.2, random_state=88)

# %% [markdown]
# Here I don't create separate test sets as they are already created.

# %%
X_train_ULMFIT3.shape,X_test_ULMFIT2.shape
# Out:
# ((8367,), (2928,))

# %%
# Show exemplary tweets - cleaned lightly and pre-selected
pd.set_option('display.max_colwidth', -1)
train_ULMFIT3 = Y_train_ULMFIT3.to_frame().merge(pd.DataFrame(X_train_ULMFIT3), left_index=True, right_index=True)
train_ULMFIT3.columns=['labels','text']
print(f'Shape : {train_ULMFIT3.shape}')
train_ULMFIT3.sample(5)
# Out:
# Shape : (8367, 2)
#        labels  \
# 220    0
# 7688   0
# 9958   1
# 12877  0
# 9302   0
#
#                                                                                                                                           text
# 220     had to change to another airline to get to DC today ... Why is  able to land in DC but not you? Cost me $800 ...ugh
# 7688    I missed a goal On  because of your Inept male stewardess. I should have landed already but I havent taken off yet.
# 9958    AA Gate Supervisor emplid 600117 allowed flight AA67 to leave JFK to SJ on 20feb15 w/o 8 customers that made final boarding call.
# 12877   not only on both legs did I have damaged seat, u damaged an expensive case and not offered anything.Just an apology 6wks Late Flightr!
# 9302   . and then you said I could move my Thursday flight for free if I CALL A NUMBER. And then you HANG UP ON ME.

# %%
train_ULMFIT3_, val_ULMFIT3_ = train_test_split(train_ULMFIT3, 
                                                test_size = 0.2, 
                                                random_state = 88)

# %%
train_ULMFIT3_.shape, train_ULMFIT2_.shape
# Out:
# ((6693, 2), (9369, 2))

# %% [markdown]
# I lost almost 3k of tweets for purpose of training due to selection based on confidence.
# It is important to notice that my validation set to which I compare my accuracy during model training consists of the selected tweets (confidence >0.8), whereas my test set is my original test set consisting of all kind of tweets (also these having sentiment confidence lower than 0.8). It means that I can expect higher scores on validation but the true benchmark score will be test set prediction which should be lower than validation score.

# %% [markdown]
# ### Fine-tuning language model

# %%
# Tokenize the words for LM
data_lm3 = TextLMDataBunch.from_df('./', train_ULMFIT3_,val_ULMFIT3_)
data_lm3
# Out:
# TextLMDataBunch;
#
# Train: LabelList (6693 items)
# x: LMTextList
# xxbos it ’s just a bug report , guys,xxbos i want to give a warm thanks to your crew at xxmaj logan airport for still getting me to the xxup dc area after xxmaj cancelled xxmaj flightlations this morning !,xxbos xxmaj are you xxunk any more winners to the # destinationdragons show in xxup utah this weekend ? # xxmaj lucky,xxbos yes ! xxmaj always a treat to fly with you guys ! 😊 ✈ ️,xxbos has no idea what customer service means . xxmaj as the customer , if you mess up my plans , do n't treat me like its no big deal !
# y: LMLabelList
# ,,,,
# Path: .;
#
# Valid: LabelList (1674 items)
# x: LMTextList
# xxbos xxmaj making sure your flights are n't delayed due to poor maintenance would be a start .,xxbos misplaced my bag 36 hr ago and ca n't tell me where it is . i 've lost $ 1000 of stuff :( # americanairlines # xxunk,xxbos over 4 weeks since you took our money and left us stranded 9 hours from home . xxmaj had to rent a car and you still have not helped us,xxbos honestly i ’m glad you did n’t xxmaj cancelled xxmaj flight the flight , just that i ’ll be driving home at 3 - 4 am now . : /,xxbos . xxmaj not what 's been shared by the pilot with passengers !
# y: LMLabelList
# ,,,,
# Path: .;
#
# Test: None

# %%
# Fit the pretrained language model
learn3 = language_model_learner(data_lm3, AWD_LSTM, drop_mult=0.5)
learn3.fit_one_cycle(1, 1e-2)
# Out:
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.614425</td>
#       <td>4.808823</td>
#       <td>0.199479</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Find learning rate
learn3.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn3.recorder.plot()

# %%
# Fine-tune the LM
learn3.unfreeze()
learn3.fit_one_cycle(10, 1e-3, moms=(0.8,0.7))
# Out:
# Total time: 02:48 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.865239</td>
#       <td>4.432508</td>
#       <td>0.223413</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.659314</td>
#       <td>4.221804</td>
#       <td>0.244469</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.452980</td>
#       <td>4.059975</td>
#       <td>0.256275</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.260666</td>
#       <td>3.965018</td>
#       <td>0.265352</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.091630</td>
#       <td>3.912980</td>
#       <td>0.271974</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.943680</td>
#       <td>3.880371</td>
#       <td>0.275694</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.816028</td>
#       <td>3.865519</td>
#       <td>0.277579</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.712872</td>
#       <td>3.863450</td>
#       <td>0.277728</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.639132</td>
#       <td>3.861272</td>
#       <td>0.278547</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.591646</td>
#       <td>3.862769</td>
#       <td>0.278423</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn3.save('fine_tuned3')
learn3.save_encoder('fine_tuned_enc3')

# %% [markdown]
# The trained ULMFIT3 LM looks comparable to ULMFIT2 LM model in terms of accuracy.

# %% [markdown]
# ### Fine-tuning classification model

# %%
# Prepare data for classification model
data_clas3 = TextClasDataBunch.from_df('./', train_ULMFIT3_,val_ULMFIT3_, vocab=data_lm3.train_ds.vocab, bs=32)
data_clas3
# Out:
# TextClasDataBunch;
#
# Train: LabelList (6693 items)
# x: TextList
# xxbos it ’s just a bug report , guys,xxbos i want to give a warm thanks to your crew at xxmaj logan airport for still getting me to the xxup dc area after xxmaj cancelled xxmaj flightlations this morning !,xxbos xxmaj are you xxunk any more winners to the # destinationdragons show in xxup utah this weekend ? # xxmaj lucky,xxbos yes ! xxmaj always a treat to fly with you guys ! 😊 ✈ ️,xxbos has no idea what customer service means . xxmaj as the customer , if you mess up my plans , do n't treat me like its no big deal !
# y: CategoryList
# 1,2,1,2,0
# Path: .;
#
# Valid: LabelList (1674 items)
# x: TextList
# xxbos xxmaj making sure your flights are n't delayed due to poor maintenance would be a start .,xxbos misplaced my bag 36 hr ago and ca n't tell me where it is . i 've lost $ 1000 of stuff :( # americanairlines # xxunk,xxbos over 4 weeks since you took our money and left us stranded 9 hours from home . xxmaj had to rent a car and you still have not helped us,xxbos honestly i ’m glad you did n’t xxmaj cancelled xxmaj flight the flight , just that i ’ll be driving home at 3 - 4 am now . : /,xxbos . xxmaj not what 's been shared by the pilot with passengers !
# y: CategoryList
# 0,0,0,0,0
# Path: .;
#
# Test: None

# %%
# Let's tune classification model
learn3 = text_classifier_learner(data_clas3, AWD_LSTM, drop_mult=0.5)
learn3.load_encoder('fine_tuned_enc3')

# %%
learn3.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn3.recorder.plot()

# %%
# Tuning classification model using Gradual Unfreezing
learn3.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
learn3.save('first3')
# Out:
# Total time: 00:14 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.599574</td>
#       <td>0.399241</td>
#       <td>0.839307</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn3.load('first3');
learn3.freeze_to(-2)
learn3.fit_one_cycle(1, slice(1e-2/(2.6**4), 1e-2))
learn3.save('second3')
# Out:
# Total time: 00:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.531623</td>
#       <td>0.349482</td>
#       <td>0.871565</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn3.load('second3')
learn3.freeze_to(-3)
learn3.fit_one_cycle(1, slice(5e-3/(2.6**4),5e-3))
learn3.save('third3')
# Out:
# Total time: 00:25 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.476796</td>
#       <td>0.320753</td>
#       <td>0.887694</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn3.load('third3');
learn3.unfreeze()
learn3.fit_one_cycle(15, slice(1e-3/(2.6**4), 5e-4), moms=(0.8,0.7),callbacks=[callbacks.SaveModelCallback(learn3, every='improvement', monitor='accuracy', name='best3')])
# Out:
# Total time: 08:25 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.428759</td>
#       <td>0.314168</td>
#       <td>0.892473</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.426104</td>
#       <td>0.314587</td>
#       <td>0.890681</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.427127</td>
#       <td>0.316740</td>
#       <td>0.890084</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.413861</td>
#       <td>0.305272</td>
#       <td>0.896057</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.356786</td>
#       <td>0.306943</td>
#       <td>0.894863</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.366104</td>
#       <td>0.297609</td>
#       <td>0.896057</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.351447</td>
#       <td>0.302249</td>
#       <td>0.900239</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.358197</td>
#       <td>0.291552</td>
#       <td>0.899642</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.327970</td>
#       <td>0.302614</td>
#       <td>0.899044</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.320382</td>
#       <td>0.304208</td>
#       <td>0.893668</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.310922</td>
#       <td>0.298783</td>
#       <td>0.895460</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.301874</td>
#       <td>0.291253</td>
#       <td>0.894863</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.288346</td>
#       <td>0.301270</td>
#       <td>0.900836</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.317789</td>
#       <td>0.299352</td>
#       <td>0.901434</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.308070</td>
#       <td>0.294889</td>
#       <td>0.900836</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 1 with accuracy value: 0.8924731016159058.
# Better model found at epoch 4 with accuracy value: 0.8960573673248291.
# Better model found at epoch 7 with accuracy value: 0.9002389311790466.
# Better model found at epoch 13 with accuracy value: 0.9008363485336304.
# Better model found at epoch 14 with accuracy value: 0.9014337062835693.

# %%
# Read the best model
learn3.load('best3')
None

# %% [markdown]
# For validation which consists only from highly confident sentiment tweets, I reached score above **90%**, nice!. Let's see the impact of my change on the test set.

# %% [markdown]
# ### Test set accuracy

# %%
test_ULMFIT3=test_ULMFIT2.copy()

# %%
test_ULMFIT3['Prediction'] = test_ULMFIT3['text'].apply(lambda row: str(learn3.predict(row)[0]))

# %%
plot_confusion_matrix(test_ULMFIT3['labels'].astype(int), test_ULMFIT3['Prediction'].astype(int), classes=['Negative','Medium','Positive'], normalize=True,
                      title='Normalized confusion matrix')
print()
print('Accuracy score:',accuracy_score(test_ULMFIT3['labels'].astype(int), test_ULMFIT3['Prediction'].astype(int)))
None
# Out:
# Normalized confusion matrix
# [[0.853563 0.132867 0.088362]
#  [0.114005 0.785548 0.135776]
#  [0.032432 0.081585 0.775862]]
#
# Accuracy score: 0.8312841530054644

# %% [markdown]
# My score increased from 82% to **83%**.. I expected a bit more.
# Nevertheless this is my final score and final model.
# It is also worth emphasizing that I improved the prediction for neutral and medium sentiment class and worsened a bit the score for negative class. Let's see why it happened.

# %%
import seaborn as sns
custom_bucket_array = np.linspace(0.2, 1, 4)
custom_bucket_array
df_tweet['airline_sentiment_confidence_buckets'] = pd.cut(df_tweet['airline_sentiment_confidence'], custom_bucket_array, labels=["weak", "medium", "strong"])

ax = pd.crosstab(index = df_tweet["airline_sentiment"],columns = df_tweet["airline_sentiment_confidence_buckets"]).apply(lambda x: round(x / x.sum() * 100,2), axis=1).plot(kind='bar',
                                                                                                                                                                            color=sns.color_palette("Pastel1", 10),
                                                                                                                                                                            figsize=(10, 6),
                                                                                                                                                                            rot=0,
                                                                                                                                                                            stacked=True,
                                                                                                                                                                            title="Sentiment Confidence")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

for p in ax.patches:
  #print(p.get_width())
  width, heigth = p.get_width(), p.get_height()
  x, y = p.get_xy()
  ax.annotate('{:.0f}%'.format(heigth), (p.get_x()+.4*width, p.get_y()+.44*heigth))

None

# %% [markdown]
# The reason for the boost in precision for neutral and positive classes is that the medium share is quite big (47% for neutral and 33% for positive) and I get rid of it for training the model. For neutral and positive classes the medium tweets consist rather from non-informative wording whereas for negative class the medium confident tweets might have some valuable predictive power and when I removed these tweets from training, then I lost this predictive power. I could check this hypothesis by adding to training the medium negative class now, but I will not to that due to lack of time.

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Conclusions**:
# * My final score reached **83.12%** on the test set, which could be perceived as very good result for this data set.
# * UMLFIT occured to be great tool for quickly getting good results. However when comparing the same training data with LSTM scores the UMLFIT improved the score just by a tiny bit. The reason for this might be that the tweet data does not use the potential of the ULMFIT architecture, the beauty of multi-layer transfer learning. The vocabulary is limited and tweets are short. I am pretty sure that for other wealthier in terms of semantic as well as longer sequences, this model will outperform vanilla-LSTM.
# * I see further technical-modelling improvements to reach higher score :
#   * Implementation of attention mechanism which could capture the position of words in tweet, hypothesis is that either at the beginning or at the end of tweet there might be the words significantly indicating the sentiment, therefore making signal of the position of the words might contribute to score significantly.
#   * Better optimization of ULMFIT from my side. I think that by choosing better: learning rate and other parameters (scale, wd etc.) I could reach better result. For now I do not have tools to find optimized hyper-parameters for this model.
#   * Other score metrics like weighted accuracy or sampling strategies to balance the sentiment classes. I did not play with other metrics, especially when in the end I get quite uniform precision per class (85%-negative, 79%-neutral, 78%-positive) but maybe I could reach overall higher accuracy by choosing other metrics for optimization.
# * I see further feature engineering improvements to reach higher score:
#  * Good analysis of emojis and conversion them to english text. I think that if we could map the emojis to certain words, then the signal of the meaning of particular words would increase. Like :) could mean happy and then we could join the effect of token happy rather then create two separate tokens.
#  * Algorithm which could separate the words in #hashtags. Quite often hashtags consist of many words presented in one non-separable string like #behappyandbrave. Hashtags might capture some meaningful emotions or contents and being treated as separate tokens might have better predicitive powers.
#  * Adding other variables from data set, like location or time and do the stacking approach of LSTM + some classifier where LSTM would capture the text influence and second model would capture the other dimensions sentiment impact.
